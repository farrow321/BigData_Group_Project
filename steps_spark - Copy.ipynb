# %%
import time

# %%
from pyspark import SparkContext, SparkConf

conf = SparkConf().set('spark.executor.memory', '16g')\
                    .set('spark.driver.memory', '16g')\
                    .setAppName("beer_analysis")\
                    .setMaster('local[*]')
sc = SparkContext(conf=conf)
sc
# Out:
# <SparkContext master=local[*] appName=beer_analysis>

# %%
elapsed_times_list = []
start_time_overall = time.time()

# %%
# STEP 1
start_time1 = time.time()

rdd = sc.textFile('beer_reviews.csv')
header = rdd.first()
rdd = rdd.filter(lambda line: line != header)
split_rdd = rdd.map(lambda x: x.split(','))

end_time1 = time.time()
elapsed_time1 = end_time1 - start_time1
elapsed_times_list.append(elapsed_time1)
print(f"Elapsed time: {elapsed_time1} seconds")
# Out:
# Elapsed time: 0.6035358905792236 seconds

# %%
# STEP 2
start_time2 = time.time()

review_overall_rdd = split_rdd.map(lambda x: (float(x[4]), x))
mapped_rdd = review_overall_rdd.filter(lambda x: x[0] == 5)
mapped_rdd = mapped_rdd.map(lambda x: x[1])

end_time2 = time.time()
elapsed_time2 = end_time2 - start_time2
elapsed_times_list.append(elapsed_time2)
print(f"Elapsed time: {elapsed_time2} seconds")


mapped_rdd.collect()
# Out:
# Elapsed time: 0.0 seconds
# [['11',
#   '1075',
#   'Caldera Brewing Company',
#   '1283154365',
#   '5.0',
#   '5.0',
#   '4.0',
#   'MadeInOregon',
#   'Herbed / Spiced Beer',
#   '4.0',
#   '4.0',
#   'Caldera Ginger Beer',
#   '4.7',
#   '52159'],
#  ['25',
#   '1075',
#   'Caldera Brewing Company',
#   '1318802642',
#   '5.0',
#   '5.0',
#   '3.5',
#   'optimator13',
#   'Rauchbier',
#   '3.5',
#   '5.0',
#   'Rauch Ür Bock',
#   '7.4',
#   '58046'],
#  ['31',
#   '1075',
#   'Caldera Brewing Company',
#   '1315014054',
#   '5.0',
#   '4.5',
#   '4.0',
#   'Bung',
#   'Rauchbier',
#   '4.0',
#   '5.0',
#   'Rauch Ür Bock',
#   '7.4',
#   '58046'],
#  ['42',
#   '1075',
#   'Caldera Brewing Company',
#   '1305926255',
#   '5.0',
#   '4.5',
#   '3.5',
#   'Deuane',
#   'Rauchbier',
#   '4.0',
#   '5.0',
#   'Rauch Ür Bock',
#   '7.4',
#   '58046'],
#  ['73',
#   '1075',
#   'Caldera Brewing Company',
#   '1246913078',
#   '5.0',
#   '4.0',
#   '4.5',
#   'GratefulBeerGuy',
#   'American Pale Ale (APA)',
#   '4.5',
#   '4.0',
#   'Caldera Pale Ale',
#   '5.5',
#   '25414'],
#  ['87',
#   '1075',
#   'Caldera Brewing Company',
#   '1235940573',
#   '5.0',
#   '3.5',
#   '4.0',
#   'mtrentm',
#   'American Pale Ale (APA)',
#   '4.0',
#   '5.0',
#   'Caldera Pale Ale',
#   '5.5',
#   '25414'],
#  ['88',
#   '1075',
#   'Caldera Brewing Company',
#   '1235869779',
#   '5.0',
#   '4.0',
#   '4.5',
#   'maximum12',
#   'American Pale Ale (APA)',
#   '4.0',
#   '4.0',
#   'Caldera Pale Ale',
#   '5.5',
#   '25414'],
#  ['118',
#   '1075',
#   'Caldera Brewing Company',
#   '1206326545',
#   '5.0',
#   '4.0',
#   '3.5',
#   'BeerZack',
#   'American Pale Ale (APA)',
#   '4.5',
#   '4.0',
#   'Caldera Pale Ale',
#   '5.5',
#   '25414'],
#  ['131',
#   '1075',
#   'Caldera Brewing Company',
#   '1160699043',
#   '5.0',
#   '4.0',
#   '3.5',
#   'IntriqKen',
#   'American Pale Ale (APA)',
#   '4.0',
#   '4.0',
#   'Caldera Pale Ale',
#   '5.5',
#   '25414'],
#  ['190',
#   '1075',
#   'Caldera Brewing Company',
#   '1258511938',
#   '5.0',
#   '5.0',
#   '3.0',
#   'cjever19',
#   'American Pale Ale (APA)',
#   '5.0',
#   '5.0',
#   'Caldera Pale Ale',
#   '5.5',
#   '25414'],
#  ['191',
#   '1075',
#   'Caldera Brewing Company',
#   '1280377901',
#   '5.0',
#   '3.5',
#   '4.0',
#   'ThreeWiseMen',
#   'American Pale Ale (APA)',
#   '5.0',
#   '4.0',
#   'Caldera Pale Ale',
#   '5.5',
#   '25414'],
#  ['210',
#   '1075',
#   'Caldera Brewing Company',
#   '1265831510',
#   '5.0',
#   '4.0',
#   '4.0',
#   'onix1agr',
#   'American Pale Ale (APA)',
#   '4.5',
#   '4.0',
#   'Caldera Pale Ale',
#   '5.5',
#   '25414'],
#  ['216',
#   '1075',
#   'Caldera Brewing Company',
#   '1261976212',
#   '5.0',
#   '4.0',
#   '4.0',
#   'womencantsail',
#   'American Pale Ale (APA)',
#   '4.0',
#   '4.5',
#   'Caldera Pale Ale',
#   '5.5',
#   '25414'],
#  ['232',
#   '1075',
#   'Caldera Brewing Company',
#   '1254977926',
#   '5.0',
#   '4.0',
#   '4.5',
#   'Reidrover',
#   'American Porter',
#   '4.0',
#   '4.0',
#   'Pilot Rock Porter',
#   '5.8',
#   '10788'],
#  ['269',
#   '1075',
#   'Caldera Brewing Company',
#   '1277179584',
#   '5.0',
#   '4.0',
#   '4.0',
#   'GRG1313',
#   'Belgian Strong Dark Ale',
#   '3.5',
#   '4.0',
#   'Vas Deferens Ale',
#   '8.1',
#   '58920'],
#  ['286',
#   '1075',
#   'Caldera Brewing Company',
#   '1312575615',
#   '5.0',
#   '4.5',
#   '4.5',
#   'Tilley4',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Old Growth Imperial Stout',
#   '8.8',
#   '20818'],
#  ['287',
#   '1075',
#   'Caldera Brewing Company',
#   '1310693953',
#   '5.0',
#   '5.0',
#   '5.0',
#   'Cyberkedi',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Old Growth Imperial Stout',
#   '8.8',
#   '20818'],
#  ['303',
#   '1075',
#   'Caldera Brewing Company',
#   '1232517923',
#   '5.0',
#   '4.5',
#   '4.5',
#   'bitterthebetter',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Old Growth Imperial Stout',
#   '8.8',
#   '20818'],
#  ['324',
#   '1075',
#   'Caldera Brewing Company',
#   '1275771652',
#   '5.0',
#   '4.0',
#   '4.0',
#   'Wetpaperbag',
#   'American Adjunct Lager',
#   '4.0',
#   '4.5',
#   'Lawnmower Lager',
#   '3.9',
#   '20817'],
#  ['346',
#   '1075',
#   'Caldera Brewing Company',
#   '1294974656',
#   '5.0',
#   '4.0',
#   '5.0',
#   'lnashsig',
#   'American IPA',
#   '4.0',
#   '4.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['369',
#   '1075',
#   'Caldera Brewing Company',
#   '1288326570',
#   '5.0',
#   '4.0',
#   '4.5',
#   'wcudwight',
#   'American IPA',
#   '4.5',
#   '4.5',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['372',
#   '1075',
#   'Caldera Brewing Company',
#   '1287709770',
#   '5.0',
#   '4.0',
#   '4.0',
#   'DeanMoriarty',
#   'American IPA',
#   '4.0',
#   '4.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['395',
#   '1075',
#   'Caldera Brewing Company',
#   '1282425919',
#   '5.0',
#   '4.0',
#   '4.0',
#   'samie85',
#   'American IPA',
#   '4.5',
#   '4.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['404',
#   '1075',
#   'Caldera Brewing Company',
#   '1280541063',
#   '5.0',
#   '4.0',
#   '4.5',
#   'JohnQVegas',
#   'American IPA',
#   '4.5',
#   '5.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['431',
#   '1075',
#   'Caldera Brewing Company',
#   '1275388099',
#   '5.0',
#   '5.0',
#   '4.5',
#   'Freethyhops',
#   'American IPA',
#   '3.5',
#   '4.5',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['432',
#   '1075',
#   'Caldera Brewing Company',
#   '1274584909',
#   '5.0',
#   '5.0',
#   '4.5',
#   'wolfinthemirror',
#   'American IPA',
#   '4.5',
#   '4.5',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['443',
#   '1075',
#   'Caldera Brewing Company',
#   '1325980456',
#   '5.0',
#   '5.0',
#   '5.0',
#   'vicsju1991',
#   'American IPA',
#   '5.0',
#   '5.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['449',
#   '1075',
#   'Caldera Brewing Company',
#   '1324173764',
#   '5.0',
#   '5.0',
#   '4.0',
#   'IPAguy2009',
#   'American IPA',
#   '4.0',
#   '4.5',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['482',
#   '1075',
#   'Caldera Brewing Company',
#   '1261454050',
#   '5.0',
#   '4.5',
#   '4.0',
#   'Gyle41386',
#   'American IPA',
#   '4.0',
#   '4.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['496',
#   '1075',
#   'Caldera Brewing Company',
#   '1258906716',
#   '5.0',
#   '5.0',
#   '4.0',
#   'woodychandler',
#   'American IPA',
#   '4.0',
#   '5.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['510',
#   '1075',
#   'Caldera Brewing Company',
#   '1253477448',
#   '5.0',
#   '4.5',
#   '4.5',
#   'Stimwizzle',
#   'American IPA',
#   '5.0',
#   '5.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['525',
#   '1075',
#   'Caldera Brewing Company',
#   '1250097211',
#   '5.0',
#   '4.0',
#   '4.0',
#   'beerswamie',
#   'American IPA',
#   '4.5',
#   '5.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['549',
#   '1075',
#   'Caldera Brewing Company',
#   '1245540392',
#   '5.0',
#   '5.0',
#   '4.5',
#   'jfitzy78',
#   'American IPA',
#   '4.5',
#   '5.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['586',
#   '1075',
#   'Caldera Brewing Company',
#   '1235943951',
#   '5.0',
#   '4.0',
#   '4.5',
#   'mtrentm',
#   'American IPA',
#   '4.0',
#   '5.0',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['625',
#   '1075',
#   'Caldera Brewing Company',
#   '1207535403',
#   '5.0',
#   '4.0',
#   '4.0',
#   'libertygrails',
#   'American IPA',
#   '4.0',
#   '4.5',
#   'Caldera IPA',
#   '6.1',
#   '10784'],
#  ['797',
#   '1075',
#   'Caldera Brewing Company',
#   '1267073262',
#   '5.0',
#   '4.0',
#   '4.5',
#   'kevinmkirk',
#   'American IPA',
#   '4.0',
#   '5.0',
#   'Hopportunity Knocks',
#   '6.8',
#   '56071'],
#  ['799',
#   '1075',
#   'Caldera Brewing Company',
#   '1100675578',
#   '5.0',
#   '4.0',
#   '4.5',
#   'freed',
#   'American Strong Ale',
#   '4.5',
#   '5.0',
#   'Cauldron Brew',
#   '7.6',
#   '10793'],
#  ['908',
#   '1075',
#   'Caldera Brewing Company',
#   '1282674179',
#   '5.0',
#   '4.5',
#   '5.0',
#   'eatabagofbooger',
#   'American Porter',
#   '5.0',
#   '5.0',
#   'Mogli',
#   '8.5',
#   '60990'],
#  ['909',
#   '1075',
#   'Caldera Brewing Company',
#   '1281680251',
#   '5.0',
#   '5.0',
#   '4.5',
#   'squaremile',
#   'American Porter',
#   '5.0',
#   '4.5',
#   'Mogli',
#   '8.5',
#   '60990'],
#  ['1025',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1240171428',
#   '5.0',
#   '2.0',
#   '2.0',
#   'archerwrestler',
#   'Light Lager',
#   '3.0',
#   '3.0',
#   'Amstel Light',
#   '3.5',
#   '436'],
#  ['1032',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1235954167',
#   '5.0',
#   '2.0',
#   '3.0',
#   'McKnightOwl',
#   'Light Lager',
#   '2.0',
#   '2.5',
#   'Amstel Light',
#   '3.5',
#   '436'],
#  ['1075',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1219022467',
#   '5.0',
#   '3.0',
#   '4.0',
#   'ejthetiger',
#   'Light Lager',
#   '5.0',
#   '5.0',
#   'Amstel Light',
#   '3.5',
#   '436'],
#  ['1131',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1194928706',
#   '5.0',
#   '4.0',
#   '4.5',
#   'NascarJDS',
#   'Light Lager',
#   '5.0',
#   '5.0',
#   'Amstel Light',
#   '3.5',
#   '436'],
#  ['1136',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1189389953',
#   '5.0',
#   '3.0',
#   '2.0',
#   'botham',
#   'Light Lager',
#   '3.0',
#   '2.0',
#   'Amstel Light',
#   '3.5',
#   '436'],
#  ['1145',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1183597496',
#   '5.0',
#   '3.0',
#   '4.0',
#   'riemenschneider',
#   'Light Lager',
#   '2.0',
#   '4.0',
#   'Amstel Light',
#   '3.5',
#   '436'],
#  ['1262',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1112840376',
#   '5.0',
#   '3.0',
#   '3.0',
#   'samsneed',
#   'Light Lager',
#   '4.0',
#   '4.0',
#   'Amstel Light',
#   '3.5',
#   '436'],
#  ['1264',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1111539398',
#   '5.0',
#   '2.0',
#   '3.0',
#   'sinkr',
#   'Light Lager',
#   '3.0',
#   '4.0',
#   'Amstel Light',
#   '3.5',
#   '436'],
#  ['1449',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1238550598',
#   '5.0',
#   '3.0',
#   '3.0',
#   'guitarcrazy3',
#   'Euro Pale Lager',
#   '4.0',
#   '4.0',
#   'Amstel Bright',
#   '5.0',
#   '3386'],
#  ['1450',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1231533223',
#   '5.0',
#   '2.5',
#   '2.5',
#   'frankld2',
#   'Euro Pale Lager',
#   '3.0',
#   '3.5',
#   'Amstel Bright',
#   '5.0',
#   '3386'],
#  ['1467',
#   '163',
#   'Amstel Brouwerij B. V.',
#   '1304375804',
#   '5.0',
#   '4.0',
#   '4.0',
#   'EssexAleMan',
#   'Euro Pale Lager',
#   '4.5',
#   '3.0',
#   'Amstel Lager',
#   '5.0',
#   '1414'],
#  ['1628',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1215108987',
#   '5.0',
#   '4.5',
#   '4.0',
#   'JamesS',
#   'American Amber / Red Lager',
#   '4.0',
#   '4.5',
#   'Amarillo Lager',
#   '5.0',
#   '43516'],
#  ['1641',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1160669337',
#   '5.0',
#   '3.5',
#   '4.5',
#   'RustyShackleford',
#   'Märzen / Oktoberfest',
#   '4.0',
#   '4.5',
#   'Oktoberfest',
#   '5.5',
#   '13289'],
#  ['1649',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1294015618',
#   '5.0',
#   '4.0',
#   '4.5',
#   'JamesS',
#   'English Strong Ale',
#   '4.0',
#   '4.5',
#   'Limping Mallard',
#   '7.7',
#   '63460'],
#  ['1650',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1289592403',
#   '5.0',
#   '4.5',
#   '4.5',
#   'ktrillionaire',
#   'English Strong Ale',
#   '5.0',
#   '5.0',
#   'Limping Mallard',
#   '7.7',
#   '63460'],
#  ['1654',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1318962300',
#   '5.0',
#   '4.0',
#   '4.5',
#   'JamesS',
#   'American Pale Ale (APA)',
#   '5.0',
#   '5.0',
#   'Extra Pale Ale',
#   '5.0',
#   '38414'],
#  ['1656',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1268435695',
#   '5.0',
#   '5.0',
#   '4.5',
#   '908carson',
#   'American Porter',
#   '5.0',
#   '4.5',
#   'Monon Porter',
#   '6.0',
#   '39008'],
#  ['1659',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1191940359',
#   '5.0',
#   '4.0',
#   '4.5',
#   'JamesS',
#   'American Porter',
#   '5.0',
#   '4.5',
#   'Monon Porter',
#   '6.0',
#   '39008'],
#  ['1660',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1295878422',
#   '5.0',
#   '4.0',
#   '4.0',
#   'JamesS',
#   'Märzen / Oktoberfest',
#   '5.0',
#   '4.0',
#   'Marzen',
#   '5.2',
#   '65568'],
#  ['1670',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1191939582',
#   '5.0',
#   '3.0',
#   '4.0',
#   'JamesS',
#   'American IPA',
#   '4.0',
#   '4.0',
#   'I.P.A.',
#   '6.2',
#   '6825'],
#  ['1678',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1299188185',
#   '5.0',
#   '5.0',
#   '4.0',
#   'JamesS',
#   'American Porter',
#   '4.0',
#   '5.0',
#   'Jack Daniels Barrel Aged Porter',
#   '6.0',
#   '66857'],
#  ['1679',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1292279279',
#   '5.0',
#   '4.5',
#   '5.0',
#   'JamesS',
#   'English Strong Ale',
#   '4.0',
#   '4.0',
#   "Bigger Boy's Beer",
#   '8.4',
#   '63020'],
#  ['1694',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1295991277',
#   '5.0',
#   '4.0',
#   '4.5',
#   'JamesS',
#   'American Pale Ale (APA)',
#   '4.5',
#   '5.0',
#   'Amarillo Single Hop Pale Ale',
#   '5.0',
#   '65636'],
#  ['1695',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1298059262',
#   '5.0',
#   '4.0',
#   '4.0',
#   'JamesS',
#   'American Double / Imperial IPA',
#   '4.5',
#   '4.5',
#   'Hopcicle Double IPA',
#   '9.0',
#   '55445'],
#  ['1701',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1298059701',
#   '5.0',
#   '4.0',
#   '4.0',
#   'JamesS',
#   'American Double / Imperial Stout',
#   '5.0',
#   '4.5',
#   "Ackerman's Imperial Double Stout (Winterfest Replicale 2011)",
#   '8.0',
#   '66430'],
#  ['1708',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1279124302',
#   '5.0',
#   '5.0',
#   '4.0',
#   'ktrillionaire',
#   'Extra Special / Strong Bitter (ESB)',
#   '5.0',
#   '4.5',
#   'E.S.B.',
#   '5.6',
#   '6824'],
#  ['1715',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1303400336',
#   '5.0',
#   '4.0',
#   '4.5',
#   'JamesS',
#   'English Bitter',
#   '5.0',
#   '4.5',
#   "T.J.'s Best Bitter",
#   '5.3',
#   '16491'],
#  ['1716',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1166540267',
#   '5.0',
#   '3.0',
#   '4.0',
#   'Ricochet',
#   'Extra Special / Strong Bitter (ESB)',
#   '4.0',
#   '4.5',
#   'E.S.B.',
#   '5.6',
#   '6824'],
#  ['1717',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1156176091',
#   '5.0',
#   '4.5',
#   '4.5',
#   'Generik420',
#   'Extra Special / Strong Bitter (ESB)',
#   '4.5',
#   '5.0',
#   'E.S.B.',
#   '5.6',
#   '6824'],
#  ['1725',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1299187586',
#   '5.0',
#   '4.0',
#   '3.5',
#   'JamesS',
#   'California Common / Steam Beer',
#   '5.0',
#   '4.0',
#   'California Common',
#   '5.0',
#   '66856'],
#  ['1729',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1182392570',
#   '5.0',
#   '5.0',
#   '5.0',
#   'shbobdb',
#   'English Bitter',
#   '5.0',
#   '5.0',
#   "T.J.'s Best Bitter",
#   '5.3',
#   '16491'],
#  ['1739',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1287451400',
#   '5.0',
#   '5.0',
#   '4.0',
#   'JamesS',
#   'Irish Dry Stout',
#   '4.5',
#   '5.0',
#   "Finneen's Auld Sod Stout",
#   '4.8',
#   '43364'],
#  ['1744',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1323979200',
#   '5.0',
#   '4.5',
#   '4.0',
#   'JamesS',
#   'Euro Dark Lager',
#   '4.5',
#   '5.0',
#   'Black Heart Lager',
#   '5.9',
#   '43944'],
#  ['1750',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1262208342',
#   '5.0',
#   '4.5',
#   '5.0',
#   'JamesS',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '4.5',
#   'Wee Alec Heavy',
#   '7.7',
#   '8284'],
#  ['1754',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1104559525',
#   '5.0',
#   '5.0',
#   '4.5',
#   'RustyShackleford',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '4.5',
#   'Wee Alec Heavy',
#   '7.7',
#   '8284'],
#  ['1756',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1294324816',
#   '5.0',
#   '4.5',
#   '4.5',
#   'JamesS',
#   'English Pale Ale',
#   '5.0',
#   '4.0',
#   'Lawn Mower Pale Ale',
#   '5.0',
#   '61478'],
#  ['1763',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1156177895',
#   '5.0',
#   '4.5',
#   '4.5',
#   'Generik420',
#   'Saison / Farmhouse Ale',
#   '4.5',
#   '5.0',
#   'Farmhouse Ale',
#   '5.9',
#   '32306'],
#  ['1764',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1155747089',
#   '5.0',
#   '4.0',
#   '4.0',
#   'BlackAngus',
#   'Saison / Farmhouse Ale',
#   '4.0',
#   '4.5',
#   'Farmhouse Ale',
#   '5.9',
#   '32306'],
#  ['1765',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1321646001',
#   '5.0',
#   '4.0',
#   '4.5',
#   'JamesS',
#   'American Pale Ale (APA)',
#   '4.0',
#   '4.5',
#   'Centennial Pale Ale',
#   '5.0',
#   '75449'],
#  ['1766',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1294013791',
#   '5.0',
#   '4.0',
#   '4.0',
#   'JamesS',
#   'American Pale Ale (APA)',
#   '4.5',
#   '4.5',
#   'Wobbly Bob APA',
#   '5.5',
#   '15660'],
#  ['1767',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1289594316',
#   '5.0',
#   '4.0',
#   '4.0',
#   'ktrillionaire',
#   'American Pale Ale (APA)',
#   '4.0',
#   '4.5',
#   'Wobbly Bob APA',
#   '5.5',
#   '15660'],
#  ['1768',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1288538410',
#   '5.0',
#   '5.0',
#   '5.0',
#   '908carson',
#   'American Pale Ale (APA)',
#   '5.0',
#   '5.0',
#   'Wobbly Bob APA',
#   '5.5',
#   '15660'],
#  ['1772',
#   '1454',
#   'Broad Ripple Brew Pub',
#   '1075563582',
#   '5.0',
#   '4.5',
#   '4.5',
#   'zerk',
#   'American Pale Ale (APA)',
#   '4.5',
#   '4.5',
#   'Wobbly Bob APA',
#   '5.5',
#   '15660'],
#  ['1955',
#   '850',
#   'Moon River Brewing Company',
#   '1096081380',
#   '5.0',
#   '2.5',
#   '3.0',
#   'aracauna',
#   'Märzen / Oktoberfest',
#   '3.0',
#   '3.0',
#   'Savannah Fest Beer',
#   '4.9',
#   '8717'],
#  ['1985',
#   '850',
#   'Moon River Brewing Company',
#   '1217627049',
#   '5.0',
#   '3.5',
#   '4.0',
#   'Gavage',
#   'American Brown Ale',
#   '5.0',
#   '4.5',
#   "Gene's American Brown Ale",
#   '6.0',
#   '44081'],
#  ['2004',
#   '577',
#   'Isle Of Skye Brewery',
#   '1221848246',
#   '5.0',
#   '4.5',
#   '4.0',
#   'Offa',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Wee Beast (Cuillin Beast)',
#   '7.0',
#   '17010'],
#  ['2029',
#   '577',
#   'Isle Of Skye Brewery',
#   '1160533136',
#   '5.0',
#   '4.0',
#   '4.0',
#   'scruffwhor',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '4.5',
#   'Wee Beast (Cuillin Beast)',
#   '7.0',
#   '17010'],
#  ['2130',
#   '577',
#   'Isle Of Skye Brewery',
#   '1000848115',
#   '5.0',
#   '5.0',
#   '5.0',
#   'dennis',
#   'Scottish Ale',
#   '5.0',
#   '5.0',
#   'Black Cuillin',
#   '4.5',
#   '1557'],
#  ['2171',
#   '14756',
#   'Bluegrass Brewing Co.',
#   '1232757768',
#   '5.0',
#   '4.0',
#   '3.5',
#   'DarkerTheBetter',
#   'Altbier',
#   '4.5',
#   '4.5',
#   'Altbier',
#   '4.19',
#   '45132'],
#  ['2271',
#   '21841',
#   'Craggie Brewing Company',
#   '1289830150',
#   '5.0',
#   '4.0',
#   '4.0',
#   'goindownsouth',
#   'Keller Bier / Zwickel Bier',
#   '4.5',
#   '4.5',
#   'Toubab Brewe',
#   '4.2',
#   '57668'],
#  ['2321',
#   '21841',
#   'Craggie Brewing Company',
#   '1287426971',
#   '5.0',
#   '4.0',
#   '4.0',
#   'thagr81us',
#   'Doppelbock',
#   '4.0',
#   '4.0',
#   'Germinator Doppelbock',
#   '6.0',
#   '62717'],
#  ['2399',
#   '16859',
#   'Great South Bay Brewery',
#   '1313808291',
#   '5.0',
#   '5.0',
#   '5.0',
#   'cstrong821',
#   'American Blonde Ale',
#   '5.0',
#   '5.0',
#   'Blonde Ambition',
#   '4.8',
#   '61800'],
#  ['2478',
#   '23246',
#   'Yeastie Boys',
#   '1307184100',
#   '5.0',
#   '4.5',
#   '4.5',
#   'joecast',
#   'American Black Ale',
#   '4.5',
#   '4.5',
#   'Pot Kettle Black',
#   '6.0',
#   '66818'],
#  ['2483',
#   '23246',
#   'Yeastie Boys',
#   '1299068754',
#   '5.0',
#   '4.0',
#   '4.0',
#   'ADZA',
#   'American Black Ale',
#   '4.0',
#   '4.5',
#   'Pot Kettle Black',
#   '6.0',
#   '66818'],
#  ['2568',
#   '15527',
#   'Meta Abo Brewery - Ethiopia',
#   '1269830797',
#   '5.0',
#   '3.0',
#   '4.0',
#   'ManofWax',
#   'American Adjunct Lager',
#   '4.5',
#   '4.0',
#   'Meta Export Lager',
#   '5.0',
#   '35064'],
#  ['2596',
#   '20658',
#   '7 Seas Brewery and Taproom',
#   '1258086587',
#   '5.0',
#   '3.5',
#   '4.0',
#   'jdavin',
#   'American Double / Imperial IPA',
#   '4.0',
#   '4.5',
#   'Ballz Deep Double IPA',
#   '8.4',
#   '53679'],
#  ['2637',
#   '15636',
#   'Calapooia Brewing Company',
#   '1199574009',
#   '5.0',
#   '5.0',
#   '4.0',
#   'BigJTrucker',
#   'Extra Special / Strong Bitter (ESB)',
#   '4.0',
#   '4.0',
#   'BourbonDog ESB',
#   '5.5',
#   '40448'],
#  ['2645',
#   '15636',
#   'Calapooia Brewing Company',
#   '1174772712',
#   '5.0',
#   '5.0',
#   '4.5',
#   'RedDiamond',
#   'American Barleywine',
#   '4.5',
#   '5.0',
#   'Calapooia Barleywine',
#   '11.0',
#   '36039'],
#  ['2675',
#   '2055',
#   'Bernard Family Brewery',
#   '1292701374',
#   '5.0',
#   '4.0',
#   '3.5',
#   'bark',
#   'Czech Pilsener',
#   '4.5',
#   '4.5',
#   'Bernard Light 10° - Bernard Sv&#283;tlé Pivo 10°',
#   '3.8',
#   '64262'],
#  ['2683',
#   '2055',
#   'Bernard Family Brewery',
#   '1232509591',
#   '5.0',
#   '3.0',
#   '3.0',
#   'junjun',
#   'Czech Pilsener',
#   '3.0',
#   '3.0',
#   'Bernard Svetly Lezak',
#   '4.7',
#   '19309'],
#  ['2686',
#   '2055',
#   'Bernard Family Brewery',
#   '1212117286',
#   '5.0',
#   '3.0',
#   '2.5',
#   'scruffwhor',
#   'Czech Pilsener',
#   '4.0',
#   '4.0',
#   'Bernard Svetly Lezak',
#   '4.7',
#   '19309'],
#  ['2725',
#   '2055',
#   'Bernard Family Brewery',
#   '1175954045',
#   '5.0',
#   '4.0',
#   '4.5',
#   'CzechThisOut',
#   'Euro Dark Lager',
#   '4.5',
#   '5.0',
#   'Bernard Cerne',
#   '5.0',
#   '21521'],
#  ['2739',
#   '2055',
#   'Bernard Family Brewery',
#   '1148215169',
#   '5.0',
#   '3.5',
#   '4.0',
#   'RedRocker5152',
#   'Czech Pilsener',
#   '4.0',
#   '4.0',
#   'Bernard Sváte&#269;ní Le\x9eák',
#   '5.0',
#   '13583'],
#  ['2877',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1266860528',
#   '5.0',
#   '4.5',
#   '4.5',
#   'FromTheRoad',
#   'American Double / Imperial IPA',
#   '4.0',
#   '4.5',
#   'Hop Dam Triple IPA',
#   '10.0',
#   '56115'],
#  ['2878',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1266248283',
#   '5.0',
#   '5.0',
#   '5.0',
#   'BeerVikingSailor',
#   'American Double / Imperial IPA',
#   '5.0',
#   '5.0',
#   'Hop Dam Triple IPA',
#   '10.0',
#   '56115'],
#  ['2900',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1310778336',
#   '5.0',
#   '5.0',
#   '4.5',
#   'KansasBeerLover',
#   'American Double / Imperial IPA',
#   '4.5',
#   '5.0',
#   'Hop Dam Triple IPA',
#   '10.0',
#   '56115'],
#  ['2967',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1269387317',
#   '5.0',
#   '4.5',
#   '4.5',
#   'alkemy',
#   'American Double / Imperial IPA',
#   '5.0',
#   '5.0',
#   'Hop Dam Triple IPA',
#   '10.0',
#   '56115'],
#  ['3032',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1193359842',
#   '5.0',
#   '4.0',
#   '3.5',
#   'Vancer',
#   'Hefeweizen',
#   '4.5',
#   '4.5',
#   'Wild Frog Wheat Ale',
#   '6.0',
#   '36862'],
#  ['3039',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1188508390',
#   '5.0',
#   '5.0',
#   '4.0',
#   'Grundle20',
#   'Hefeweizen',
#   '4.0',
#   '4.0',
#   'Wild Frog Wheat Ale',
#   '6.0',
#   '36862'],
#  ['3068',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1261935000',
#   '5.0',
#   '4.0',
#   '4.0',
#   'dsw4b',
#   'American Double / Imperial IPA',
#   '4.5',
#   '5.0',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3085',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1254075549',
#   '5.0',
#   '5.0',
#   '4.5',
#   'bark',
#   'American Double / Imperial IPA',
#   '4.0',
#   '5.0',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3146',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1228122188',
#   '5.0',
#   '5.0',
#   '5.0',
#   'corby112',
#   'American Double / Imperial IPA',
#   '5.0',
#   '5.0',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3154',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1322189916',
#   '5.0',
#   '4.5',
#   '4.0',
#   'RoyalT',
#   'American Double / Imperial IPA',
#   '5.0',
#   '5.0',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3226',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1208467384',
#   '5.0',
#   '4.5',
#   '4.0',
#   'dholway',
#   'American Double / Imperial IPA',
#   '4.5',
#   '5.0',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3275',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1199565403',
#   '5.0',
#   '4.0',
#   '4.5',
#   'Vancer',
#   'American Double / Imperial IPA',
#   '4.5',
#   '4.5',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3281',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1198560469',
#   '5.0',
#   '5.0',
#   '5.0',
#   'DevilDogBeer',
#   'American Double / Imperial IPA',
#   '5.0',
#   '5.0',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3284',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1197855856',
#   '5.0',
#   '4.5',
#   '5.0',
#   'pwoods',
#   'American Double / Imperial IPA',
#   '4.5',
#   '5.0',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3287',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1197087258',
#   '5.0',
#   '5.0',
#   '4.5',
#   'BeerZack',
#   'American Double / Imperial IPA',
#   '5.0',
#   '4.5',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3332',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1299994857',
#   '5.0',
#   '4.0',
#   '4.5',
#   'AleWatcher',
#   'American Double / Imperial IPA',
#   '4.5',
#   '4.0',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3373',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1273443997',
#   '5.0',
#   '5.0',
#   '5.0',
#   'Cyberkedi',
#   'American Double / Imperial IPA',
#   '5.0',
#   '4.5',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3380',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1271556275',
#   '5.0',
#   '5.0',
#   '4.0',
#   'sudz9382',
#   'American Double / Imperial IPA',
#   '4.5',
#   '5.0',
#   'Mean Manalishi Double I.P.A.',
#   '8.2',
#   '37518'],
#  ['3385',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1325561290',
#   '5.0',
#   '4.5',
#   '4.0',
#   'Pahn',
#   'English Barleywine',
#   '5.0',
#   '5.0',
#   'Barrel Aged Naked Evil',
#   '11.3',
#   '72827'],
#  ['3389',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1324264565',
#   '5.0',
#   '5.0',
#   '5.0',
#   'scottyg354',
#   'English Barleywine',
#   '4.5',
#   '5.0',
#   'Barrel Aged Naked Evil',
#   '11.3',
#   '72827'],
#  ['3392',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1323497785',
#   '5.0',
#   '5.0',
#   '4.5',
#   'mikesgroove',
#   'English Barleywine',
#   '4.5',
#   '5.0',
#   'Barrel Aged Naked Evil',
#   '11.3',
#   '72827'],
#  ['3414',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1319633462',
#   '5.0',
#   '4.5',
#   '5.0',
#   'Brew33',
#   'English Barleywine',
#   '5.0',
#   '5.0',
#   'Barrel Aged Naked Evil',
#   '11.3',
#   '72827'],
#  ['3424',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1318181561',
#   '5.0',
#   '5.0',
#   '4.0',
#   'ktrillionaire',
#   'English Barleywine',
#   '4.0',
#   '5.0',
#   'Barrel Aged Naked Evil',
#   '11.3',
#   '72827'],
#  ['3472',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1218411539',
#   '5.0',
#   '4.0',
#   '4.0',
#   'GoodKnight1220',
#   'Fruit / Vegetable Beer',
#   '3.5',
#   '4.0',
#   'Smashing Berry Ale',
#   '4.3',
#   '38982'],
#  ['3497',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1298667835',
#   '5.0',
#   '3.5',
#   '5.0',
#   'Jesse13713',
#   'American Pale Ale (APA)',
#   '4.5',
#   '4.5',
#   'Fresh Frog Raw Hop Imperial Pale Ale',
#   '7.8',
#   '53779'],
#  ['3554',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1300067030',
#   '5.0',
#   '4.5',
#   '5.0',
#   'rivalrome',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3581',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1240232743',
#   '5.0',
#   '3.5',
#   '4.5',
#   'imaguitargod',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '4.5',
#   'Outta Kilter',
#   '8.2',
#   '47694'],
#  ['3587',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1289797722',
#   '5.0',
#   '4.0',
#   '5.0',
#   'BigB415',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3602',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1285465261',
#   '5.0',
#   '4.0',
#   '5.0',
#   'AleWatcher',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3641',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1277432427',
#   '5.0',
#   '4.5',
#   '4.5',
#   'connecticutpoet',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3648',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1275630664',
#   '5.0',
#   '4.0',
#   '5.0',
#   'beerhan',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3665',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1324265105',
#   '5.0',
#   '5.0',
#   '5.0',
#   'scottyg354',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3678',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1273004308',
#   '5.0',
#   '5.0',
#   '5.0',
#   'bert13tj',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3685',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1272259563',
#   '5.0',
#   '5.0',
#   '5.0',
#   'brewdlyhooked13',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3698',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1271176726',
#   '5.0',
#   '4.5',
#   '4.5',
#   'phiberoptik',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3713',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1269650999',
#   '5.0',
#   '5.0',
#   '5.0',
#   'imaguitargod',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3717',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1322700014',
#   '5.0',
#   '5.0',
#   '5.0',
#   'SawDog505',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3740',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1313896188',
#   '5.0',
#   '4.5',
#   '4.5',
#   'JayS2629',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3744',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1312840164',
#   '5.0',
#   '4.0',
#   '5.0',
#   'biegaman',
#   'Russian Imperial Stout',
#   '4.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3756',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1307149317',
#   '5.0',
#   '5.0',
#   '5.0',
#   'DangerDawg',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3790',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1300593151',
#   '5.0',
#   '4.5',
#   '5.0',
#   'Cyberkedi',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'D.O.R.I.S. The Destroyer Double Imperial Stout',
#   '10.5',
#   '57110'],
#  ['3836',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1277788587',
#   '5.0',
#   '4.0',
#   '3.0',
#   'paco1029384756',
#   'Fruit / Vegetable Beer',
#   '3.0',
#   '3.5',
#   'Turbo Shandy',
#   '7.0',
#   '59548'],
#  ['3842',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1250918095',
#   '5.0',
#   '4.5',
#   '5.0',
#   'corby112',
#   'American IPA',
#   '4.0',
#   '4.5',
#   "Hoppin' To Heaven IPA",
#   '6.8',
#   '33624'],
#  ['3863',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1234144447',
#   '5.0',
#   '4.5',
#   '5.0',
#   'scruffwhor',
#   'American IPA',
#   '5.0',
#   '4.0',
#   "Hoppin' To Heaven IPA",
#   '6.8',
#   '33624'],
#  ['3906',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1199219998',
#   '5.0',
#   '4.0',
#   '4.0',
#   'ppoitras',
#   'American IPA',
#   '4.5',
#   '4.0',
#   "Hoppin' To Heaven IPA",
#   '6.8',
#   '33624'],
#  ['3925',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1182795075',
#   '5.0',
#   '4.5',
#   '4.0',
#   'brewdlyhooked13',
#   'American IPA',
#   '3.5',
#   '4.5',
#   "Hoppin' To Heaven IPA",
#   '6.8',
#   '33624'],
#  ['3962',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1166302950',
#   '5.0',
#   '4.5',
#   '4.5',
#   'WestsideSteve',
#   'American IPA',
#   '4.5',
#   '4.5',
#   "Hoppin' To Heaven IPA",
#   '6.8',
#   '33624'],
#  ['3963',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1163980263',
#   '5.0',
#   '4.0',
#   '4.0',
#   'chipsbr',
#   'American IPA',
#   '4.5',
#   '4.5',
#   "Hoppin' To Heaven IPA",
#   '6.8',
#   '33624'],
#  ['3984',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1295007283',
#   '5.0',
#   '4.0',
#   '4.0',
#   'mdagnew',
#   'American IPA',
#   '4.0',
#   '4.0',
#   "Hoppin' To Heaven IPA",
#   '6.8',
#   '33624'],
#  ['3990',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1289600465',
#   '5.0',
#   '4.5',
#   '4.5',
#   'polio',
#   'American IPA',
#   '5.0',
#   '5.0',
#   "Hoppin' To Heaven IPA",
#   '6.8',
#   '33624'],
#  ['4005',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1276438375',
#   '5.0',
#   '5.0',
#   '4.0',
#   'Norfawkers',
#   'American IPA',
#   '5.0',
#   '5.0',
#   "Hoppin' To Heaven IPA",
#   '6.8',
#   '33624'],
#  ['4106',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1250994456',
#   '5.0',
#   '4.5',
#   '5.0',
#   'JamnesCameron',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Outta Kilter',
#   '8.2',
#   '47694'],
#  ['4136',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1289100257',
#   '5.0',
#   '4.5',
#   '3.0',
#   'fo5s',
#   'Pumpkin Ale',
#   '3.5',
#   '4.5',
#   "Frog's Hollow Double Pumpkin Ale",
#   '8.4',
#   '52211'],
#  ['4149',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1286909414',
#   '5.0',
#   '3.0',
#   '4.0',
#   'beerhan',
#   'Pumpkin Ale',
#   '4.0',
#   '4.5',
#   "Frog's Hollow Double Pumpkin Ale",
#   '8.4',
#   '52211'],
#  ['4249',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1320534364',
#   '5.0',
#   '4.5',
#   '4.0',
#   'AleWatcher',
#   'Pumpkin Ale',
#   '4.0',
#   '4.0',
#   "Frog's Hollow Double Pumpkin Ale",
#   '8.4',
#   '52211'],
#  ['4315',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1261713353',
#   '5.0',
#   '4.5',
#   '4.0',
#   'brewdlyhooked13',
#   'Winter Warmer',
#   '4.5',
#   '4.5',
#   'Frosted Frog Christmas Ale',
#   '8.6',
#   '54134'],
#  ['4320',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1310341777',
#   '5.0',
#   '5.0',
#   '4.5',
#   'RedSpecial1',
#   'Pumpkin Ale',
#   '5.0',
#   '5.0',
#   "Frog's Hollow Double Pumpkin Ale",
#   '8.4',
#   '52211'],
#  ['4337',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1259156365',
#   '5.0',
#   '5.0',
#   '4.5',
#   'BeerVikingSailor',
#   'Winter Warmer',
#   '4.5',
#   '4.5',
#   'Frosted Frog Christmas Ale',
#   '8.6',
#   '54134'],
#  ['4367',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1320373948',
#   '5.0',
#   '4.5',
#   '4.5',
#   'Jesse13713',
#   'Winter Warmer',
#   '4.0',
#   '4.5',
#   'Frosted Frog Christmas Ale',
#   '8.6',
#   '54134'],
#  ['4457',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1311299740',
#   '5.0',
#   '4.5',
#   '4.5',
#   'mikesgroove',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'BORIS Royale',
#   '9.4',
#   '69461'],
#  ['4470',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1307330068',
#   '5.0',
#   '4.0',
#   '5.0',
#   'Preismj',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'BORIS Royale',
#   '9.4',
#   '69461'],
#  ['4473',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1307075121',
#   '5.0',
#   '4.5',
#   '4.0',
#   'MbpBugeye',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.0',
#   'BORIS Royale',
#   '9.4',
#   '69461'],
#  ['4494',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1303177194',
#   '5.0',
#   '5.0',
#   '4.5',
#   'brewdlyhooked13',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4543',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1290950869',
#   '5.0',
#   '4.5',
#   '4.0',
#   'junjun',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4545',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1290920543',
#   '5.0',
#   '4.5',
#   '4.5',
#   'levifunk',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4551',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1289532949',
#   '5.0',
#   '5.0',
#   '4.0',
#   'DavoleBomb',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4562',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1287963052',
#   '5.0',
#   '5.0',
#   '5.0',
#   'badworthing',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4588',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1280627055',
#   '5.0',
#   '4.0',
#   '3.5',
#   'billab914',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4640',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1266953490',
#   '5.0',
#   '4.5',
#   '4.0',
#   'SaCkErZ9',
#   'Russian Imperial Stout',
#   '4.0',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4662',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1262838181',
#   '5.0',
#   '4.0',
#   '4.0',
#   'Jmoore50',
#   'Russian Imperial Stout',
#   '4.0',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4670',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1262052047',
#   '5.0',
#   '4.5',
#   '4.5',
#   'Beejay',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4674',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1261761966',
#   '5.0',
#   '3.5',
#   '4.0',
#   'strictly4DK',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4676',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1261543282',
#   '5.0',
#   '5.0',
#   '4.0',
#   'mwa423',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4677',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1249873949',
#   '5.0',
#   '5.0',
#   '4.5',
#   'rye726',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4687',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1260149714',
#   '5.0',
#   '4.5',
#   '4.0',
#   'GbVDave',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4713',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1257482733',
#   '5.0',
#   '4.0',
#   '4.0',
#   'OlieIPA',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4719',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1255659648',
#   '5.0',
#   '4.0',
#   '4.5',
#   'TheKingsOfHop',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4729',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1253593090',
#   '5.0',
#   '4.5',
#   '3.0',
#   'russpowell',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4734',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1251856292',
#   '5.0',
#   '4.0',
#   '4.0',
#   'bruachan',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4760',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1248750109',
#   '5.0',
#   '4.5',
#   '4.5',
#   'Jcb890',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4763',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1248620079',
#   '5.0',
#   '4.5',
#   '4.0',
#   'mikesgroove',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4765',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1248605903',
#   '5.0',
#   '4.5',
#   '4.0',
#   'Overlord',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4767',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1248570526',
#   '5.0',
#   '4.0',
#   '4.5',
#   'infestaxion',
#   'Russian Imperial Stout',
#   '4.0',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4788',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1242720670',
#   '5.0',
#   '4.5',
#   '4.0',
#   'nrbw23',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4796',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1240031990',
#   '5.0',
#   '5.0',
#   '4.5',
#   'raninator84',
#   'Russian Imperial Stout',
#   '4.0',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4797',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1240009480',
#   '5.0',
#   '4.5',
#   '4.0',
#   'bluejacket74',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4798',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1239923813',
#   '5.0',
#   '4.0',
#   '4.0',
#   'drgonzo3705',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4813',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1239021600',
#   '5.0',
#   '4.0',
#   '5.0',
#   'jampics2',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4814',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1317236245',
#   '5.0',
#   '5.0',
#   '4.5',
#   'ubufan2112',
#   'Russian Imperial Stout',
#   '4.0',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4838',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1314228762',
#   '5.0',
#   '4.5',
#   '4.0',
#   'lackenhauser',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4867',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1306982551',
#   '5.0',
#   '4.5',
#   '4.5',
#   'aasher',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Barrel Aged B.O.R.I.S. Oatmeal Imperial Stout',
#   '9.4',
#   '47695'],
#  ['4958',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1301277305',
#   '5.0',
#   '4.5',
#   '4.5',
#   'PorterLambic',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['4972',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1298903369',
#   '5.0',
#   '4.0',
#   '4.5',
#   'bucklemyshoe',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['4985',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1296783775',
#   '5.0',
#   '5.0',
#   '4.5',
#   'Avagadro',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['4992',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1295492970',
#   '5.0',
#   '4.0',
#   '4.0',
#   'Gunslinger711',
#   'Russian Imperial Stout',
#   '4.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['4995',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1295280927',
#   '5.0',
#   '4.5',
#   '4.0',
#   'thagr81us',
#   'Russian Imperial Stout',
#   '4.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5027',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1325774367',
#   '5.0',
#   '3.5',
#   '4.5',
#   'deadonhisfeet',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5044',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1287467200',
#   '5.0',
#   '4.5',
#   '4.0',
#   'dragonWhale',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5045',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1287344561',
#   '5.0',
#   '4.5',
#   '4.0',
#   'junjun',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5046',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1287020425',
#   '5.0',
#   '5.0',
#   '5.0',
#   'nismo80',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5059',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1285619214',
#   '5.0',
#   '4.5',
#   '4.0',
#   'bigfnjoe',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5081',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1281751893',
#   '5.0',
#   '4.0',
#   '3.5',
#   'BrewCrew2010',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5092',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1278994844',
#   '5.0',
#   '5.0',
#   '3.5',
#   'popery',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5094',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1278558360',
#   '5.0',
#   '4.0',
#   '4.0',
#   'abecall98',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5099',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1277473674',
#   '5.0',
#   '4.5',
#   '4.0',
#   'avalon07',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5116',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1273793566',
#   '5.0',
#   '4.5',
#   '5.0',
#   'Cyberkedi',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5134',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1324342834',
#   '5.0',
#   '4.5',
#   '5.0',
#   'scottyg354',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5155',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1268960257',
#   '5.0',
#   '4.5',
#   '4.5',
#   'dougofthefuture',
#   'Russian Imperial Stout',
#   '4.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5161',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1267937129',
#   '5.0',
#   '4.5',
#   '5.0',
#   'ikenney87',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5178',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1265663194',
#   '5.0',
#   '4.5',
#   '4.5',
#   'mgbickel',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5189',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1263955309',
#   '5.0',
#   '5.0',
#   '4.5',
#   'bonsreeb85',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5200',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1262145507',
#   '5.0',
#   '4.0',
#   '5.0',
#   'manahansf',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5202',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1262107990',
#   '5.0',
#   '5.0',
#   '4.5',
#   'backfat',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5204',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1261934525',
#   '5.0',
#   '4.5',
#   '4.5',
#   'redsonja',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5216',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1259899693',
#   '5.0',
#   '5.0',
#   '4.0',
#   'vacax',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5259',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1253250234',
#   '5.0',
#   '4.5',
#   '4.0',
#   'DavoleBomb',
#   'Russian Imperial Stout',
#   '4.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5269',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1251849361',
#   '5.0',
#   '5.0',
#   '4.5',
#   'JamnesCameron',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5270',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1251619250',
#   '5.0',
#   '4.0',
#   '4.5',
#   'rajendra82',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5311',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1242780686',
#   '5.0',
#   '4.5',
#   '4.5',
#   'Birdiebeagle',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5315',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1241815137',
#   '5.0',
#   '4.5',
#   '4.5',
#   'easement',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5316',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1241663484',
#   '5.0',
#   '3.5',
#   '4.0',
#   'younger35',
#   'Russian Imperial Stout',
#   '3.5',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5318',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1241375276',
#   '5.0',
#   '3.5',
#   '3.5',
#   'tigg924',
#   'Russian Imperial Stout',
#   '4.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5340',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1238434345',
#   '5.0',
#   '4.5',
#   '4.0',
#   'br3wmeister',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5347',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1238040689',
#   '5.0',
#   '4.5',
#   '3.5',
#   'everetends',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5384',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1234839471',
#   '5.0',
#   '4.5',
#   '4.0',
#   'biegaman',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5385',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1234838933',
#   '5.0',
#   '4.5',
#   '4.5',
#   'ThatWineGuy',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5394',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1232611685',
#   '5.0',
#   '4.5',
#   '5.0',
#   'MCfunkyJ',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5400',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1231530768',
#   '5.0',
#   '4.0',
#   '4.0',
#   'bigfoot13',
#   'Russian Imperial Stout',
#   '4.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5409',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1229360069',
#   '5.0',
#   '4.5',
#   '4.5',
#   'stumac',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5423',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1227890341',
#   '5.0',
#   '5.0',
#   '5.0',
#   'TommyBuckeye',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5431',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1227144594',
#   '5.0',
#   '4.5',
#   '5.0',
#   'Marcus6679',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5446',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1225854306',
#   '5.0',
#   '4.5',
#   '4.5',
#   'beachbum1975',
#   'Russian Imperial Stout',
#   '4.0',
#   '4.5',
#   'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout',
#   '9.4',
#   '33644'],
#  ['5453',
#   '14879',
#   "Hoppin' Frog Brewery",
#   '1225307109',
#   '5.0',
#   '4.0',
#   '3.5',
#   'ThreeWiseMen',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
# ...
#   '10.2',
#   '35036'],
#  ['18776',
#   '1199',
#   'Founders Brewing Company',
#   '1295784644',
#   '5.0',
#   '4.5',
#   '4.0',
#   'JizackFH',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18788',
#   '1199',
#   'Founders Brewing Company',
#   '1294803306',
#   '5.0',
#   '4.5',
#   '4.5',
#   'ekardz',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18820',
#   '1199',
#   'Founders Brewing Company',
#   '1292303321',
#   '5.0',
#   '3.5',
#   '3.0',
#   'stawn',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18826',
#   '1199',
#   'Founders Brewing Company',
#   '1292086612',
#   '5.0',
#   '5.0',
#   '5.0',
#   'AScribjr',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18839',
#   '1199',
#   'Founders Brewing Company',
#   '1291165416',
#   '5.0',
#   '4.0',
#   '4.0',
#   'BruceWineworks',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18840',
#   '1199',
#   'Founders Brewing Company',
#   '1291493362',
#   '5.0',
#   '4.5',
#   '4.5',
#   'smakawhat',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18841',
#   '1199',
#   'Founders Brewing Company',
#   '1291439801',
#   '5.0',
#   '4.5',
#   '4.0',
#   'cosmicevan',
#   'Scotch Ale / Wee Heavy',
#   '4.0',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18879',
#   '1199',
#   'Founders Brewing Company',
#   '1290552643',
#   '5.0',
#   '4.5',
#   '5.0',
#   'mynie',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18890',
#   '1199',
#   'Founders Brewing Company',
#   '1290208485',
#   '5.0',
#   '5.0',
#   '5.0',
#   'donniecuffs',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18894',
#   '1199',
#   'Founders Brewing Company',
#   '1290046977',
#   '5.0',
#   '4.0',
#   '4.0',
#   'Mitchster',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18928',
#   '1199',
#   'Founders Brewing Company',
#   '1287451731',
#   '5.0',
#   '4.5',
#   '4.0',
#   'jpmclaug',
#   'Scotch Ale / Wee Heavy',
#   '4.0',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18949',
#   '1199',
#   'Founders Brewing Company',
#   '1276639061',
#   '5.0',
#   '5.0',
#   '3.5',
#   'ktrillionaire',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18970',
#   '1199',
#   'Founders Brewing Company',
#   '1271616980',
#   '5.0',
#   '4.5',
#   '4.0',
#   'Arenbeer',
#   'Scotch Ale / Wee Heavy',
#   '4.0',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['18995',
#   '1199',
#   'Founders Brewing Company',
#   '1269222612',
#   '5.0',
#   '4.0',
#   '4.0',
#   'cbutova',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19014',
#   '1199',
#   'Founders Brewing Company',
#   '1267020478',
#   '5.0',
#   '4.0',
#   '4.0',
#   'Mavajo',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19026',
#   '1199',
#   'Founders Brewing Company',
#   '1264903128',
#   '5.0',
#   '4.5',
#   '4.5',
#   'sulldaddy',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19037',
#   '1199',
#   'Founders Brewing Company',
#   '1264027696',
#   '5.0',
#   '5.0',
#   '4.0',
#   'becktone',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19101',
#   '1199',
#   'Founders Brewing Company',
#   '1261119065',
#   '5.0',
#   '4.5',
#   '4.0',
#   'machostacos',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19105',
#   '1199',
#   'Founders Brewing Company',
#   '1261014585',
#   '5.0',
#   '3.5',
#   '4.0',
#   'techfed87',
#   'Scotch Ale / Wee Heavy',
#   '4.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19129',
#   '1199',
#   'Founders Brewing Company',
#   '1260242946',
#   '5.0',
#   '5.0',
#   '4.5',
#   'mbudner',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19141',
#   '1199',
#   'Founders Brewing Company',
#   '1258596616',
#   '5.0',
#   '4.0',
#   '4.5',
#   'danielharper',
#   'Scotch Ale / Wee Heavy',
#   '4.0',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19172',
#   '1199',
#   'Founders Brewing Company',
#   '1258692625',
#   '5.0',
#   '5.0',
#   '5.0',
#   'Frosty80',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19188',
#   '1199',
#   'Founders Brewing Company',
#   '1258084644',
#   '5.0',
#   '4.5',
#   '4.0',
#   'homebrew311',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19191',
#   '1199',
#   'Founders Brewing Company',
#   '1258045467',
#   '5.0',
#   '5.0',
#   '3.0',
#   'Katahdin',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19229',
#   '1199',
#   'Founders Brewing Company',
#   '1248494723',
#   '5.0',
#   '4.5',
#   '3.5',
#   'rawrgasaurus',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19309',
#   '1199',
#   'Founders Brewing Company',
#   '1233805763',
#   '5.0',
#   '4.5',
#   '4.5',
#   'cvfish',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19317',
#   '1199',
#   'Founders Brewing Company',
#   '1321493311',
#   '5.0',
#   '5.0',
#   '4.5',
#   'angelogarcia3',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19322',
#   '1199',
#   'Founders Brewing Company',
#   '1233369600',
#   '5.0',
#   '4.0',
#   '4.0',
#   'Avagadro',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19357',
#   '1199',
#   'Founders Brewing Company',
#   '1230410094',
#   '5.0',
#   '4.0',
#   '4.0',
#   'Slatetank',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19372',
#   '1199',
#   'Founders Brewing Company',
#   '1229022688',
#   '5.0',
#   '5.0',
#   '4.5',
#   'Sycodrummer',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19380',
#   '1199',
#   'Founders Brewing Company',
#   '1228707959',
#   '5.0',
#   '5.0',
#   '4.0',
#   'yourefragile',
#   'Scotch Ale / Wee Heavy',
#   '4.0',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19409',
#   '1199',
#   'Founders Brewing Company',
#   '1227563911',
#   '5.0',
#   '4.5',
#   '4.0',
#   'brewdlyhooked13',
#   'Scotch Ale / Wee Heavy',
#   '4.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19429',
#   '1199',
#   'Founders Brewing Company',
#   '1320994811',
#   '5.0',
#   '4.5',
#   '4.0',
#   'sdmvd6',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19433',
#   '1199',
#   'Founders Brewing Company',
#   '1226727115',
#   '5.0',
#   '5.0',
#   '4.5',
#   'seitzka',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19458',
#   '1199',
#   'Founders Brewing Company',
#   '1224895308',
#   '5.0',
#   '5.0',
#   '4.5',
#   'inhoc00',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19469',
#   '1199',
#   'Founders Brewing Company',
#   '1214014689',
#   '5.0',
#   '5.0',
#   '4.0',
#   'amiles',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19480',
#   '1199',
#   'Founders Brewing Company',
#   '1208488674',
#   '5.0',
#   '4.0',
#   '4.5',
#   'mrkrispy',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19487',
#   '1199',
#   'Founders Brewing Company',
#   '1206858833',
#   '5.0',
#   '4.0',
#   '4.5',
#   'BlindPig',
#   'Scotch Ale / Wee Heavy',
#   '5.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19509',
#   '1199',
#   'Founders Brewing Company',
#   '1199761259',
#   '5.0',
#   '4.5',
#   '4.0',
#   'MDekker',
#   'Scotch Ale / Wee Heavy',
#   '4.0',
#   '4.5',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19513',
#   '1199',
#   'Founders Brewing Company',
#   '1198112949',
#   '5.0',
#   '4.5',
#   '4.5',
#   'Blakaeris',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19516',
#   '1199',
#   'Founders Brewing Company',
#   '1198035060',
#   '5.0',
#   '4.0',
#   '3.5',
#   'bashiba',
#   'Scotch Ale / Wee Heavy',
#   '4.5',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19538',
#   '1199',
#   'Founders Brewing Company',
#   '1320804012',
#   '5.0',
#   '5.0',
#   '4.0',
#   'jmich24',
#   'Scotch Ale / Wee Heavy',
#   '4.0',
#   '5.0',
#   'Founders Backwoods Bastard',
#   '10.2',
#   '35036'],
#  ['19544',
#   '1199',
#   'Founders Brewing Company',
#   '1261033407',
#   '5.0',
#   '3.5',
#   '3.0',
#   'machostacos',
#   'American Pale Lager',
#   '3.0',
#   '4.0',
#   'Founders Super Gold',
#   '5.4',
#   '53497'],
#  ['19560',
#   '1199',
#   'Founders Brewing Company',
#   '1293938713',
#   '5.0',
#   '5.0',
#   '4.5',
#   'Thorpe429',
#   'American Stout',
#   '4.5',
#   '4.5',
#   'Founders Frangelic Stout',
#   '4.2',
#   '21753'],
#  ['19562',
#   '1199',
#   'Founders Brewing Company',
#   '1289964141',
#   '5.0',
#   '5.0',
#   '4.5',
#   'hophunter',
#   'American Stout',
#   '4.5',
#   '5.0',
#   'Founders Frangelic Stout',
#   '4.2',
#   '21753'],
#  ['19574',
#   '1199',
#   'Founders Brewing Company',
#   '1262571380',
#   '5.0',
#   '5.0',
#   '4.5',
#   'eddocron',
#   'American Double / Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Breakfast Stout',
#   '8.3',
#   '11757'],
#  ['19575',
#   '1199',
#   'Founders Brewing Company',
#   '1112554234',
#   '5.0',
#   '3.0',
#   '4.5',
#   'TikkiGodxxx',
#   'American Stout',
#   '5.0',
#   '5.0',
#   'Founders Frangelic Stout',
#   '4.2',
#   '21753'],
#  ['19592',
#   '1199',
#   'Founders Brewing Company',
#   '1212111767',
#   '5.0',
#   '4.5',
#   '4.5',
#   'GbVDave',
#   'American Pale Wheat Ale',
#   '4.5',
#   '4.5',
#   'Founders Dumbo Head Wheat Beer',
#   '6.0',
#   '42939'],
#  ['19594',
#   '1199',
#   'Founders Brewing Company',
#   '1126315990',
#   '5.0',
#   '4.0',
#   '4.5',
#   'KarlHungus',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19613',
#   '1199',
#   'Founders Brewing Company',
#   '1118549427',
#   '5.0',
#   '4.5',
#   '4.5',
#   'mentor',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19631',
#   '1199',
#   'Founders Brewing Company',
#   '1114192667',
#   '5.0',
#   '5.0',
#   '4.0',
#   'jasonpeckins32',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19665',
#   '1199',
#   'Founders Brewing Company',
#   '1067752081',
#   '5.0',
#   '3.5',
#   '4.0',
#   'Ellbert',
#   'Russian Imperial Stout',
#   '4.5',
#   '3.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19680',
#   '1199',
#   'Founders Brewing Company',
#   '1311738717',
#   '5.0',
#   '4.0',
#   '4.5',
#   'AleWatcher',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19688',
#   '1199',
#   'Founders Brewing Company',
#   '1309223466',
#   '5.0',
#   '5.0',
#   '5.0',
#   'Armand',
#   'Russian Imperial Stout',
#   '4.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19699',
#   '1199',
#   'Founders Brewing Company',
#   '1307073845',
#   '5.0',
#   '4.5',
#   '5.0',
#   'sendsilk',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19718',
#   '1199',
#   'Founders Brewing Company',
#   '1304566366',
#   '5.0',
#   '4.5',
#   '3.5',
#   'CHickman',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19719',
#   '1199',
#   'Founders Brewing Company',
#   '1304387601',
#   '5.0',
#   '4.5',
#   '5.0',
#   'phillybeer7779',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19725',
#   '1199',
#   'Founders Brewing Company',
#   '1301196542',
#   '5.0',
#   '4.5',
#   '5.0',
#   'Aircow86',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19746',
#   '1199',
#   'Founders Brewing Company',
#   '1303064092',
#   '5.0',
#   '5.0',
#   '4.0',
#   'brandoncox',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19753',
#   '1199',
#   'Founders Brewing Company',
#   '1302831336',
#   '5.0',
#   '4.5',
#   '4.5',
#   'camp0474',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19760',
#   '1199',
#   'Founders Brewing Company',
#   '1302160235',
#   '5.0',
#   '4.5',
#   '4.0',
#   'MattyG85',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19761',
#   '1199',
#   'Founders Brewing Company',
#   '1302112579',
#   '5.0',
#   '4.5',
#   '4.0',
#   'mechamifune',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19762',
#   '1199',
#   'Founders Brewing Company',
#   '1302035683',
#   '5.0',
#   '4.5',
#   '4.5',
#   'OWSLEY069',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19781',
#   '1199',
#   'Founders Brewing Company',
#   '1301208042',
#   '5.0',
#   '5.0',
#   '5.0',
#   'Snow81',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19789',
#   '1199',
#   'Founders Brewing Company',
#   '1326253848',
#   '5.0',
#   '4.5',
#   '5.0',
#   'EnJeiBee',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19798',
#   '1199',
#   'Founders Brewing Company',
#   '1301021376',
#   '5.0',
#   '5.0',
#   '5.0',
#   'yuenglingfan101',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19800',
#   '1199',
#   'Founders Brewing Company',
#   '1300928248',
#   '5.0',
#   '4.5',
#   '4.0',
#   'Bendurgin',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19802',
#   '1199',
#   'Founders Brewing Company',
#   '1300924764',
#   '5.0',
#   '4.5',
#   '4.5',
#   'dmfrench',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19814',
#   '1199',
#   'Founders Brewing Company',
#   '1300411304',
#   '5.0',
#   '4.5',
#   '5.0',
#   'jayt206',
#   'Russian Imperial Stout',
#   '4.5',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19818',
#   '1199',
#   'Founders Brewing Company',
#   '1300230645',
#   '5.0',
#   '4.5',
#   '4.5',
#   'larryi86',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19825',
#   '1199',
#   'Founders Brewing Company',
#   '1299720884',
#   '5.0',
#   '4.5',
#   '4.5',
#   'JoEBoBpr',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19841',
#   '1199',
#   'Founders Brewing Company',
#   '1299310750',
#   '5.0',
#   '4.0',
#   '4.5',
#   'ChugginOil',
#   'Russian Imperial Stout',
#   '4.5',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19881',
#   '1199',
#   'Founders Brewing Company',
#   '1298658117',
#   '5.0',
#   '3.5',
#   '3.0',
#   'fastsrt',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19896',
#   '1199',
#   'Founders Brewing Company',
#   '1325974732',
#   '5.0',
#   '4.5',
#   '4.5',
#   'brydeen',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19897',
#   '1199',
#   'Founders Brewing Company',
#   '1325964481',
#   '5.0',
#   '4.5',
#   '4.5',
#   'dejrrma',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19904',
#   '1199',
#   'Founders Brewing Company',
#   '1298243956',
#   '5.0',
#   '3.5',
#   '4.5',
#   'TheBungyo',
#   'Russian Imperial Stout',
#   '5.0',
#   '5.0',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ['19918',
#   '1199',
#   'Founders Brewing Company',
#   '1297576146',
#   '5.0',
#   '4.5',
#   '4.5',
#   'ChadQuest',
#   'Russian Imperial Stout',
#   '5.0',
#   '4.5',
#   'Founders Imperial Stout',
#   '10.5',
#   '21822'],
#  ...]

# %%
# STEP 3
start_time3 = time.time()

processed_rdd = split_rdd.map(lambda x: (x[2], (float(x[4]), x[11])))
top_reviews_rdd = processed_rdd.reduceByKey(lambda x,y: x if x[0] > y[0] else y)

end_time3 = time.time()
elapsed_time3 = end_time3 - start_time3
elapsed_times_list.append(elapsed_time3)
print(f"Elapsed time: {elapsed_time3} seconds")

top_reviews_rdd.collect()
# Out:
# Elapsed time: 0.013422489166259766 seconds
# [('Pacific Coast Brewing Company', (4.5, 'Killer Whale Stout')),
#  ('Asmara Breweries', (4.0, 'Asmara Lager Beer')),
#  ('Bernard Family Brewery', (5.0, 'Bernard Sváte&#269;ní Le\x9eák')),
#  ('Otro Mundo Brewing Company', (4.5, 'Otro Mundo Strong Red Ale')),
#  ("Emmett's Brewing Company", (5.0, 'Dopplebock')),
#  ('Becker Brewing Company', (4.0, 'Rooster Red')),
#  ('Birrificio Indipendente Elav', (3.5, 'Raggea Stout')),
#  ('Stakhanovitz', (4.5, 'Bogemia')),
#  ('Richmodis-Bräu', (4.0, 'Richmodis Koelsch')),
#  ('Privatbrauerei Hösl', (4.5, 'Helles Weissbier Resi')),
#  ('Spanish Springs Brewing Company', (5.0, 'Spanish Springs Porter')),
#  ('Archers Brewing & Wholesale Limited', (4.0, 'Village Bitter')),
#  ('Lido Atputas Centrs', (4.0, 'LIDO Speci&#257;lais')),
#  ('Sternquell Brauerei Plauen', (4.0, 'Sternquell Bockbier')),
#  ('Cerveceros Krut S.L.', (4.0, 'Krut Gold')),
#  ('Riverside Brewing Company', (3.5, 'Riverside Curleys Irish Style Stout')),
#  ('Speciaalbierbrouwerij Oijen', (4.0, 'Eikelbier')),
#  ('Benny Brewing Company', (5.0, 'Benny Brew Hopenstein')),
#  ('Ancient Lakes Brewing Company', (3.5, 'I-90 IPA')),
#  ('Klosterbrauerei Weltenburg', (5.0, 'Weltenburger Kloster Barock-Hell')),
#  ('Mountaineer Brewing Co.', (5.0, 'Old Snowshoe Winter Ale')),
#  ('Island Cafe & Brew Pub', (3.0, 'Anglers Ale')),
#  ("Gentle Ben's Brewing Company", (5.0, 'Chelsea India Pale Ale')),
#  ('Ufford Ales Ltd.', (3.0, 'New Model Ale')),
#  ('Streets Of New York / Uptown Brewery', (4.5, 'Bavarian Hefe-Weizen')),
#  ('Harar Beer Factory', (5.0, 'Hakim Stout')),
#  ('Mornington Peninsula Brewery', (4.5, 'Mornington Peninsula Witbier')),
#  ('Outer Banks Brewing Station', (5.0, 'Hopsnort Golden Pale Ale')),
#  ('Tenaya Creek Brewery', (5.0, 'Tenaya Creek Pilsner')),
#  ('W.H. Brakspear & Sons plc', (5.0, 'Vintage Henley')),
#  ('St. Peters Brewery (Australia)', (4.0, 'Cinnamon Girl')),
#  ('Kölner Verbund Brauereien GmbH & Co. KG', (3.0, "Kupper's")),
#  ('Allendale Brew Company Limited', (3.5, 'Allendale Black Grouse Bitter')),
#  ('Three Heads Brewing', (5.0, 'Skunk Black IPA')),
#  ('Brauerei Georg Michael GmbH', (4.0, 'Luchs Bier Dinkel')),
#  ('Odd Side Ales', (4.5, 'Dark Roast')),
#  ('Blue Tractor BBQ & Brewery', (4.0, 'Funkel Dunkel')),
#  ('Mallard Brewery', (4.0, 'Duck & Disorderly')),
#  ("Mike's Organic Brewery", (4.0, "Mike's Imperial Porter")),
#  ('Coopers Brewery Limited', (5.0, 'Coopers Best Extra Stout')),
#  ('Brouwerij Strubbe', (5.0, "Ichtegem's Grand Cru")),
#  ('Red Oak Brewery', (5.0, 'Red Oak Amber')),
#  ('Aztec Brewing Company', (4.5, 'Noche De Los Muertos')),
#  ('Kamchatskoye Pivo OAO', (3.5, 'Kamchatskoye Svetloye Firmennoye')),
#  ('Eschweger Klosterbrauerei', (4.5, 'Jacobinus Hefe Weizen')),
#  ("Barney's Beer", (3.5, 'Beet Red Beer')),
#  ('Kichesippi Beer Co.', (4.5, 'Heritage Traditional Dark')),
#  ('Water Street Brewing & Ale House',
#   (2.5, 'Water Street Old Wookie Barley Wine')),
#  ('Brasserie Brootcoorens', (5.0, 'La Sambresse Blonde')),
#  ('Stillwater Artisanal Ales', (5.0, 'Autumnal')),
#  ('Mack Bryggeri', (4.5, 'Haakon')),
#  ('Oakshire Brewing', (5.0, 'Watershed IPA')),
#  ('Brauerei August Gleumes GmbH', (5.0, 'Gleumes Hell')),
#  ('Fountain Square Brewing Co.', (4.0, 'Batch 13')),
#  ('Browar Fortuna', (4.0, 'Fortuna Komes Porter')),
#  ("Galbraith's Alehouse", (4.5, "Bob Hudson's Bitter")),
#  ('Blue Cat Brew Pub', (4.5, 'Howling Man Imperial Pale Ale')),
#  ('Euskal Garagardoa S.L.', (3.5, 'Pagoa Stout')),
#  ('White Rabbit', (5.0, 'White Rabbit Dark Ale')),
#  ('BrewPub København', (5.0, 'Atlantic IPA')),
#  ("Windsor Castle Brewery (Sadler's Ales)", (4.5, 'Mud City Stout')),
#  ('Brasserie Vanuxeem', (4.5, 'Queue De Charrue Brune')),
#  ('Cigar City Brewing', (5.0, 'Dirac  - Oak Aged')),
#  ('Big Rapids Brewing Co.', (4.5, 'Big Rapids Ale')),
#  ('Port Brewing Company / Pizza Port', (5.0, 'Port Pils')),
#  ('Pivovar Janá&#269;ek', (3.5, 'Janá&#269;ek Patriot')),
#  ('Ginga Kogen Beer', (5.0, 'Ginga Kogen White Beer')),
#  ('Capitol City Brewing Company', (5.0, 'Prohibition Porter')),
#  ('Cervejaria Schornstein', (4.0, 'Schornstein Pale Ale')),
#  ('SBC Restaurant & Brewery - Milford', (3.5, 'Southport Southtoberfest')),
#  ('Steelback Brewery', (4.0, 'Chain')),
#  ('Brouwerij Martens NV', (5.0, 'Larine Grand 95')),
#  ('De Fontein', (4.0, 'Vlaamsche Reus Blond')),
#  ('Chastnaya Pivovarnya Erstes', (4.0, 'Erstes Dunkel')),
#  ('Eastern Shore Brewing', (4.5, 'Magic Hefeweizen')),
#  ('Long Trail Brewing Co.', (5.0, 'Centennial Red (Brewmaster Series)')),
#  ('Brauerei Diebels GmbH & Co KG', (5.0, 'Diebels Alt')),
#  ('Blue Hills Brewery', (5.0, 'Imperial Red I.P.A.')),
#  ('Black Fox Brewing', (4.0, "Don't Call Me Wit")),
#  ('Gage Roads Brewing Company', (5.0, 'Sleeping Giant IPA')),
#  ('Colonial Brewing Company', (5.0, '18 Hands Brown Ale')),
#  ('Bootleg Brewery', (4.5, 'Bootleg Light Lager')),
#  ('Holdens Brewery Limited', (4.5, 'Golden Pale Ale')),
#  ('Bavarian Barbarian Brewing Company', (5.0, "Hammerin' Ale")),
#  ('Ludwig Roth Bierbrauerei GmbH', (5.0, 'Roth Weissbier Premium')),
#  ('Saku Brewery LTD', (5.0, 'Saku Hele')),
#  ("Facer's Flintshire Brewery", (5.0, "Facer's North Star Porter")),
#  ('Yellowstone Valley Brewing Co.', (5.0, 'Black Widow Oatmeal Stout')),
#  ('Bank Top Brewery', (4.0, 'Gold Digger')),
#  ('Pivovarna Union', (4.0, 'Union Temno Pivo')),
#  ('Bozeman Brewing Company', (4.5, 'Plum Street Porter')),
#  ('Triscele Srl', (4.0, 'Birra Del Sole')),
#  ('Zweite Schweriner Schlossbrauerei', (3.5, 'Schweriner Export')),
#  ('Silver Creek Brewing Co.', (5.0, 'Silver Creek Porter')),
#  ('Carlsberg-Tetley Brewing Ltd', (5.0, "Tetley's English Ale")),
#  ("Cooper's Cave Ale Company", (3.5, 'Oatmeal Stout')),
#  ("Beermann's Beerwerks", (5.0, 'Bourbon Barrel Barley-wine Ale')),
#  ('Blue Monkey Brewery', (4.0, 'Ape Ale')),
#  ('Gallia Omnia', (3.0, 'Catùtarvos')),
#  ('Pivovaren Zavod Ledenika', (4.0, 'Ledenika Special')),
#  ("Welton's Brewery", (3.5, 'Chocolate Rabbit')),
#  ("Artisan's Brewery & Italian Grill", (4.5, 'Short Order Porter')),
#  ('Starr Hill Brewery', (5.0, 'Maibock')),
#  ('Tuckerman Brewing Co.', (5.0, '6288 Stout')),
#  ('The Bier Brewery', (5.0, 'DFG IPA')),
#  ('Llupols I Llevats S.L.', (4.0, 'Glops Fumada')),
#  ('Cervecería Artesanal Mastra', (4.0, 'Mastra Negra')),
#  ('Fanø Bryghus', (4.5, 'Fano Vestkyst')),
#  ('Janake Wine Group AB', (2.0, 'Bagge Bocköl')),
#  ('Mogollon Brewing Company', (5.0, 'Horny Toad IPA')),
#  ('Sunday River Brewing Co.', (4.5, '840 India Pale Ale')),
#  ('Lonerider Brewing', (5.0, 'Grave Robber')),
#  ("Dave's BrewFarm", (5.0, 'BrewFarm Select')),
#  ('Brauerei Maisach - Bräustüberl Maisach',
#   (4.0, 'Maisacher Sedlmayr Weizen')),
#  ('La Brasserie Du Val De Drôme', (3.5, 'Markus Brune')),
#  ('Två Bryggare - Österlenbryggarna (Ysta Bryggeri)', (4.0, 'Ysta Julöl')),
#  ('Crown City Brewery', (4.0, 'Father Christmas')),
#  ('Kauzen Bräu', (5.0, 'Käuzle')),
#  ("Brouwerij 't Gaverhopke", (5.0, 'Het Paasbier (Green Cap)')),
#  ('New England Brewing Co.', (5.0, 'Sea Hag IPA')),
#  ('Porter Brewing Co. Ltd.', (4.5, 'Porter')),
#  ('Big Beaver Brewing Co.', (5.0, 'Beaver Stubble Stout')),
#  ('Hops Grill & Brewery', (4.0, 'Hammerhead Red')),
#  ('Lipetskpivo', (3.0, 'Myedovukha')),
#  ('Aarhus Bryghus', (3.5, 'Sweet Georgia Brown')),
#  ("Max Lager's American Grill & Brewery", (4.5, 'Gimme Shelter Bock')),
#  ('Balmain Brewing Company', (3.5, 'Balmain Original Pale Ale')),
#  ('Abteibrauerei Siegburger Brauhaus - FritzAle', (1.5, 'Monolith')),
#  ('Brauerei Zoller-Hof', (3.5, 'Zoller-Hof Spezial-Export')),
#  ('Cerveceria Artesanal Toro', (2.0, 'Toro')),
#  ('Roppelt-Bräu Trossenfurt', (4.0, 'Roppelt-Bräu Dunkel')),
#  ('Les Frères Houblon Microbrasserie', (4.5, 'Saint-Sévère')),
#  ('Brasserie Du Chant Du Loup', (3.5, 'Lupus Ale')),
#  ('Krugher & Brent', (3.0, 'Krugher & Brent Red Beer')),
#  ('Industrial Norte Paranaense De Bebidas Ltda', (2.0, 'Spoller Pilsen')),
#  ('Haneda Shuzo Y.K.', (4.5, 'Kyo No Kyoto Beer - Amber Ale')),
#  ('Rock Art Brewery', (5.0, 'Rock Art American Red Ale')),
#  ('Stevens Point Brewery', (5.0, '2012 Black Ale')),
#  ('Brasserie Des Géants', (5.0, 'Saison Voisin')),
#  ("Naylor's Brewery", (4.5, 'Cravenbräu')),
#  ('Kapplerbräu', (4.0, 'Kapplerbräu Echt Altomünstere Hefeweisse')),
#  ("Bootlegger's Brewery", (5.0, 'Palomino American Pale Ale')),
#  ('Mudgee Brewing Co', (4.5, 'Porter')),
#  ('Griesedieck Brothers Brewery Co.', (4.5, 'Premium Golden Pilsner')),
#  ('Baltika-Baku', (3.0, 'Xirdalan')),
#  ('Waiheke Island Brewery Ltd', (4.0, 'Waiheke Island Wharf Rd')),
#  ('San Marcos Brewery & Grill', (5.0, 'Oatmeal Stout')),
#  ('Ishikari Banya No Ji-Beer', (4.0, 'American Black Ale')),
#  ('Pater Van Damme', (4.0, 'Pater Van Damme')),
#  ('Bondi Beer Company', (2.0, 'Bondi Blonde Natural Ale')),
#  ('AuerBräu AG', (5.0, 'AuerBräu Rosenheimer Hefe Weissbier')),
#  ('Berliner Bürgerbräu GmbH',
#   (5.0, 'Berliner Bürgerbräu Bernauer Schwarzbier')),
#  ('Roel Brewery', (3.0, 'Roel Linköpingsöl Pils')),
#  ('Kulturbrauerei Heidelberg', (4.0, 'Kulturbrauerei Kräusen')),
#  ('The Wheat Beer Company', (1.5, "Duke's Big Ass Bock")),
#  ('London Fields Brewery', (3.0, 'Hackney Hopster')),
#  ('South East Asia Brewery', (4.5, 'Halida Beer')),
#  ('Barnaul Brewery', (3.5, 'Golfschteiner')),
#  ('The Merchant Ale House Restaurant & Brewpub', (5.0, 'Ginger Beer')),
#  ('Tracks Brewpub (Duplicate)', (4.5, 'Old Mill Lager')),
#  ('Molson Coors Canada', (5.0, 'Molson Export')),
#  ('Murree Brewery Co. Ltd.', (3.0, 'Murree Beer')),
#  ('Purity Brewing Co', (4.5, 'Pure UBU')),
#  ('Jilin Yinpu Brewery', (4.5, 'Yinpu Black Rice Beer')),
#  ('Brauerei Grandauer - Wildbräu Grafing vor München',
#   (5.0, 'Wildbräu Meistersud')),
#  ('Feral Brewing Co.', (5.0, 'Dark Funk')),
#  ('Abita Brewing Co.', (5.0, 'Amber')),
#  ('Mishawaka Brewing Company', (5.0, 'Mishawaka Kolsch')),
#  ('Brouwerij Meesters', (4.0, 'Meesters Galmaarden Tripel')),
#  ('Grand Rapids Brewing Co', (3.5, 'Cherry Lambic')),
#  ('Moles Brewery (Cascade Drinks Limited)', (3.0, 'Molegrip')),
#  ('Pivovar Bašta (Sousedský Pivovar U Bansethů)',
#   (3.0, 'Ba\x9ata Polotmavý Speciál 12°')),
#  ('Moosehead Breweries Ltd.', (5.0, 'Alpine Lager')),
#  ('Noble Ale Works', (5.0, 'Nobility')),
#  ('Shaftebury Brewing Company', (4.5, 'Honey Pale Ale')),
#  ('Lucid Brewing', (4.5, 'Air')),
#  ('Maine Beer Company', (5.0, 'Zoe')),
#  ('Schlossbrauerei Stein Wiskott GmbH & Co. KG', (4.0, 'Steiner Märzen')),
#  ('Beach Chalet Brewery and Restaurant', (5.0, 'Hop Patootie')),
#  ('Round Barn Brewery', (5.0, 'Cocoa Stout')),
#  ('Klinskiy Pivokombinat', (3.5, 'Klinskoye Ultro')),
#  ('Brauerei Reichold', (4.0, 'Hochstahl Lager')),
#  ('Redwood Curtain Brewing Company', (5.0, 'Tripel')),
#  ('Element Brewing Company', (5.0, 'Altoberfest')),
#  ('Postbrauerei Weiler u. Siebersquelle Anton Zinth KG',
#   (3.0, 'Post Hefe Weizen')),
#  ('Empire Brewing', (3.5, 'Imperium')),
#  ('Sprig & Fern Brewery', (4.0, 'Harvest Pils')),
#  ('Gebr. Sünner GmbH & Co. KG', (5.0, 'Sünner Kölsch')),
#  ('Liechtensteiner Brauhaus', (3.5, "Liechtensteiner Brauhaus Hell's")),
#  ('Brasserie De Milly', (4.5, 'La Rebelle')),
#  ('Skye Book And Brew', (4.0, 'Pataha Creek Porter')),
#  ("Brasserie Grain d' Orge (Brasserie Jeanne d'Arc SA)",
#   (5.0, "Grain D'orge Secret Des Moines")),
#  ('Deka Brewery', (4.5, 'Ilmen Lager Beer')),
#  ('Thirsty Crow', (4.0, 'Vanilla Milk Stout')),
#  ('Povolzhye OAO', (3.5, 'Volzhanin Akhtuba')),
#  ('Birra Peja', (4.0, 'Peja Pilsner')),
#  ('Bowland Beer Company Limited', (4.0, 'Bowland Hunters Moon')),
#  ('E & O Trading Company', (4.0, 'Bell In Hand')),
#  ('Frankenmuth Brewery', (5.0, 'Frankenmuth Cass River Blonde Ale')),
#  ('Le Moulin De Saint Martin', (3.0, 'Le Mounlin De Saint Martin Blonde')),
#  ('Amarcord Birra Artigianale Italiana', (5.0, 'Prima Donna')),
#  ('The Little Brewing Company', (5.0, 'Wicked Elf Pale Ale')),
#  ('La Diable', (4.5, 'Extreme Onction')),
#  ("Brasserie d'Oran", (4.0, "Taron D'Or Enkhept")),
#  ('Roskilde Øl', (3.0, 'Roskilde Enebær Ale')),
#  ('Weeping Radish Eco Farm & Brewery', (4.5, 'Black Radish Dark Lager')),
#  ('Castle Rock Brewery', (5.0, 'Harvest Pale')),
#  ('Brasserie Artisanale De La Crécelle', (3.5, 'Crécelle Brune')),
#  ("Lefty's Brewing Company", (5.0, 'Irish-Style Stout')),
#  ('Motor City Brewing Works', (5.0, 'Motor City Brewing Ghettoblaster')),
#  ('Holy City Brewing', (4.5, 'Pecan Dream')),
#  ('Davidson Brothers Restaurant & Brewery', (5.0, 'Oatmeal Stout')),
#  ('Glückauf Brauerei GmbH Gersdorf', (4.5, 'Karl May Jubilaums Pils')),
#  ('Privatbrauerei Kesselring Gmbh & Co. KG', (4.5, 'Kesselring Urtyp Export')),
#  ('Brauerei Josef Greif', (5.0, 'Greif-Bräu Weisse')),
#  ('Mt. Carmel Brewing Company', (5.0, 'Amber Ale')),
#  ('Five Seasons Prado', (5.0, 'Hopgasm')),
#  ('Science Infuse', (3.5, 'Science Infuse Triple Spéciale')),
#  ('Jaden James Brewery', (4.0, 'RIS')),
#  ('Stevns Bryghus', (3.5, 'Tryggevældebryg Nr. 1')),
#  ('Chelsea Brewing Company', (5.0, 'Chelsea Cream Stout')),
#  ('Chicago Brewing Company', (5.0, 'Chicago Belgian Dubbel')),
#  ('Old Credit Brewing Co.', (5.0, 'Old Credit Pale Pilsner')),
#  ('Alameda Brewhouse', (5.0, 'My Bloody Valentine')),
#  ('Half Moon Restaurant & Brewery', (5.0, "Elwood's IPA")),
#  ('Brouwerij Facon', (4.0, 'Satcheu')),
#  ('Dogwood Brewing Company', (4.0, 'Dogwood Winter Ale (2001)')),
#  ('Salamander Brewing Company', (4.5, 'Truncheon')),
#  ('Shandong Taishan Beer Co Ltd', (3.5, 'Kritzer')),
#  ('Baltika Breweries', (5.0, 'Baltika #6 Porter')),
#  ('Brauerei C. & A. Veltins GmbH & Co.', (5.0, 'Veltins Pilsner')),
#  ('Lucky Labrador Beer Hall', (5.0, 'Triple Threat IPA')),
#  ('DuClaw Brewing Co.', (4.0, '31.0')),
#  ('Brauerei Baar AG', (3.5, 'Erdmandli Zuger Amber Bier')),
#  ('Microbrasserie Le Naufrageur', (5.0, 'La Corte Real')),
#  ('La Cumbre Brewing Co.', (5.0, 'Elevated IPA')),
#  ('Baying Hound Aleworks', (5.0, "Lord Wimsey's")),
#  ('Ariana Brewery', (4.0, 'Ariana Tumno (Dark)')),
#  ('Equinox Brewing Company', (5.0, 'Sunset Stout')),
#  ('Elm City Brewing Co.', (4.5, 'Elm City Schwarzbier')),
#  ('Ross Valley Brewing Company', (4.5, 'Repack Red Ale')),
#  ('Milton Brewery', (4.5, 'Nero')),
#  ('Hargreaves Hill Brewing Company', (5.0, 'ESB')),
#  ('Lervig Aktiebryggeri AS', (4.0, 'White Dog Norwegian Wheat Beer')),
#  ('La Cervesera Artesana', (4.5, 'Iberian De Mel')),
#  ('Drummond Brewing Company', (3.5, 'Beer Beer')),
#  ('Galway Hooker Brewery', (5.0, 'Galway Hooker Irish Pale Ale')),
#  ('The Flowerpots Brewery / The Flowerpots Inn',
#   (4.0, 'Brandy Mount Barley Wine')),
#  ('Beltaine Appennino Risorse', (4.0, 'Beltaine')),
#  ('Saint Louis Brewery / Schlafly Tap Room', (5.0, 'Schlafly Bock')),
#  ('Firestone Walker Brewing Co.', (5.0, 'Union Jack India Pale Ale')),
#  ('Jolly Pumpkin Artisan Ales', (5.0, 'Collababeire Special Holiday Ale')),
#  ('Brasserie Artisanale Ratz', (3.5, 'Saint-Patrick')),
#  ('The Tin Whistle Brewing Company', (4.5, 'Chocolate Cherry Porter')),
#  ('Microbrasserie La Chouape', (4.5, 'Rousse')),
#  ('Baikalskaya Pivovarenniya Kompaniya', (2.5, 'Komanda Svetloye')),
#  ('Lapin Kulta', (4.0, 'Lapin Kulta Special III')),
#  ('Brouwerij De Drie Koningen', (4.5, "Caspar's Triple")),
#  ('Tigertops Brewery', (4.5, 'Blanche De Newland')),
#  ('Brouwerij Maximus', (4.0, 'Brutus')),
#  ("Bushy's (Mount Brewing Company Ltd)", (4.0, 'Ruby (1874) Mild')),
#  ('Onuma Brewery', (3.0, 'ALT')),
#  ('Kasztelan Browar Sierpc S.A. (Carlsberg)', (5.0, 'Kasztelan Jasne Pelne')),
#  ('Brouwerij Angerik BVBA', (4.0, 'Harten Troef')),
#  ("Butcher's Brewing", (2.5, 'Double Shaka Imperial IPA')),
#  ('Freedom Brewery Ltd', (4.5, 'Freedom Pilsener Lager')),
#  ('St. Francis Brewery & Restaurant', (4.0, 'South Shore Stout')),
#  ('S.C. Bere Mure&#351;', (1.5, 'Neumarkt Premium')),
#  ('First Draft - Niagara College Teaching Brewery',
#   (4.0, 'First Draft Campus Ale')),
#  ('Thornbridge Brewery', (5.0, 'St Petersburg Imperial Stout')),
#  ('Federation Brewery Ltd', (4.5, 'Angel Ale')),
#  ('Elliot Glacier Public House', (4.5, 'Barrett Spur Bitter')),
#  ('Ballast Point Brewing Company', (5.0, 'Ballast Point Rocktoberfest Lager')),
#  ('Willimantic Brewing Co.', (5.0, 'Willimantic Pony Espresso Stout')),
#  ('Harpoon Brewery', (5.0, 'Harpoon Oak Aged Dunkel (100 Barrel Series #34)')),
#  ('Marshall Brewing Company', (5.0, 'El CuCuy')),
#  ('Crossroads Brewing Company', (5.0, "Brady's Bay Cream Ale")),
#  ('Ringnes Bryggeri (Carlsberg)', (5.0, 'Lysholmer Double Ice')),
#  ('Queen City Brewing Limited', (4.0, 'Celtic Rabbit Amber Ale')),
#  ('Bridge Road Brewers', (5.0, 'B2 Bomber')),
#  ("Birrificio L'Olmaia", (4.0, "L'Olmaia La 5")),
#  ('Privatbrauerei Scherdel OHG', (4.5, 'Scherdel Helle Weisse')),
#  ('Hyouko Yashiki No Mori Brewery', (4.5, 'Swan Lake Imperial Stout')),
#  ('Zuma Brewing Company', (4.0, 'Cancun')),
#  ('Cerveza Ancla Colombia', (3.0, 'Cerveza Ancla')),
#  ('Odin Brewing Company', (4.5, "Thor's Fury")),
#  ('Ankerbräu Nördlingen', (5.0, 'Rieser Kristall-Weizen')),
#  ('Barley Brothers Brewery & Grill', (3.5, 'Double Espresso Stout')),
#  ('Riverhead Brewery Limited', (3.5, 'Redbrook')),
#  ('Avery Brewing Company', (5.0, 'Gemini')),
#  ('Cwmbran Brewery', (5.0, 'Blackcurrant Stout')),
#  ('Breakwater Brewing', (4.5, "Maverick's")),
#  ('Microbrasserie Du Lac-Saint-Jean', (4.0, 'Belle Gigue')),
#  ('Sherwood Forest Brewers Ltd.', (5.0, "Sheriff's India Pale Ale")),
#  ('Crooked Stave Artisan Beer Project', (4.5, 'Crooked Stave Fertile Soil')),
#  ('Snowy Mountains Brewery', (4.5, 'Crackenback')),
#  ('Independence Brew Pub', (5.0, 'Oatmeal Stout')),
#  ('Shardlow Brewing Company Ltd', (3.0, "Reverend Eaton's Ale")),
#  ('Wold Top Brewery', (5.0, 'Wolds Way Pale Ale')),
#  ("Brewster's Brewing Co Ltd", (5.0, 'HopHead')),
#  ('Krasniy Vostok', (5.0, 'Solodoff Classic')),
#  ('Rio Salado Brewing Company', (5.0, 'Rio Salado Mai Bock')),
#  ('Asheville Brewing Company', (5.0, 'Old School Pale Ale')),
#  ('Big Buck Brewery & Steakhouse #3', (4.5, "Doc's ESB")),
#  ('Beba', (5.0, 'Birra Di Natale')),
#  ('Brouwerij Drie Fonteinen', (5.0, 'Drie Fonteinen Straffe Winter')),
#  ('Independence Brewing Co.', (5.0, 'Convict Hill Oatmeal Stout')),
#  ('Boulder Beer / Wilderness Pub', (5.0, 'Singletrack Copper Ale')),
#  ('Traditional Scottish Ales', (5.0, 'Double Espresso Wild Oat Stout')),
#  ('Great Oakley Brewery', (4.0, "Wot's Occurring")),
#  ('Wagtail Brewery', (3.5, 'The Devils Doorbell')),
#  ('Brouwerij De Horste', (5.0, 'Beatrix')),
#  ('Tower Brewery', (4.5, 'Tower Pale Ale')),
#  ("Hamburger Mary's Rec Room", (3.5, 'Christmas Ale')),
#  ('Storm Brewing Co.', (3.0, 'Silk Of Amnesia')),
#  ('Angry Minnow Brewpub', (4.5, 'River Pig Pale Ale')),
#  ('Turkey Hill Brewing Co. Pub & Grille', (4.0, 'Vienna Lager')),
#  ('Teme Valley Brewery', (4.0, 'Wass Ale')),
#  ('P.H. Woods Restaurant & Brewery', (4.5, 'Blackfin Lager')),
#  ('Jessenhofke NV', (4.0, 'Jessenhofke Triple')),
#  ('Löwenbräu Buttenheim', (5.0, 'Ungespundetes Lagerbier')),
#  ('Archipelago Brewing Company / Craft Beer Hub',
#   (5.0, 'Archipelago Explorer')),
#  ('Santa Fe Brewing Company', (5.0, 'Freestyle Pilsner')),
#  ('Scone Bierbrouwerij', (5.0, 'Sconedorpsch Weizen')),
#  ('Big Boss Brewing', (5.0, "Hell's Belle")),
#  ('Scuttlebutt Brewing Company', (5.0, 'Gale Force India Style Pale Ale')),
#  ('Dark Horse Brewing Company', (5.0, 'Raspberry Black Ice')),
#  ('Two Brothers Brewing Company',
#   (5.0, 'Domaine DuPage French Style Country Ale')),
#  ('Brauerei Fischerstube AG', (4.0, 'Ueli Bier Spezial')),
#  ('Brasserie Gigi', (4.5, 'La Gaumaise Blonde')),
#  ('Castle Danger Brewery', (4.0, 'Danger Ale')),
#  ('Pivovar Hostan', (3.5, 'Praga')),
#  ('Fletcher Street Brewing Company', (4.0, 'Thunder Bay Bock')),
#  ('Maritime Beer Company Inc.', (4.5, 'Black Pearl Cream Ale')),
#  ('Cottage Brewing Co. Ltd', (5.0, 'Auburn')),
#  ('Appalachian Brewing Company', (5.0, 'Mountain Lager')),
#  ('Huebert Brewing Company', (3.5, 'Chocolate Mint Stout')),
#  ('Red Eye Brewing Company', (4.5, 'Barrel-Aged Tempt')),
#  ('Red Rat Craft Brewery', (4.0, "Hadley's Blonde")),
#  ('Suginoya Brewery (Hamachi Shuzo K.K.)', (5.0, 'Suginoya Stout')),
#  ("Rooster's Brewing Company Ltd.", (5.0, "Rooster's - Hooligan")),
#  ('Red Hare Brewing Company', (4.0, "Rabbit's Reserve #1: Chocolate Porter")),
#  ('Ostankinskiy Pivovarinniy Zavod', (4.0, 'Meks')),
#  ("Adelbert's Brewery", (4.0, 'Scratching Hippo')),
#  ('Wedge Brewing Company', (5.0, '3rd Rail IPA')),
#  ('Gruhlke Brewery', (4.0, 'Dortmunder')),
#  ('Brauerei Georg Meister', (4.0, 'Meisterbräu Vollbier Dunkel')),
#  ('Scotch Irish Brewing Company', (5.0, "Sgt Major's IPA")),
#  ('Badische Staatsbrauerei Rothaus AG', (5.0, 'Rothaus Hefeweizen')),
#  ('Flat Branch Pub & Brewery', (4.5, 'Pilsener')),
#  ("B.O.B.'s House Of Brews", (4.0, "B.O.B.'s Hopsun")),
#  ('Celtic Bayou', (5.0, 'Three Threads Porter')),
#  ('Bahamian Brewery Beverage & Co. Ltd.', (5.0, 'Strong Back Stout')),
#  ('Artebirraia', (2.0, 'Mazarol')),
#  ("Marston's PLC", (4.5, "Banks's Original")),
#  ('Watson Bros. Bistro & Brewery',
#   (4.0, "Abigail's Amber (Buddy's Ringside Amber Ale)")),
#  ('Privatbrauerei Gebrüder Mayer', (4.5, "Mayer's Osterbier")),
#  ('Brewery Ommegang',
#   (5.0, 'Three Philosophers Belgian Style Blend (Quadrupel)')),
#  ('Fort George Brewery + Public House', (5.0, 'Vortex IPA')),
#  ('Williamsburg AleWerks', (5.0, 'Ironbound Ale')),
#  ('Great Newsome Brewery', (4.5, "Newsome's Ploughman's Pride")),
#  ("Bloomington Brewing Company / Lennie's", (5.0, 'Quarrymen Pale Ale')),
#  ('Marston Moor Brewery Limited', (4.5, 'Heebee Geebee')),
#  ('Ambacht Brewing', (4.5, 'Ambacht Matzobraü')),
#  ('Peak Brewing Company', (2.5, "Bruno's Amber Lager")),
#  ('Maui Brewing Co. (Brewpub)', (5.0, 'Big Swell IPA')),
#  ('Ezo Beer KK', (5.0, "Red Fox  (Rogue's American Amber)")),
#  ('Central City Brewing', (5.0, 'Copper Bock')),
#  ('Brauerei Vasold & Schmitt', (3.5, 'Benedikt Dunkel')),
#  ("Lily's Seafood & B.C.", (4.5, "Lily's Light Pilsner")),
#  ('Surly Brewing Company', (5.0, 'Tea Bagged Bitter Brewer')),
#  ('Grebbestad Bryggeri', (4.5, 'Original')),
#  ('Old Hat Brewery & Grill', (4.0, 'Old Hat Red Lager')),
#  ('Pivovary Staropramen', (5.0, 'Staropramen Dark')),
#  ('John Boston Premium Beverages', (3.5, "Boston's Mill Pale Ale")),
#  ('Bayhawk Ales', (5.0, 'California Pale Ale')),
#  ('Alltech’s Lexington Brewing and Distilling Co.', (5.0, 'Kentucky Light')),
#  ('Great Dane Pub & Brewing Company (Downtown)', (5.0, 'Barleywine')),
#  ("Amber's Brewing Co.", (5.0, 'Australian Mountain Pepper Berry')),
#  ('Blue House Mediterranean Cafe', (4.0, 'Pale Ale')),
#  ('Anchorage Brewing Company', (5.0, 'Love Buzz Saison')),
#  ('Blacksmith Brewing', (5.0, 'Pulaski Porter')),
#  ('Fish Brewing Company / Fishbowl Brewpub', (5.0, 'Fish Tale Amber Ale')),
#  ('Freedom Brewery Ltd.', (3.5, 'Pilsner')),
#  ('Coach House Brewing Company Ltd.', (4.0, 'Rabbit Punch')),
#  ('Old European Brewing Company', (3.0, 'Frederick Scholz NA Amber')),
#  ('West End Brewery', (2.5, 'West End Draught')),
#  ("De La Vega's Pecan Grill & Brewery", (3.5, 'German Pilsner')),
#  ('Cerveseria Birrart', (3.0, 'Moska Rossa')),
#  ('Birreria Blues', (3.0, 'Blues Ale')),
#  ('Micro-brasserie Saint-Arnould', (4.5, 'Rivière Rouge')),
#  ('Michelsbräu GmbH', (4.0, "Michel's Kellerbier")),
#  ('Payette Brewing', (4.0, 'Outlaw IPA')),
#  ('First In Last Out (FILO) Brewery', (3.0, 'Cardinal')),
#  ('Burg Bier Brouwerij', (4.5, 'Burg Winterbok')),
#  ('Valkyrie Brewing', (5.0, 'Berserk')),
#  ('Durdin (Len)', (4.0, 'Bogyemskoye Chyernoye')),
#  ('Weisses Bräuhaus G. Schneider & Sohn GmbH',
#   (5.0, 'Schneider Weisse Tap X Mein Nelson Sauvin')),
#  ('Church End Brewery Ltd', (5.0, 'Church End Gravediggers Mild')),
#  ('Battered Boar Brewing Company', (5.0, 'Coconut Cream Stout')),
#  ('Ale Industries', (5.0, 'Fysus')),
#  ("Liebhart's Privatbrauerei Detmold",
#   (5.0, "Liebhart's Dunkel Bio Landbier")),
#  ('Brouwerij Rodenburg', (3.5, 'Winterbok')),
#  ('Brauerei Johannes Grasser', (5.0, 'Huppendorfer Vollbier')),
#  ('Brauerei Friedr. Jacob', (4.5, 'Jacob Winter Gold')),
#  ('Round Guys Brewing Company', (5.0, 'BerlinerWeisster-WeissterBerliner')),
#  ('Big Bear Mountain Brewery', (4.5, 'Orange Blossom')),
#  ('Westerham Brewery Company Ltd', (5.0, 'British Bulldog')),
#  ("Uncle Buck's Brewery & Steakhouse", (4.0, 'Uncle Bucks Light')),
#  ('Microbrasserie Le Corsaire', (4.5, 'Kirke')),
#  ('Frampton Brasse', (4.0, 'St-Édouard')),
#  ('Brasserie Des Monts', (2.5, 'Cuvee Des Monts')),
#  ('Black Lotus Brewery', (5.0, 'Imperial Oatmeal Stout')),
#  ('Bürgerbräu Bad Reichenhall', (4.0, 'Alpen Stoff')),
#  ('Hansa Borg Bryggerier ASA', (4.5, 'Hansa Pilsner')),
#  ('Bethlehem Brew Works', (5.0, 'Organically Brewed Imperial IPA')),
#  ('Cervejaria Universitária', (5.0, 'Universitária Pilsen')),
#  ('Les Bieres Des Hauts', (3.0, 'Sa Majesté Des Arbres')),
#  ('Brouwerij Cnudde', (3.5, 'Cnudde Bruin')),
#  ('Three Troupers Brewery', (4.0, 'Pale Ale')),
#  ('Cervejaria Bruge', (1.0, 'Bruge Stout')),
#  ('Crailsheimer Engelbräu', (4.5, 'Engel Kellerbier Dunkel')),
#  ('Deschutes Brewery & Public House', (5.0, 'Pilsner 005')),
#  ('Stone City Brewing', (4.5, 'Iowa Pale Ale')),
#  ('Amnesia Brewing', (5.0, 'The ESB')),
#  ('Brasserie du Chardon', (4.0, 'Roche Noire')),
#  ("Sacramento Brewing Company's Oasis", (4.5, 'Russian Imperial Stout')),
#  ('Yarra Flats Brewery', (4.0, 'Buckleys Original Ale')),
#  ('Brauerei Zwettl Karl Schwarz GmbH', (4.0, 'Zwettler Zwickl')),
#  ('Sebago Brewing Company', (5.0, "Frye's Leap India Pale Ale")),
#  ('Morgan Street Brewery', (5.0, 'Dopplebock')),
#  ('Harriet Brewing', (5.0, 'Wodan Weizen')),
#  ('Sun King Brewing Company', (5.0, 'Wee Muckle')),
#  ('Flying Goose Brew Pub & Grille', (4.0, 'Long Brothers Strong Ale')),
#  ('Thirsty Bear Brewing Company', (4.5, 'Hibernator')),
#  ('Art Cervesers - Cervesa Artesanal', (4.5, 'Art Coure')),
#  ('Grupo Modelo S.A. de C.V.', (5.0, 'Victoria')),
#  ('Spendrups Bryggeri AB', (4.5, 'Mariestads Prima Lager')),
#  ('Silva Reghin S.A. (Brau-Union Romania)', (4.0, 'Silva Strong Dark Beer')),
#  ("O'Dempsey's", (5.0, 'Inukshuk IPA')),
#  ('Harbor City Brewing Company', (5.0, 'Harbor City Harvest Wheat')),
#  ("McGuire's Irish Pub of Destin",
#   (5.0, "McGuire's Raspberry Imperial Stout")),
#  ('Lucky Bucket Brewing Co.', (5.0, 'IPA')),
#  ('Birrificio Del Ducato', (5.0, "L'Ultima Luna")),
#  ('Fossil Fuels Brewing Company', (5.0, 'Ancient Wheat')),
#  ('Byron Bay Brewing', (4.0, 'Byron Bay Premium Ale')),
#  ('Squam Brewing', (5.0, 'Golden IPA')),
#  ('Purrumbete Brewing Company', (5.0, 'Red Duck The Ox')),
#  ('Route 66 Brewery', (4.5, 'Maple Oatmeal (Maypo) Stout')),
#  ('Castel-Sakartvelo', (4.0, 'Argo Dark')),
#  ('Blind Lady Ale House & Automatic Brewing Co.',
#   (5.0, 'Automatic Coffee Rain Oatmeal Stout')),
#  ('Limestone Brewing Company', (5.0, 'Flying Pig Imperial IPA')),
#  ('Wessex Brewery', (3.0, 'Russian Stoat')),
#  ('Ironbark Brewery', (4.0, 'Debilitator')),
#  ('PT Bali Hai Brewery Indonesia', (4.0, 'Bali Hai Premium')),
#  ('Hampshire Brewery Ltd', (5.0, 'Pride Of Romsey I.P.A.')),
#  ('Macedonian Thrace Brewery', (4.5, 'Hillas')),
#  ('Buckeye Brewing Company', (5.0, "Seventy-Six ('76)")),
#  ('S´Kloane Brauhaus', (4.0, 'Weizenbier')),
#  ('Bent River Brewing Company', (5.0, 'Uncommon Stout')),
#  ('Moon Dog Craft Brewery',
#   (4.5, 'Skunkworks Double IPA (Cognac Barrel Aged)')),
#  ('Zeos Brewing Company S.A.', (3.5, 'Makedoniki Syntaghy')),
#  ("Stewart's Brewing Co.", (5.0, 'Glacier IPA')),
#  ('San Biagio', (4.0, 'Verbum')),
#  ('Bayou Teche Brewery', (4.0, 'LA-31 Boucanèe')),
#  ('Pretty Things Beer & Ale Project', (5.0, 'Babayaga')),
#  ('Brasserie Du Bocq', (5.0, 'Triple Moine / Deugniet')),
#  ('Hoeksche Waard Bierbrouwerij', (3.5, 'Hoeksch Eikenbier')),
#  ('Antigua Brewery Ltd.', (5.0, 'Wadadli')),
#  ('Birrificio Freccia', (4.0, 'Extra 2009')),
#  ('Middle East International Investments Group/MEIIG', (2.5, 'Petra 10%')),
#  ('Brouwerij Bockor N.V.', (5.0, 'Bellegems Bruin')),
#  ('Brownstone Restaurant & Brewhouse', (4.0, 'Russian Imperial Stout')),
#  ('Pivovar Ostravar (Staropramen Breweries / Inbev)',
#   (4.0, 'Ostravar Premium')),
#  ('The Fox & Newt / Fox Beer Co.', (4.0, 'Fox IPA')),
#  ('Fusion Brewing', (4.0, 'Prime Ale')),
#  ('Pivovarský dv&#367;r Plze&#328; / Purkmistr Restaurant',
#   (4.0, 'Purkmistr 12° - Dark Lager')),
#  ('Crouch Vale Brewery Limited', (5.0, 'Crouch Vale Brewers Gold')),
#  ("Govnor's Public House Restaurant And Brewery",
#   (4.5, 'Absolute Rat Bastard')),
#  ('HogsBack Brewing Company', (4.0, 'HogsBack Vintage Lager')),
#  ("Gritty McDuff's Brewing Company", (5.0, 'Vacationland Summer Ale')),
#  ('J.J. Bitting Brewing Company', (5.0, 'Woodbridge Winter Warmer')),
#  ('Dragonmead Microbrewery',
#   (5.0, "Dragonmead Guinevere's Golden Belgian Ale")),
#  ('Dachsbräu', (4.0, 'Weilheimer Ur-Hell')),
#  ('Anadolu Efes Brewery', (5.0, 'Efes Pilsener')),
#  ("O'Brien Brewing", (3.5, "O'Brien Pale Ale")),
#  ('Sapporo Breweries Ltd.', (5.0, 'Yebisu (Premium)')),
#  ('Oceanside Ale Works', (5.0, 'American Strong Ale')),
#  ("Trader Joe's Brewing Company", (5.0, 'Josephs Brau Winterfest')),
#  ('Iceni Brewery', (4.0, 'Iceni Golden Harvest')),
#  ('Hansens Brauerei', (3.5, 'Hansens Schwarzbier')),
#  ('Pivovariya Luzhniki OAO', (4.0, 'Ingver')),
#  ("Weston Brewing Company & O'Malley's Pub",
#   (4.0, 'Brew Labs #1 India Pale Ale')),
#  ("JT Schmid's Restaurant & Brewery", (4.5, "JT Schmid's India Pale Ale")),
#  ('Weissbierbrauerei Schwendl', (3.5, 'Weisser Bock')),
#  ('Minhas Craft Brewery', (5.0, 'Boxer Lager')),
#  ('Wharfedale Brewery', (4.5, 'Van De Plas')),
#  ('Obolon Brewery', (5.0, 'Obolon Premium')),
#  ('Cervesera Tramuntana', (3.5, 'Illa')),
#  ('Israel Beer Breweries Ltd.', (4.5, 'Malty')),
#  ('Brasserie Seigneuriale (Sleeman Breweries Ltd.)',
#   (4.5, 'La Seigneuriale Réserve')),
#  ('C.B. & Potts Restaurant & Brewery', (4.0, 'Hefeweizen')),
#  ('Einstök Ölgerð', (3.5, 'Icelandic Pale Ale')),
#  ('KleinBrouwerij De Glazen Toren', (5.0, 'Ondineke Oilsjtersen Tripel')),
#  ('Liquid Hero Brewery', (3.0, 'American Hero')),
#  ('Fyne Ales Ltd', (4.5, 'Highlander')),
#  ('Rock Bottom Restaurant And Brewery', (4.0, 'Pinstripe Pale')),
#  ('Pivovar Zlaty Bazant a.s.', (5.0, 'Golden Pheasant')),
#  ('Café - Brouwerij Nieuwhuys', (4.5, 'Alpaïde')),
#  ('Päffgen Obergärige Hausbrauerei', (5.0, 'Kölsch')),
#  ('Elland Brewery', (4.5, 'Tremendous Delerium')),
#  ('Fiddlehead Brewing Company', (4.5, 'IPA')),
#  ('Red Lion Ales', (5.0, 'White Lion')),
#  ('Brasserie La Choulette', (5.0, 'La Choulette Ambrée')),
#  ('Viking Brewery - Vifilfell Ltd.', (4.5, 'Víking Jólabjór')),
#  ('Barley and Hops Grill & Microbrewery', (4.5, 'HopTopsy ESB')),
#  ('Abbey Beverage Company', (5.0, "Monks' Wit")),
#  ('Brasserie Artisanale Des Grands Cols', (4.5, 'La Tourmente Blanche')),
#  ('Long Brewing', (4.5, 'Long Brewing IPA')),
#  ('Strange Brewing Company', (4.5, 'Tainted Black')),
#  ('Lodi Beer Company', (4.5, 'Eisbock')),
#  ('Allentown Brew Works', (5.0, 'Steelgarden Wit')),
#  ('Choperia & Distribuidora Opa Bier', (2.5, 'Chopp Porter')),
#  ('Lang Creek Brewery', (5.0, 'Lang Creek Windsock Pale Ale')),
#  ('Brauerei Schäffler', (3.5, 'Härte 10')),
#  ('Weissbierbrauerei Hopf', (5.0, 'Hopf Spezial Weisse')),
#  ('Oaken Barrel Brewing Company', (5.0, 'Meridian Street Premium Lager')),
#  ('AS L&#257;&#269;pl&#275;\x9aa Alus',
#   (3.5, 'L&#257;cpl&#275;sis Tum\x9aais Alus (Dark Beer)')),
#  ('Privatbrauerei Joh. Cramer', (3.0, 'Cramer Kellerbier - BIO')),
#  ('Demarche Brewery', (5.0, 'Ciney Brune')),
#  ('Margaret River Ale Company', (3.0, 'Bug Ocean Altbier')),
#  ('Brasserie Saint-Monon', (4.5, 'Saint-Monon Bière Au Miel (Honey Blonde)')),
#  ('Brasserie De La Pigeonnelle', (4.0, 'Loirette')),
#  ('Cervecería Bayernbräu de México', (4.5, 'Weissbier')),
#  ('Brouwerij Bavik', (5.0, 'Bavik Witte Ezel (White Donkey)')),
#  ('Mendocino Brewing Company', (5.0, 'White Hawk Original IPA')),
#  ('Tui Brewery', (5.0, 'Tui East India Pale Ale')),
#  ('Hofbräu Kaltenhausen (Brau Union)', (5.0, 'Edelweiss Weissbier Snowfresh')),
#  ('Pratt Street Ale House', (5.0, "Oliver's Manchester Cream Ale")),
#  ("Monty's Brewery", (3.5, 'Moonrise')),
#  ('Apatinska Pivara A.D.', (4.5, 'Jelen Svetlo Pivo')),
#  ("Otter Creek Brewing / Wolaver's",
#   (5.0, 'Mud Bock (Otter Creek World Tour)')),
#  ('Grassroots Brewing', (5.0, 'Wachu Saison')),
#  ('Grauballe Bryghus - Gaardbryggeriet', (4.0, 'Grauballe Enebær Stout')),
#  ('Custom Beers Limited', (4.0, 'Custom Beers Dark Roast Porter')),
#  ('Krash Brewery', (3.5, 'KaHopper Ale')),
#  ('Streek Bieren Iwamizawa Bakushukan', (3.0, 'Furano Beer Light Lager')),
#  ('Trap Rock Restaurant & Brewery', (4.5, 'William Tell ESB')),
#  ('Boscos Restaurant & Brewing Co. - Nashville',
#   (5.0, 'Boscos Flaming Stone')),
#  ('Brasserie Saint Antoine Abbé', (4.5, 'Pale Ale')),
#  ('Columbia Brewery', (5.0, 'Kootenay Mountain Ale')),
#  ('Cold Spring Brewing Co.', (5.0, 'Gluek Red Bock Royal Select')),
#  ('The Lab Brewing Co.', (3.5, 'Bad Influence')),
#  ('Ruby Mountain Brewing', (5.0, 'Bristlecone Brown Porter')),
#  ('Brasserie Haldemann', (4.0, 'Darach Mòr Special Reserve 35')),
#  ('Sandbacka Bryggeri', (5.0, 'Imperial Stout')),
#  ('Brouwerij De Graal', (4.5, 'De Graal Gember')),
#  ('Peace Tree Brewing Co.', (4.5, 'Rye Porter')),
#  ('Bedondaine & Bedons Ronds', (5.0, "La Reyne D'escosse")),
#  ('Occidental Brewing Co.', (4.0, 'Cloudy Summer')),
#  ('Ruckus Brewing', (5.0, 'Hoptimus Prime')),
#  ('Lymestone Brewery', (4.0, 'Stone Brood')),
#  ('Utrechtse Stoombierbrouwerij B.V.', (4.0, 'Bokbier')),
#  ('Throwback Brewery', (5.0, 'Throwback Fat Alberta Imperial Stout')),
#  ('Brauerei Eugen Häberlen', (3.0, 'Gaildorfer Spezial')),
#  ('Brauerei Erharting', (3.5, 'Erhartinger Hefe-Weisse')),
#  ('Ringwood Brewery', (5.0, 'Ringwood Fortyniner')),
#  ('Smuttynose Brewing Company',
#   (5.0, 'Smuttynose Barleywine Style Ale (Big Beer Series)')),
#  ('Barley Island Brewing Company', (5.0, 'Bourbon Barrel Aged Oatmeal Stout')),
#  ('Brauerei Mittenwald', (4.0, 'Josefi Bock Dunkel')),
#  ('Griesbräu Zu Murnau', (4.5, 'Griesbräu Weisse')),
#  ('Picaroons Brewing Co.', (5.0, 'Irish Red Ale')),
#  ('Pen-lon Cottage Brewery', (4.0, 'Stock Ram')),
#  ('Lake Bluff Brewing Company', (4.5, 'Hard Tail')),
#  ('Heater Allen Brewing', (5.0, 'Sandy Paws (2008)')),
#  ('De Leyerth Brouwerijen (Urthel)', (5.0, 'Urthel Hop-It')),
#  ('Greenbush Brewing Company', (5.0, 'Sunspot')),
#  ('Qvänum Mat & Malt', (3.5, 'Grannen Ale')),
#  ('La Brasserie Artisanale Touken', (4.0, 'Philomenn Spoum')),
#  ('Cerveza Artesanal Araucana', (4.0, 'Araucana Rojiza Cordillerana')),
#  ('Toscana Tipica  Birra  Del Linchetto',
#   (5.0, 'Birra Del Linchetto Birra Dark')),
#  ('The Commons Brewery', (4.5, 'Flemish Kiss')),
#  ('Privatbrauerei Bischoff',
#   (5.0, 'Donnersberger - Bischoff Premium Black Lager')),
#  ('The Walkerville Brewing Company', (5.0, 'Superior Light')),
#  ('Les Brasseurs Du Sornin', (4.5, 'Perle Verte')),
#  ('Sebastopol Brewing Company', (3.0, 'IPA')),
#  ('Brew Wharf', (4.5, 'Light Black')),
#  ('Eldos Grill And Brewery', (3.5, 'Golden Giant')),
#  ('Laverstoke Park Farm', (4.5, 'Organic Real Lager')),
#  ('Bass Brewers Limited', (5.0, 'Worthington Creamflow Bitter')),
#  ('Brok Brewery', (4.5, 'Martin')),
#  ("Martha's Exchange", (5.0, 'Weathertop Doppelbock')),
#  ('Nashoba Valley Winery', (5.0, 'Heron Ale')),
#  ('Redondo Beach Brewing', (5.0, 'Blueberry Wheat')),
#  ('Zagorka Brewery / Pivovaren Zavod Zagorka', (4.5, 'Stolichno Bock')),
#  ('Dogfish Head Brewery', (5.0, 'Palo Santo Marron')),
#  ('Skytop Steakhouse', (5.0, "Aidan Michael's Amber Lager")),
#  ('Main Street Beer Company / Williamsville Brewery',
#   (5.0, "Dergy's Honey Blonde Ale")),
#  ('Brauerei Haag', (4.0, 'Haag Oberdachstetter Hefeweizen')),
#  ('Storchenbräu', (4.0, 'Storchenbräu Helles')),
#  ('Manhattan Beach Brewing Co.', (4.0, 'El Porto')),
#  ('Silver Gulch Brewing and Bottling Co.', (5.0, 'Grand Reserve')),
#  ('Birrificio Hibu', (2.5, 'Köln')),
#  ('Stadsbrouwerij Wittenburg', (3.5, 'De Jonkheer Blond')),
#  ('Greenshields Brewing Co.', (4.0, 'Greenshields India Pale Ale')),
#  ('Privatbrauerei Friedrich Düll', (2.0, 'Krautheimer Heller Bock')),
#  ('Brouwerij De Block bvba', (4.5, 'Special Block 6')),
#  ('Wiibroes Bryggeri', (4.0, 'Wiibroes Porter Imperial Stout')),
#  ('Unertl Weissbier GmbH', (5.0, 'Unertl Weissbier')),
#  ('Square One Brewery', (5.0, 'WheatWine')),
#  ('Straub Brewery', (5.0, 'Straub Beer')),
#  ('Socorro Springs Brewing Company', (4.0, 'Socorro Springs Pick Axe IPA')),
#  ('Allagash Brewing Company', (5.0, 'Allagash Speciale Reserve')),
#  ('New Zealand Breweries Limited', (5.0, 'Steinlager')),
#  ('Cervecería Polar Los Cortijos', (4.5, 'Cerveza Tipo Pilsen')),
#  ('Twisted Pine Brewing Company', (5.0, 'Twisted Pine Hoppy Man IIPA')),
#  ('Electric Brewing Company', (4.0, 'OK Ale')),
#  ('Northwoods Brewpub and Grill', (4.0, 'White Weasel Ale')),
#  ('LoverBeer', (4.5, 'Madamin')),
#  ('Blue Frog Grog & Grill', (4.5, 'The Big DIPA')),
#  ('Pepperwood Bistro', (4.5, 'Pale Ale')),
#  ('Il Forteto', (1.5, 'Vernata')),
#  ('Browar Jab&#322;onowo S.C.', (3.0, 'Piwo Na Miodzie Gryczanym')),
#  ('ShawneeCraft Brewing Company', (5.0, 'Blanche Au Natural')),
#  ('Pasadena Brewing Company', (4.0, 'IPA')),
#  ('Queens Wharf Brewery', (3.0, 'Queens Wharf Newcastle Old')),
#  ('Birra Tenute Collesi SRL', (4.5, 'Imper Ale Ubi Rossa')),
#  ('Titletown Brewing Company', (5.0, 'Weizen Dopplebock')),
#  ('Pivovar Litovel', (4.0, 'Original Litovel Premium')),
#  ('Shikoku Kakou K.K.', (3.5, 'Awa Uzushio Beer Alt')),
#  ('Brauerei Gebrüder Röhrl', (4.5, 'Straubinger Weisse')),
#  ('Angel City Brewing', (5.0, 'Angel City Abbey')),
#  ('Vat Pivobyezalkogolniy Kombinat Krim', (3.0, 'Krim Svitle')),
#  ('Storm Brewing', (5.0, 'Cherry Lambic')),
#  ('Red Dot Brewhouse', (1.0, 'Monster Green Lager')),
#  ('Birrificio Ticinese', (3.5, 'Bad Attitude Rudolph')),
#  ('Onidensetsu Ji-Beer', (4.5, 'Red Ale')),
#  ('North Coast Brewing Co.', (5.0, 'Old Rasputin XI')),
#  ('Tempo Beer Industries LTD', (4.5, 'Gold Star - Black Roast')),
#  ('Bräu im Moos', (3.5, 'Bräu Im Moos Dunkel')),
#  ('Greene King / Morland Brewery', (5.0, 'Abbot Ale')),
#  ('Brouwerij Fisser NV', (4.5, 'Ne Flierefluiter Westelse Tripel')),
#  ('Commonwealth Brewery Ltd.',
#   (4.5, 'Guinness Foreign Extra Stout (Bahamas)')),
#  ('Musikbryggeriet DaCapo', (4.0, 'Maestoso')),
#  ('Nantahala Brewing Company', (5.0, 'Appalachian Trail Extra Pale Ale')),
#  ('Ma&#322;opolski Browar Strzelec', (4.5, 'Strzelec Porter')),
#  ('Great Baraboo Brewing Company', (4.0, 'Snake Eye Canyon Red Ale')),
#  ('Flying Monkey Brewing Company', (4.5, 'Pony Express Rattlesnake Pale Ale')),
#  ('Grolsch Bierbrouwerij N.V.', (5.0, 'Amsterdam Maximator')),
#  ('Cold Storage Craft Brewery', (5.0, 'Florida Avenue Ale')),
#  ('Old Chimneys Brewery',
#   (5.0, 'Old Chimneys Good King Henry Special Reserve')),
#  ('Borsodi Brewery', (4.5, 'Borsodi')),
#  ('Beachwood BBQ & Brewing', (5.0, 'Tovarish')),
#  ('Huttenkloas', (4.0, 'Dubbel Kloat')),
#  ('Northern Rivers Brewing Co.', (4.0, 'Northern Rivers Blonde Ale')),
#  ('Furthermore Beer', (5.0, 'Fallen Apple')),
#  ('Lagerheads Smokehouse & Brewing Co.', (4.0, 'Tyranny')),
#  ('Brewboys', (4.5, 'Ace Of Spades')),
#  ('Creekside Pub & Brewery', (3.0, 'Cat Tail Ale')),
#  ("Mac's Brewery", (4.5, 'Sassy Red')),
#  ('The Gahan House', (4.5, "Gahan House Sir John A's Honey Wheat Ale")),
#  ('C.K. Browar', (4.5, 'Dunkel')),
#  ('Brouwerij Het Sas', (4.5, 'Leroy Paulus')),
#  ("Mick Duff's Brewing Company", (5.0, 'Knot Tree Porter')),
#  ('Mountain Ridge Brewery', (4.0, 'Broughton Pale Ale')),
#  ('Tullycross Tavern & Microbrewery', (4.5, 'TCT Pale Ale')),
#  ('961 Beer', (5.0, '961 IPA (India Pale Ale)')),
#  ('Harvest Moon Brewery', (4.0, 'Elevator Imperial IPA')),
#  ('Cervezas Anaga', (3.0, 'Reina Oro')),
#  ('Beaver Street Brewery & Whistle Stop Cafe', (4.5, 'Railhead Red')),
#  ('Vanberg & DeWulf', (5.0, 'Lambrucha')),
#  ('Ascot Ales', (4.0, 'Alligator American Style Beer')),
#  ('Pivovar Steiger', (4.0, 'Steiger 11% Tmavý')),
#  ('Oasis Brewery', (4.5, 'Tut Brown Ale')),
#  ("Callahan's Pub & Brewery", (5.0, 'Hop Goddess')),
#  ('Whitewater Brewing Co', (4.5, 'Belfast Ale')),
#  ('Red Rose Brewery', (2.5, 'Junipers Ale')),
#  ('Brasserie de Skida', (1.5, 'Ale')),
#  ('Licher Privatbrauerei', (5.0, 'Licher Pils')),
#  ('Potosi Brewing Company', (5.0, 'Snake Hollow IPA')),
#  ('Brasserie Piedboeuf', (4.5, 'Jupiler')),
#  ('Bison Brewing', (5.0, 'Bison Organic Chocolate Stout')),
#  ('Tin Mill Brewing', (4.5, 'Pilsner')),
#  ('Brouwerij De Dolle Brouwers',
#   (5.0, 'De Dolle Stille Nacht Special Reserva 2005')),
#  ('Hawkshead Brewery / Staveley Brewery & Beer Hall',
#   (4.5, 'Hawkshead Lakeland Gold')),
#  ('Chateau Kamiya Hachinohe', (4.5, 'Chateau Kamiya Dunkel')),
#  ('Kraft Bräu - Blesius Garten', (3.5, 'Kraft Brau Weizen')),
#  ('Rahr & Sons Brewing Company', (5.0, 'Winter Warmer')),
#  ('Wuppertaler Brauhaus GmbH', (4.5, '1/2 Weizen Bier')),
#  ('SanTan Brewing Co.', (5.0, "Devil's Ale")),
#  ('Laughing Dog Brewing', (5.0, 'Alpha Dog Imperial IPA')),
#  ('Old Schoolhouse Brewery', (5.0, 'Bush Whacker Ale')),
#  ('Nynäshamns Angbryggeri', (5.0, 'Pickla Pils')),
#  ('Brasserie Val De Sambre', (5.0, 'Heylissem Triple Brune')),
#  ('Hue Brewery LTD', (4.0, 'Hue Beer')),
#  ('Flat 12 Bierwerks', (5.0, "Pogue's Run Porter (formerly Flat12 Porter)")),
#  ('Multi-Brasses', (5.0, 'La Pentecote Blonde')),
#  ('Bowman Ales Ltd.', (4.5, 'Swift One')),
#  ('Tundra Brewery', (3.5, 'Ma-Pale Pale Ale')),
#  ('Italian Oasis Restaurant And Brewery',
#   (4.0, 'Italian Oasis Black Bear Stout')),
#  ('Kloster Kreuzberg', (5.0, 'Kloster Kreuzberg Dunkel')),
#  ('Brauerei Alsfeld AG', (3.5, 'Alsfelder Pilsner')),
#  ("Johansson's Dining House", (5.0, 'Sticke Alt')),
#  ('Bierbrouwerij De Drie Ringen', (4.5, 'Amersfoorts Bokbier')),
#  ('Empresa De Cervejas Da Madeira', (3.0, 'Coral Cerveja')),
#  ('Black Country Ales', (4.0, 'Pig On The Wall')),
#  ('Andwell Brewing Company', (4.5, 'King John')),
#  ('Wolf Brewery Ltd.', (4.5, 'Freedom')),
#  ('Bonnema Brewing Company', (4.5, 'Pozo Pale Ale')),
#  ('New Orleans Lager & Ale Brewing Company (NOLA)', (5.0, 'Hopitoulas IPA')),
#  ('Kingdom Brewers', (5.0, 'Chopping Block India Pale Ale')),
#  ('Phantom Canyon Brewing Company', (5.0, 'Two Headed Dog DIPA')),
#  ('Brasserie Zannekin', (3.0, 'Zannekin Cassel Blanche')),
#  ('Highlander Brew Co.', (4.0, 'Pale Ale')),
#  ('Lucky Labrador Brewing Company', (5.0, 'Blue Dog Pale Ale')),
#  ("Eske's Brew Pub & Eatery", (4.5, 'Artist Ale')),
#  ('Landmark Brewing Company', (5.0, 'India Red Ale')),
#  ('Indslev Bryggeri', (4.0, 'Sort Hvede')),
#  ('Åsundens Bryggeri', (4.0, 'Asundi')),
#  ('Craft Brewing Company', (4.0, 'Raven Stout')),
#  ('Barossa Brewing Company', (4.0, "Barossa Brewing The Miller's Lager")),
#  ('Beauce Broue', (3.5, 'Maple Pale Ale')),
#  ("Brasserie Kerav'ale", (4.0, 'Eost Du')),
#  ('Nihonkai Yuhi Brewery', (3.5, 'Koshihikari Lager')),
#  ('Rivertowne Pourhouse', (5.0, 'Drunken Leprechaun')),
#  ('Shipyard Brewing Co.',
#   (5.0, "Shipyard Imperial Porter (Pugsley's Signature Series)")),
#  ('Stone Coast Brewing Co.', (5.0, 'Jamaican Style Stout')),
#  ('Stieglbrauerei zu Salzburg GmbH', (5.0, 'Original Stieglbock')),
#  ('Brouwerij De Koninck NV', (5.0, 'De Koninck')),
#  ('Rother Valley Brewing Co.', (4.5, 'Rother Valley Level Best')),
#  ("Pinglehead Brewing Co. / Brewer's Pizza", (5.0, 'Nine Voices')),
#  ('Old North State Winery And Brewery', (4.0, 'Old North State IPA')),
#  ('Ahlafors Bryggerier AB', (4.5, 'Ahlafors Kåtisbock')),
#  ('Nikko Brewing', (4.0, 'Nikko Premium Beer')),
#  ("BJ's Chicago Pizza & Brewery Inc.", (5.0, 'Nutty Brewnette')),
#  ('Café-Brouwerij Loterbol', (5.0, 'Loterbol Bruin')),
#  ('Hirschbrauerei GmbH & Co. KG', (4.0, 'Hirsch Pils')),
#  ('Tuscan Brewing', (4.5, 'Paradise Pale Ale')),
#  ("Ham's Restaurant & Brewhouse", (5.0, 'Blasphemy')),
#  ('Kikazakura K.K.', (2.0, 'Kuranokahori')),
#  ('Lautertaler Hausbrauerei', (4.0, 'Drachenblut')),
#  ('Charlis Brygghus', (4.0, 'Lakriz')),
#  ('Bierbrouwerij De Boei', (4.0, 'Hoornder Loods Bier (Zeeschuimer)')),
#  ('Serengeti Breweries Ltd', (4.0, 'Premium Serengeti Lager')),
#  ('Brasserie Augrenoise', (4.0, 'Augrenoise')),
#  ('Oskar Blues Grill & Brew', (5.0, 'Old Chub - Scottish Style Ale')),
#  ('Roy Pitz Brewing Company', (5.0, 'Lovitz Lager')),
#  ('Shoes Brewery', (4.0, "Farriers' Beer")),
#  ('Black Forest Brew Haus', (5.0, 'Black Forest Schwarzbier')),
#  ('Otter Brewery Ltd', (5.0, 'Hoppy Otter IPA')),
#  ('La Grihète', (5.0, 'La Grihète Ambrée')),
#  ('Ursus S.A. (SAB) / Compania de Bere Romania', (4.5, 'Bere Timisoreana')),
#  ('Microbrasserie Archibald', (5.0, 'Chipie')),
#  ('Yakima Craft Brewing Co.', (5.0, 'IPA')),
#  ('Jack Black Beer', (4.0, 'Jack Black Brewers Reserve Classic Lager')),
#  ('Augusta Brewing Company', (4.5, 'Augusta Saison')),
#  ('Wibblers', (4.0, 'Wibblers Wobbly Wabbit')),
#  ('Finlandia Sahti Ky', (4.5, 'Finlandia Sahti')),
#  ('Bellarine Brewing Co.', (3.5, 'Mussel Stout')),
#  ('Brasserie Basabürüa', (2.5, 'Akerbeltz Ambrée Gorrosta')),
#  ('Athenian Brewery', (4.5, 'Alfa')),
#  ('Maltovivo', (4.0, 'Noscia')),
#  ('Dugges Ale- & Porterbryggeri AB', (5.0, 'High Five!')),
#  ('Clanconnel Brewing Company', (4.5, 'Weavers Gold')),
#  ('Brouwerij De Ryck', (4.5, 'Arend Tripel')),
#  ('Seabright Brewery', (5.0, 'Vicenary Position Pilsner')),
#  ('Paulaner Bräuhaus', (4.0, 'Paulaner Bräuhaus Thomas Aktions Festbier')),
#  ('La Micro de Bromont', (4.0, 'Chanvre Rouge')),
#  ('Luckie Ales', (4.5, 'Brown Stout')),
#  ('Spitalbrauerei Regensburg', (4.0, 'Spital Dunkel')),
#  ('Adirondack Pub & Brewery', (4.5, 'Double IPA')),
#  ('Black Rock Brewing Co.', (4.0, 'Rocktoberfest')),
#  ('San Luis Valley Brewing Company', (4.5, 'Hefe Suave')),
#  ('Boundary Bay Brewery & Bistro', (5.0, 'Cabin Fever Winter Ale')),
#  ('Mauldons', (5.0, 'Silver Adder')),
#  ('Logsdon Farmhouse Ales', (5.0, 'Seizoen')),
#  ("BJ's Restaurant", (4.0, 'Harvest Hefeweizen')),
#  ('Central Waters Brewing Company', (5.0, 'Brewhouse Coffee Stout')),
#  ('Alandale Brewing Company', (4.5, 'Amber Ale')),
#  ('Hinterland Brewery Restaurant', (5.0, 'Bourbon Stout')),
#  ('Hausbrauerei Zum Schlüssel', (5.0, 'Original Schlüssel Alt')),
#  ("Cally's Restaurant and Brewing Co.", (5.0, "Smokin' Scottish Ale")),
#  ('Last Drop Brewery', (4.0, 'Last Drop Bock')),
#  ('De Hoevebrouwers', (5.0, 'Toria')),
#  ('El Toro Brewing Co.', (5.0, 'El Toro Deuce Imperial IPA')),
#  ('Linden Brauerei GmbH', (4.0, 'Finkbrau Blonde Lager')),
#  ('Beer House', (3.5, 'Märzen Speziel')),
#  ('Birrificio Spluga', (1.5, 'Spluga Pils')),
#  ('St. George Brewery', (4.0, 'St. George Lager')),
#  ('Mistura Clássica', (4.0, 'Mistura Clássica Strong Dark Ale')),
#  ('Old Yale Brewing Co.', (5.0, 'Sasquatch Stout')),
#  ('Maple Valley Brewing Company', (4.5, "Druid's Double IPA")),
#  ('Brouwerij Het Anker', (5.0, 'Gouden Carolus Ambrio')),
#  ('Barley Creek Brewing Company', (5.0, 'Antler Brown Ale')),
#  ('Steam Exchange Brewery', (4.5, 'Steam Exchange Steam Ale')),
#  ('Hardknott Brewery', (4.0, 'Infra Red')),
#  ('Brouwerij Van den Bossche', (5.0, 'Pierre Celis Memoirs Triple Ale')),
#  ('Atlantic Brewery', (4.0, 'Atlantic Blue')),
#  ('Inuyama Loreley Beer', (4.0, 'Pilsener')),
#  ('Grimm Brothers Brewhouse', (5.0, 'Snow Drop')),
#  ('Big Rock Brewery', (5.0, 'Grasshopper')),
#  ('Alaskan Brewing Co.', (5.0, 'Alaskan White')),
#  ('OPZ Saransk', (3.0, 'Tolstyak Svetloye')),
#  ('Riverport Brewing Company', (4.5, 'Cedar Rock Pale')),
#  ("Bill's Tavern & Brewhouse", (4.5, 'Duckdive Pale Ale')),
#  ('Browary Bydgoskie Sp. Z O.o. (Brau Union Polska)', (4.5, 'Kujawiak')),
#  ('Meantime Brewing Company Limited', (5.0, 'India Pale Ale')),
#  ('Brauerei Göss (Brau Union)', (5.0, 'Gösser')),
#  ('Mythos Breweries S.A.', (4.5, 'Mythos Hellenic Lager Beer')),
#  ('Birdsview Brewing Company', (5.0, 'Lights Out')),
#  ('Wild Wolf Brewing Company', (4.0, 'Alpha Ale')),
#  ('Hill Farmstead Brewery', (5.0, 'Florence Organic Wheat Saison')),
#  ('Bruggsmiðjan', (4.0, 'Jóla Kaldi 2008')),
#  ('2 Brothers Brewery', (5.0, 'Growler American Brown Ale')),
#  ('Brauhaus Simon Strasser', (3.5, 'Gauder Bock')),
#  ('Ilkley Brewery Co.', (4.5, 'Mary Jane')),
#  ("Brasserie D'Annoeulin", (4.5, 'Angelus')),
#  ('Bandersnatch Brewpub', (4.5, 'Bandersnatch Pog No Thon Stout')),
#  ('Great White North Craft Brewery', (4.0, 'Port Arthur Pale')),
#  ('Ørbæk Bryggeri', (4.5, 'Pale Ale')),
#  ('Privatbrauerei M.C. Wieninger',
#   (5.0, 'Wieninger Helles Lagerbier Premium')),
#  ('Sillamäe Õlletehas', (3.0, 'München Vaskne')),
#  ('Broken Drum Brewery And Wood Grill', (4.0, 'IPA')),
#  ('Southern Star Brewing Company', (5.0, 'Pro-AM 2010 (Smoked Porter)')),
#  ('Günther Bräu', (4.5, 'Günther Bräu Bockbier')),
#  ('Pardubický pivovar a.s.', (5.0, 'Porter Boom')),
#  ('Le Trou Du Diable',
#   (5.0, 'La Buteuse Brassin Spécial  (750-mL Barrel Aged)')),
#  ('Wild River Brewery & Pizza Company', (4.5, 'Double Eagle Imperial Stout')),
#  ('Bi-Du', (4.0, 'Ley Line')),
#  ('The Defiant Brewing Company', (5.0, "The Horseman's Ale")),
#  ('Coldstream Brewery', (5.0, 'Coldstream Bitter')),
#  ("Bierbrouwerij 't Vølendam", (4.0, 'Pijtje')),
#  ('Caldera Brewing Company', (5.0, 'Mogli')),
#  ('7 Seas Brewery and Taproom', (5.0, 'Ballz Deep Double IPA')),
#  ('Calapooia Brewing Company', (5.0, 'Calapooia Barleywine')),
#  ('Hokusetsu Brewery', (4.0, 'Nobu Special Reserve')),
#  ('Isle Of Skye Brewery', (5.0, 'Black Cuillin')),
#  ('Founders Brewing Company', (5.0, 'Founders Newaygo County Cherry')),
#  ('Pivovarna Laško', (4.5, 'Zlatorog')),
#  ('Cambridge Brewing Company', (5.0, 'Spring Training IPA')),
#  ('Bath Ales Ltd', (5.0, 'Barnstormer')),
#  ('Great Basin Brewing Co.', (5.0, 'Ichthysaur IPA')),
#  ('Cooperstown Brewing Company', (5.0, 'Nine Man Ale Golden Ale')),
#  ('Big Hurt Brewing Company', (3.5, 'Big Hurt Beer')),
#  ('McMenamins Queen Anne Hill', (5.0, 'Javaspresso Nitro Stout')),
#  ('Brouwerij Ter Dolen N.V.', (4.5, 'Ter Dolen Tripel')),
#  ('Colorado Mountain Brewery', (3.5, 'Panther India Pale Ale')),
#  ('Rinkuškiai Alaus Darykloje', (5.0, 'Werewolf')),
#  ('Brauerei Heller-Trum / Schlenkerla',
#   (5.0, 'Aecht Schlenkerla Rauchbier Weizen')),
#  ('Brasserie Nationale (Bofferding)', (2.0, 'Battin Extra')),
#  ("O'so Brewing Company", (5.0, 'Lupulin Maximus Imperial IPA')),
#  ('Kolos OAO/ Ledyanoy Stakanchik', (3.0, 'Zhigulovskoye')),
#  ('Brauerei Gilde', (4.5, 'Gilde Lindener Spezial Premium Beer')),
#  ('Cannon Brew Pub', (4.5, 'Special Ops IPA')),
#  ('Cheriton Brewery', (5.0, 'Pots Ale')),
#  ('Nail Creek Pub & Brewery', (4.0, 'Belgian Double')),
#  ('Summit Station Restaurant & Brewery', (4.5, 'IPA')),
#  ('Scarampola', (3.0, 'IPA Italian Pale Ale')),
#  ('The Big Cheese Pizza Co.', (4.5, 'Spiced Maibock')),
#  ('Brouwerij Slaapmutske', (5.0, 'Kerstmutske Christmas Nightcap')),
#  ('Melchers Group', (3.5, 'Gold Lager Beer')),
#  ('Hofbrauhaus Berchtesgaden', (4.0, 'Hofbrauhaus Berchtesgaden Hell')),
#  ('Les Brasseurs de Gayant', (5.0, 'Goudale')),
#  ('Robinsons Family Brewers', (5.0, "Robinson's Dizzy Blond Light Bitter")),
#  ('Guangzhou Zhujiang Brewery Co. Ltd.', (5.0, 'Zhu Jiang Draft Beer')),
#  ('Via Priula', (2.5, 'Bacio')),
#  ('C.B. & Potts', (4.5, 'Apricot Ale')),
#  ('Zum Löwenbräu', (3.5, 'Aischgründer Karpfen-Weisse')),
#  ('Brasserie De Clerck', (4.0, 'Poppy')),
#  ('BFM Brasserie Des Franches-Montagnes',
#   (5.0, 'Abbaye De Saint Bon-Chien Grand Cru (Aged In Cabernet Barrels)')),
#  ('Brouwerij Roman N.V.', (5.0, 'Adriaen Brouwer Dark Gold Ale')),
#  ("Hale's Ales Brewery & Pub", (5.0, "Hale's Red Menace Big Amber")),
#  ('Four Peaks Brewing Company', (5.0, 'Kilt Lifter Scottish Style Ale')),
#  ('Brouwerij Clarysse NV', (3.5, 'St. Hermes')),
#  ('Herslev Bryghus', (5.0, 'Høst Bryg Kirsebær')),
#  ('Halifax Steam Brewing Company Ltd', (3.0, 'Luftkissenfahrzeug')),
#  ('Martini Brauerei GmbH', (4.0, 'Martini Weissbier Hell')),
#  ('Sonoma Springs Brewing Co.', (4.5, 'RyePA')),
#  ('Schmohz Brewing Company', (5.0, 'Pail Ale')),
#  ('16 Mile Brewing Company', (5.0, 'Old Court Ale')),
#  ('Keltic Brewing Company', (4.0, "McCeol's Irish Red Ale")),
#  ('Micro Cervejaria Bamberg', (5.0, 'Tcheca')),
#  ('Keuka Brewing Company', (4.5, 'Hoppy Laker IPA')),
#  ('McCall Brewing Company', (4.0, 'Secesh Scotch Ale')),
#  ('Black Raven Brewing Co.',
#   (5.0, 'Black Raven IV Imperial Rye Stout - Malt & Vine 4th Anniversary')),
#  ('Engelbräu Rettenberg', (3.5, 'Grüntengold')),
#  ('Microbrasserie la Memphré', (3.0, 'La Blonde Du Boss')),
#  ('Galway Bay Brewery', (3.5, 'Bay Lager')),
#  ("Saint Katherine's Brewing Company", (4.0, "St. Katherine's Tawny Ale")),
#  ('Buffalo Brewery (Aus.)', (3.5, 'Dark Ale')),
#  ('Genesee Brewing Co. / Dundee Brewing Co.', (5.0, 'Genesee Red Lager')),
#  ('Rheingold Brewing Co.', (5.0, 'Rheingold Beer')),
#  ("Rogue's Roost Brew Pub & Eatery", (5.0, 'Weizen')),
#  ('Bristol Brewing Company', (5.0, "John's Edge City Pale Ale")),
#  ('Original Gravity Brewing Company', (5.0, '440 Pepper Smoker')),
#  ('To Øl', (4.5, 'Final Frontier IIPA')),
#  ('Brauerei Forst AG', (5.0, 'Forst Premium')),
#  ('High House Farm Brewery', (5.0, 'Auld Hemp')),
#  ('Nelson Brewing Company', (5.0, 'Paddywhack IPA')),
#  ("Scottish Chief's Tavern Brewery", (4.5, "What's Brewing? Pale Ale")),
#  ('Brauerei Hofstetten Krammer GmbH & Co. KG', (5.0, 'Saphir Bock')),
#  ('Stallhagens Bryggeri Ab', (4.5, 'Stallhagen Dark Lager')),
#  ('Werner Bräu GmbH', (4.0, 'Werner Hefe Weissen Hell')),
#  ('Big City Brewing CO LTD', (4.5, 'Jamaica Stout')),
#  ('Aberdeen Brewing Company', (4.0, 'County Porter')),
#  ('Auerhahn Bräu Schlitz GmbH', (4.0, 'Dark')),
#  ('Arbor Brewing Company', (5.0, 'Arbor Brewing Bavarian Bliss')),
#  ('New Old Lompoc Brewery', (5.0, 'Oak Aged Doppel Bock')),
#  ('Burleigh Brewing Co.', (5.0, 'Duke Pale Ale')),
#  ('Ribe Bryghus', (4.5, 'Ribe Blond Ale')),
#  ('Brauerei Bischofshof', (5.0, 'Pralat Pilsener')),
#  ('St. Sebastiaan Belgian Microbrewery', (4.5, 'Spring Hill Blonde')),
#  ('Hook Norton Brewery Co. Ltd.', (5.0, 'Old Hooky')),
#  ('Argus Brewery', (5.0, 'Country House Red Ale')),
#  ('OWA Beer', (3.5, 'OWA')),
#  ('Howard Town Brewery', (4.5, "Wren's Nest")),
#  ('Cervejaria Petrópolis', (4.5, 'Itaipava Pilsen')),
#  ('Shinano Brewery Vanryu / Chestnut Pub', (5.0, 'Kurohime Stout')),
#  ('Brewbakers', (4.5, 'Elden Ales Pale Ale')),
#  ('River City Brewing Co.', (4.5, 'Baby Bock')),
#  ("Brasserie d'Oc", (4.5, 'La Mouska')),
#  ('Halsnæs Bryghus', (4.0, 'Fabritius Pale Ale')),
#  ('Roc Brewing Company', (3.0, 'Saison')),
#  ('Mt. Emily Ale House', (4.0, 'Snake River IPA')),
#  ('Brasserie Artisanale De Rullés SPRL',
#   (5.0, 'La Rullés Estivale (Bière De Gaume)')),
#  ('New Belgium Brewing', (5.0, 'Love (Apple Whiskey Barrel Aged)')),
#  ('The Porterhouse Brewing Company', (5.0, 'Oyster Stout')),
#  ('Cerveceria Costa Rica', (5.0, 'Pilsen')),
#  ('Brauerei Schloss Starkenberg', (5.0, 'Starkenberger Gold Lager')),
#  ('Hopdaemon Brewery Company', (5.0, 'Hopdaemon Skrimshander IPA')),
#  ('Amherst Brewing Co.', (5.0, 'Massatucky Brown')),
#  ('Brouwerij De Vlier', (3.5, 'Kessel X-Mas')),
#  ('Bowral Brewing Company', (4.5, 'Pigs Fly Pale Ale')),
#  ('Lennet Brau- Und Vertriebsgesellschaft', (3.5, 'Lennet Bier')),
#  ('Salopian Brewing Company Ltd', (5.0, 'Entire Butt English Porter')),
#  ('Odonata Beer Company', (5.0, 'Saison (Bottle)')),
#  ('Huisbrouwerij Sint Canarus', (5.0, 'Sint Canarus Tripel')),
#  ('Tun Tavern', (4.5, 'Tun Dark')),
#  ('Crazy Mountain Brewing Company', (5.0, 'Crazy Mountain Amber Ale')),
#  ('Brasserie Alauna', (4.0, 'Blonde Alauna')),
#  ('Brauerei Franz Xaver Glossner', (4.0, "Glossner Torschmied's Dunkel")),
#  ("Witch's Hat Brewing Co.", (4.5, 'Holy Confusion Barley Wine')),
#  ('Erve Kots Brouwerij', (3.0, 'Bokse Achterhoeks Witbier')),
#  ('Ben Middlemiss Brewing', (4.5, 'Benediction Ale')),
#  ('BABB Srl', (4.0, 'Rubinia')),
#  ("Maihama Beer Koubou Harvestmoon Brewery At Roti's House",
#   (4.0, 'Belgian Style Wheat')),
#  ('Market Cross Pub & Brewery', (5.0, "Bessie's Brown Ale")),
#  ('Hangtown Brewery', (4.0, 'Hangtown Vanilla Stout')),
#  ('Three Creeks Brewing Co.', (4.5, "Rudolph's Imperial Red Ale")),
#  ('Frosty Knuckle Brewing Company', (4.5, 'Frosty Knuckle Ale')),
#  ('McCallum Brewery', (4.0, '3 Coins Malt Lager')),
#  ('Baltimore Brewing Company', (5.0, "DeGroen's Pils")),
#  ('Brimstage Brewing Co Ltd', (5.0, 'Trappers Hat')),
#  ("Brasserie D'Ecaussinnes", (5.0, 'Ultra')),
#  ('Brasserie Artisanale La Frasnoise', (4.0, 'Givrée Frasnoise')),
#  ('Brouwerij Mort Subite', (5.0, 'Eylenbosch Gueuze')),
#  ('Telegraph Brewing Company', (5.0, 'California Ale')),
#  ('Southampton Publick House', (5.0, 'Southampton May Bock')),
#  ("BJ's Restaurant & Brewhouse", (5.0, 'Rye Pale Ale')),
#  ('Dead Frog Brewing', (4.5, 'Pale Ale')),
#  ('Brewsters Brewing Company & Restaurant - Eleventh Avenue',
#   (4.5, 'Blue Monk Barleywine')),
#  ('Market Garden Brewery', (4.5, 'Viking Pale Ale')),
#  ('Mystic Brewery', (4.5, 'Descendant Suffolk Dark Ale')),
#  ('High Point Brewing Company', (5.0, 'Ramstein Blonde Wheat Beer')),
#  ("Twain's Billiards and Tap", (5.0, "Twain's Mad Happy Pale Ale")),
#  ('Dama Bier', (3.5, 'Dama India Pale Ale')),
#  ('Etna Brewery', (5.0, 'Clubfoot Ale')),
#  ('Biha&#263;ka Pivovara', (4.0, 'Preminger')),
#  ("Stockholm's", (3.5, 'Aegirs Ale')),
#  ('Stoney Creek Brewing Company', (5.0, 'Stoney Creek Vanilla Porter')),
#  ('Gamla Stans Bryggeri', (4.5, 'Färsköl')),
#  ('Officina Della Birra', (3.5, 'BS Birra Scura Artigianale')),
#  ('Boston Beer Company (Samuel Adams)',
#   (5.0, 'LongShot Mile High Barley Wine Ale')),
#  ('Nimbus Brewing Company', (5.0, 'Nimbus Dirty Güera (Blonde) Ale')),
#  ('Princetown Breweries Limited', (2.5, 'Princetown Jail Ale')),
#  ('Ferme Brasserie Garland', (3.5, 'Karland Ambrée')),
#  ('Matten', (4.0, 'La Schwortz')),
#  ("Mary's Pizza Shack", (3.5, 'Capadanno Winter Ale')),
#  ('North End Tavern & Brewery', (5.0, 'India Pale Ale')),
#  ('Elevation 66 Brewing', (3.5, 'East Bay IPA')),
#  ('Jailhouse Brewing Company', (5.0, 'Mugshot IPA')),
#  ('Hopworks Urban Brewery', (5.0, 'Revolver Single Hop Pale Ale')),
#  ('Pabst Brewing Company', (5.0, 'Rainier Ale')),
#  ('Metropolitan Brewing', (5.0, 'Krankshaft Kölsch')),
#  ('Brasserie Du Canardou', (4.5, 'La Nonnette')),
#  ('Carlyle Brewing Company', (5.0, 'Scottish Ale')),
#  ('Harts Pub / Rocks Brewing Co.', (4.0, 'The Butcher')),
#  ('Mulholland Brewing Company', (4.5, 'Le Strange Trippel')),
#  ('Bridestones Brewing Company Limited', (4.0, 'Pennine Gold')),
#  ('Feldschloesschen AG', (4.5, 'Schwarzer Steiger')),
#  ('Triton Brewing Company', (5.0, 'Magnificent Amber')),
#  ('Tampa Bay Brewing Co.', (5.0, 'Jack The Quaffer Porter')),
#  ('Wentworth Brewery Limited', (4.5, 'Admiral Keppel')),
#  ('Slavutych Brewery', (5.0, 'Slavutych Pivo (Slavutich Premium)')),
#  ('Hops Grillhouse & Brewery', (4.5, 'Thoroughbred Red')),
#  ('Elk Head Brewing Company', (4.5, 'Royal Black')),
#  ('North Star Craft Brewery', (4.5, 'IPA')),
#  ('Cervecera Regional', (3.0, 'Cerveza Queretaro')),
#  ("Dempsey's Restaurant And Brewery", (4.0, 'Sonoma Irish Style Ale')),
#  ('WinterCoat', (5.0, 'WinterCoat Cockney Imperial Stout')),
#  ...]

# %%
# STEP 4
start_time4 = time.time()

processed_rdd = split_rdd.map(lambda x: (x[2], (float(x[4]),1)))

summed_ratings_rdd = processed_rdd.reduceByKey(lambda x,y: (x[0]+y[0], x[1]+y[1]))

avg_reviews_rdd = summed_ratings_rdd.mapValues(lambda x: round(x[0]/x[1], 3))

end_time4 = time.time()
elapsed_time4 = end_time4 - start_time4
elapsed_times_list.append(elapsed_time4)
print(f"Elapsed time: {elapsed_time4} seconds")

avg_reviews_rdd.collect()
# Out:
# Elapsed time: 0.012362241744995117 seconds
# [('Pacific Coast Brewing Company', 3.432),
#  ('Asmara Breweries', 4.0),
#  ('Bernard Family Brewery', 3.813),
#  ('Otro Mundo Brewing Company', 3.227),
#  ("Emmett's Brewing Company", 3.85),
#  ('Becker Brewing Company', 3.75),
#  ('Birrificio Indipendente Elav', 3.0),
#  ('Stakhanovitz', 2.583),
#  ('Richmodis-Bräu', 4.0),
#  ('Privatbrauerei Hösl', 4.167),
#  ('Spanish Springs Brewing Company', 3.542),
#  ('Archers Brewing & Wholesale Limited', 3.357),
#  ('Lido Atputas Centrs', 3.75),
#  ('Sternquell Brauerei Plauen', 3.333),
#  ('Cerveceros Krut S.L.', 4.0),
#  ('Riverside Brewing Company', 2.75),
#  ('Speciaalbierbrouwerij Oijen', 3.417),
#  ('Benny Brewing Company', 4.5),
#  ('Ancient Lakes Brewing Company', 3.5),
#  ('Klosterbrauerei Weltenburg', 3.918),
#  ('Mountaineer Brewing Co.', 3.616),
#  ('Island Cafe & Brew Pub', 3.0),
#  ("Gentle Ben's Brewing Company", 3.767),
#  ('Ufford Ales Ltd.', 3.0),
#  ('Streets Of New York / Uptown Brewery', 3.4),
#  ('Harar Beer Factory', 3.407),
#  ('Mornington Peninsula Brewery', 3.883),
#  ('Outer Banks Brewing Station', 3.904),
#  ('Tenaya Creek Brewery', 3.566),
#  ('W.H. Brakspear & Sons plc', 3.85),
#  ('St. Peters Brewery (Australia)', 3.438),
#  ('Kölner Verbund Brauereien GmbH & Co. KG', 2.3),
#  ('Allendale Brew Company Limited', 2.333),
#  ('Three Heads Brewing', 3.833),
#  ('Brauerei Georg Michael GmbH', 4.0),
#  ('Odd Side Ales', 3.727),
#  ('Blue Tractor BBQ & Brewery', 4.0),
#  ('Mallard Brewery', 4.0),
#  ("Mike's Organic Brewery", 3.5),
#  ('Coopers Brewery Limited', 3.597),
#  ('Brouwerij Strubbe', 3.646),
#  ('Red Oak Brewery', 3.716),
#  ('Aztec Brewing Company', 3.722),
#  ('Kamchatskoye Pivo OAO', 3.5),
#  ('Eschweger Klosterbrauerei', 4.25),
#  ("Barney's Beer", 3.5),
#  ('Kichesippi Beer Co.', 3.022),
#  ('Water Street Brewing & Ale House', 2.5),
#  ('Brasserie Brootcoorens', 3.767),
#  ('Stillwater Artisanal Ales', 3.963),
#  ('Mack Bryggeri', 2.864),
#  ('Oakshire Brewing', 3.725),
#  ('Brauerei August Gleumes GmbH', 4.5),
#  ('Fountain Square Brewing Co.', 4.0),
#  ('Browar Fortuna', 3.5),
#  ("Galbraith's Alehouse", 3.472),
#  ('Blue Cat Brew Pub', 3.545),
#  ('Euskal Garagardoa S.L.', 2.611),
#  ('White Rabbit', 3.64),
#  ('BrewPub København', 3.875),
#  ("Windsor Castle Brewery (Sadler's Ales)", 3.429),
#  ('Brasserie Vanuxeem', 3.571),
#  ('Cigar City Brewing', 4.023),
#  ('Big Rapids Brewing Co.', 3.625),
#  ('Port Brewing Company / Pizza Port', 3.999),
#  ('Pivovar Janá&#269;ek', 2.875),
#  ('Ginga Kogen Beer', 3.833),
#  ('Capitol City Brewing Company', 3.891),
#  ('Cervejaria Schornstein', 3.75),
#  ('SBC Restaurant & Brewery - Milford', 3.5),
#  ('Steelback Brewery', 2.032),
#  ('Brouwerij Martens NV', 2.876),
#  ('De Fontein', 3.75),
#  ('Chastnaya Pivovarnya Erstes', 3.6),
#  ('Eastern Shore Brewing', 3.115),
#  ('Long Trail Brewing Co.', 3.816),
#  ('Brauerei Diebels GmbH & Co KG', 3.88),
#  ('Blue Hills Brewery', 3.487),
#  ('Black Fox Brewing', 4.0),
#  ('Gage Roads Brewing Company', 3.5),
#  ('Colonial Brewing Company', 3.717),
#  ('Bootleg Brewery', 3.405),
#  ('Holdens Brewery Limited', 3.833),
#  ('Bavarian Barbarian Brewing Company', 3.755),
#  ('Ludwig Roth Bierbrauerei GmbH', 5.0),
#  ('Saku Brewery LTD', 3.389),
#  ("Facer's Flintshire Brewery", 5.0),
#  ('Yellowstone Valley Brewing Co.', 3.609),
#  ('Bank Top Brewery', 3.562),
#  ('Pivovarna Union', 2.425),
#  ('Bozeman Brewing Company', 3.688),
#  ('Triscele Srl', 3.333),
#  ('Zweite Schweriner Schlossbrauerei', 3.2),
#  ('Silver Creek Brewing Co.', 3.926),
#  ('Carlsberg-Tetley Brewing Ltd', 3.671),
#  ("Cooper's Cave Ale Company", 2.8),
#  ("Beermann's Beerwerks", 3.594),
#  ('Blue Monkey Brewery', 3.875),
#  ('Gallia Omnia', 3.0),
#  ('Pivovaren Zavod Ledenika', 3.3),
#  ("Welton's Brewery", 3.2),
#  ("Artisan's Brewery & Italian Grill", 3.196),
#  ('Starr Hill Brewery', 3.652),
#  ('Tuckerman Brewing Co.', 3.764),
#  ('The Bier Brewery', 4.207),
#  ('Llupols I Llevats S.L.', 3.667),
#  ('Cervecería Artesanal Mastra', 3.1),
#  ('Fanø Bryghus', 4.0),
#  ('Janake Wine Group AB', 2.0),
#  ('Mogollon Brewing Company', 3.862),
#  ('Sunday River Brewing Co.', 3.708),
#  ('Lonerider Brewing', 3.96),
#  ("Dave's BrewFarm", 4.048),
#  ('Brauerei Maisach - Bräustüberl Maisach', 4.0),
#  ('La Brasserie Du Val De Drôme', 3.25),
#  ('Två Bryggare - Österlenbryggarna (Ysta Bryggeri)', 2.5),
#  ('Crown City Brewery', 4.0),
#  ('Kauzen Bräu', 4.0),
#  ("Brouwerij 't Gaverhopke", 3.806),
#  ('New England Brewing Co.', 4.061),
#  ('Porter Brewing Co. Ltd.', 4.5),
#  ('Big Beaver Brewing Co.', 3.895),
#  ('Hops Grill & Brewery', 3.417),
#  ('Lipetskpivo', 3.0),
#  ('Aarhus Bryghus', 3.5),
#  ("Max Lager's American Grill & Brewery", 3.704),
#  ('Balmain Brewing Company', 2.833),
#  ('Abteibrauerei Siegburger Brauhaus - FritzAle', 1.5),
#  ('Brauerei Zoller-Hof', 2.833),
#  ('Cerveceria Artesanal Toro', 2.0),
#  ('Roppelt-Bräu Trossenfurt', 4.0),
#  ('Les Frères Houblon Microbrasserie', 2.824),
#  ('Brasserie Du Chant Du Loup', 3.167),
#  ('Krugher & Brent', 3.0),
#  ('Industrial Norte Paranaense De Bebidas Ltda', 2.0),
#  ('Haneda Shuzo Y.K.', 3.5),
#  ('Rock Art Brewery', 3.696),
#  ('Stevens Point Brewery', 3.552),
#  ('Brasserie Des Géants', 3.637),
#  ("Naylor's Brewery", 3.625),
#  ('Kapplerbräu', 3.833),
#  ("Bootlegger's Brewery", 3.906),
#  ('Mudgee Brewing Co', 3.611),
#  ('Griesedieck Brothers Brewery Co.', 3.929),
#  ('Baltika-Baku', 3.0),
#  ('Waiheke Island Brewery Ltd', 3.375),
#  ('San Marcos Brewery & Grill', 3.229),
#  ('Ishikari Banya No Ji-Beer', 4.0),
#  ('Pater Van Damme', 4.0),
#  ('Bondi Beer Company', 1.625),
#  ('AuerBräu AG', 3.714),
#  ('Berliner Bürgerbräu GmbH', 3.432),
#  ('Roel Brewery', 3.0),
#  ('Kulturbrauerei Heidelberg', 4.0),
#  ('The Wheat Beer Company', 1.25),
#  ('London Fields Brewery', 2.75),
#  ('South East Asia Brewery', 2.667),
#  ('Barnaul Brewery', 3.25),
#  ('The Merchant Ale House Restaurant & Brewpub', 3.391),
#  ('Tracks Brewpub (Duplicate)', 2.75),
#  ('Molson Coors Canada', 3.028),
#  ('Murree Brewery Co. Ltd.', 3.0),
#  ('Purity Brewing Co', 3.94),
#  ('Jilin Yinpu Brewery', 2.761),
#  ('Brauerei Grandauer - Wildbräu Grafing vor München', 3.375),
#  ('Feral Brewing Co.', 3.85),
#  ('Abita Brewing Co.', 3.562),
#  ('Mishawaka Brewing Company', 3.141),
#  ('Brouwerij Meesters', 4.0),
#  ('Grand Rapids Brewing Co', 3.1),
#  ('Moles Brewery (Cascade Drinks Limited)', 2.167),
#  ('Pivovar Bašta (Sousedský Pivovar U Bansethů)', 3.0),
#  ('Moosehead Breweries Ltd.', 3.273),
#  ('Noble Ale Works', 3.629),
#  ('Shaftebury Brewing Company', 3.383),
#  ('Lucid Brewing', 3.875),
#  ('Maine Beer Company', 4.218),
#  ('Schlossbrauerei Stein Wiskott GmbH & Co. KG', 2.5),
#  ('Beach Chalet Brewery and Restaurant', 3.698),
#  ('Round Barn Brewery', 3.718),
#  ('Klinskiy Pivokombinat', 2.618),
#  ('Brauerei Reichold', 4.0),
#  ('Redwood Curtain Brewing Company', 4.333),
#  ('Element Brewing Company', 3.991),
#  ('Postbrauerei Weiler u. Siebersquelle Anton Zinth KG', 2.5),
#  ('Empire Brewing', 3.5),
#  ('Sprig & Fern Brewery', 3.5),
#  ('Gebr. Sünner GmbH & Co. KG', 4.062),
#  ('Liechtensteiner Brauhaus', 3.0),
#  ('Brasserie De Milly', 3.5),
#  ('Skye Book And Brew', 3.429),
#  ("Brasserie Grain d' Orge (Brasserie Jeanne d'Arc SA)", 3.236),
#  ('Deka Brewery', 3.333),
#  ('Thirsty Crow', 4.0),
#  ('Povolzhye OAO', 3.0),
#  ('Birra Peja', 3.4),
#  ('Bowland Beer Company Limited', 3.429),
#  ('E & O Trading Company', 4.0),
#  ('Frankenmuth Brewery', 3.668),
#  ('Le Moulin De Saint Martin', 3.0),
#  ('Amarcord Birra Artigianale Italiana', 3.231),
#  ('The Little Brewing Company', 3.4),
#  ('La Diable', 3.571),
#  ("Brasserie d'Oran", 3.75),
#  ('Roskilde Øl', 3.0),
#  ('Weeping Radish Eco Farm & Brewery', 3.258),
#  ('Castle Rock Brewery', 3.645),
#  ('Brasserie Artisanale De La Crécelle', 3.375),
#  ("Lefty's Brewing Company", 3.482),
#  ('Motor City Brewing Works', 3.483),
#  ('Holy City Brewing', 3.656),
#  ('Davidson Brothers Restaurant & Brewery', 3.776),
#  ('Glückauf Brauerei GmbH Gersdorf', 3.75),
#  ('Privatbrauerei Kesselring Gmbh & Co. KG', 3.571),
#  ('Brauerei Josef Greif', 4.143),
#  ('Mt. Carmel Brewing Company', 3.833),
#  ('Five Seasons Prado', 3.985),
#  ('Science Infuse', 3.5),
#  ('Jaden James Brewery', 2.6),
#  ('Stevns Bryghus', 3.5),
#  ('Chelsea Brewing Company', 3.873),
#  ('Chicago Brewing Company', 3.568),
#  ('Old Credit Brewing Co.', 3.377),
#  ('Alameda Brewhouse', 3.9),
#  ('Half Moon Restaurant & Brewery', 3.741),
#  ('Brouwerij Facon', 4.0),
#  ('Dogwood Brewing Company', 3.833),
#  ('Salamander Brewing Company', 4.0),
#  ('Shandong Taishan Beer Co Ltd', 3.5),
#  ('Baltika Breweries', 3.304),
#  ('Brauerei C. & A. Veltins GmbH & Co.', 3.739),
#  ('Lucky Labrador Beer Hall', 4.083),
#  ('DuClaw Brewing Co.', 4.0),
#  ('Brauerei Baar AG', 3.0),
#  ('Microbrasserie Le Naufrageur', 3.814),
#  ('La Cumbre Brewing Co.', 4.25),
#  ('Baying Hound Aleworks', 2.767),
#  ('Ariana Brewery', 2.643),
#  ('Equinox Brewing Company', 3.991),
#  ('Elm City Brewing Co.', 3.458),
#  ('Ross Valley Brewing Company', 3.958),
#  ('Milton Brewery', 3.611),
#  ('Hargreaves Hill Brewing Company', 3.633),
#  ('Lervig Aktiebryggeri AS', 3.833),
#  ('La Cervesera Artesana', 3.25),
#  ('Drummond Brewing Company', 2.722),
#  ('Galway Hooker Brewery', 4.261),
#  ('The Flowerpots Brewery / The Flowerpots Inn', 4.0),
#  ('Beltaine Appennino Risorse', 2.833),
#  ('Saint Louis Brewery / Schlafly Tap Room', 3.891),
#  ('Firestone Walker Brewing Co.', 4.163),
#  ('Jolly Pumpkin Artisan Ales', 3.984),
#  ('Brasserie Artisanale Ratz', 2.5),
#  ('The Tin Whistle Brewing Company', 3.567),
#  ('Microbrasserie La Chouape', 3.452),
#  ('Baikalskaya Pivovarenniya Kompaniya', 2.25),
#  ('Lapin Kulta', 2.85),
#  ('Brouwerij De Drie Koningen', 3.667),
#  ('Tigertops Brewery', 4.25),
#  ('Brouwerij Maximus', 4.0),
#  ("Bushy's (Mount Brewing Company Ltd)", 3.6),
#  ('Onuma Brewery', 2.5),
#  ('Kasztelan Browar Sierpc S.A. (Carlsberg)', 2.833),
#  ('Brouwerij Angerik BVBA', 3.3),
#  ("Butcher's Brewing", 2.5),
#  ('Freedom Brewery Ltd', 3.714),
#  ('St. Francis Brewery & Restaurant', 3.1),
#  ('S.C. Bere Mure&#351;', 1.5),
#  ('First Draft - Niagara College Teaching Brewery', 3.7),
#  ('Thornbridge Brewery', 4.129),
#  ('Federation Brewery Ltd', 3.553),
#  ('Elliot Glacier Public House', 4.0),
#  ('Ballast Point Brewing Company', 4.129),
#  ('Willimantic Brewing Co.', 4.046),
#  ('Harpoon Brewery', 3.726),
#  ('Marshall Brewing Company', 3.939),
#  ('Crossroads Brewing Company', 4.068),
#  ('Ringnes Bryggeri (Carlsberg)', 2.823),
#  ('Queen City Brewing Limited', 3.667),
#  ('Bridge Road Brewers', 3.696),
#  ("Birrificio L'Olmaia", 3.562),
#  ('Privatbrauerei Scherdel OHG', 3.8),
#  ('Hyouko Yashiki No Mori Brewery', 3.667),
#  ('Zuma Brewing Company', 3.5),
#  ('Cerveza Ancla Colombia', 3.0),
#  ('Odin Brewing Company', 3.854),
#  ('Ankerbräu Nördlingen', 3.842),
#  ('Barley Brothers Brewery & Grill', 3.167),
#  ('Riverhead Brewery Limited', 3.5),
#  ('Avery Brewing Company', 3.814),
#  ('Cwmbran Brewery', 3.812),
#  ('Breakwater Brewing', 3.406),
#  ('Microbrasserie Du Lac-Saint-Jean', 3.379),
#  ('Sherwood Forest Brewers Ltd.', 3.543),
#  ('Crooked Stave Artisan Beer Project', 3.532),
#  ('Snowy Mountains Brewery', 3.375),
#  ('Independence Brew Pub', 3.558),
#  ('Shardlow Brewing Company Ltd', 3.0),
#  ('Wold Top Brewery', 3.781),
#  ("Brewster's Brewing Co Ltd", 3.378),
#  ('Krasniy Vostok', 2.67),
#  ('Rio Salado Brewing Company', 3.791),
#  ('Asheville Brewing Company', 3.754),
#  ('Big Buck Brewery & Steakhouse #3', 3.577),
#  ('Beba', 3.4),
#  ('Brouwerij Drie Fonteinen', 4.292),
#  ('Independence Brewing Co.', 3.687),
#  ('Boulder Beer / Wilderness Pub', 3.766),
#  ('Traditional Scottish Ales', 3.571),
#  ('Great Oakley Brewery', 4.0),
#  ('Wagtail Brewery', 3.5),
#  ('Brouwerij De Horste', 3.786),
#  ('Tower Brewery', 4.5),
#  ("Hamburger Mary's Rec Room", 3.1),
#  ('Storm Brewing Co.', 3.0),
#  ('Angry Minnow Brewpub', 3.74),
#  ('Turkey Hill Brewing Co. Pub & Grille', 3.962),
#  ('Teme Valley Brewery', 3.682),
#  ('P.H. Woods Restaurant & Brewery', 3.4),
#  ('Jessenhofke NV', 3.231),
#  ('Löwenbräu Buttenheim', 4.053),
#  ('Archipelago Brewing Company / Craft Beer Hub', 3.273),
#  ('Santa Fe Brewing Company', 3.686),
#  ('Scone Bierbrouwerij', 4.75),
#  ('Big Boss Brewing', 3.827),
#  ('Scuttlebutt Brewing Company', 3.611),
#  ('Dark Horse Brewing Company', 3.903),
#  ('Two Brothers Brewing Company', 3.846),
#  ('Brauerei Fischerstube AG', 3.667),
#  ('Brasserie Gigi', 3.833),
#  ('Castle Danger Brewery', 4.0),
#  ('Pivovar Hostan', 3.0),
#  ('Fletcher Street Brewing Company', 3.455),
#  ('Maritime Beer Company Inc.', 3.857),
#  ('Cottage Brewing Co. Ltd', 3.54),
#  ('Appalachian Brewing Company', 3.745),
#  ('Huebert Brewing Company', 2.75),
#  ('Red Eye Brewing Company', 3.981),
#  ('Red Rat Craft Brewery', 3.5),
#  ('Suginoya Brewery (Hamachi Shuzo K.K.)', 3.929),
#  ("Rooster's Brewing Company Ltd.", 4.019),
#  ('Red Hare Brewing Company', 3.667),
#  ('Ostankinskiy Pivovarinniy Zavod', 2.6),
#  ("Adelbert's Brewery", 3.625),
#  ('Wedge Brewing Company', 3.972),
#  ('Gruhlke Brewery', 2.833),
#  ('Brauerei Georg Meister', 4.0),
#  ('Scotch Irish Brewing Company', 3.716),
#  ('Badische Staatsbrauerei Rothaus AG', 4.357),
#  ('Flat Branch Pub & Brewery', 3.731),
#  ("B.O.B.'s House Of Brews", 2.75),
#  ('Celtic Bayou', 3.952),
#  ('Bahamian Brewery Beverage & Co. Ltd.', 3.242),
#  ('Artebirraia', 1.667),
#  ("Marston's PLC", 3.371),
#  ('Watson Bros. Bistro & Brewery', 3.5),
#  ('Privatbrauerei Gebrüder Mayer', 4.0),
#  ('Brewery Ommegang', 4.032),
#  ('Fort George Brewery + Public House', 3.932),
#  ('Williamsburg AleWerks', 3.829),
#  ('Great Newsome Brewery', 4.083),
#  ("Bloomington Brewing Company / Lennie's", 3.721),
#  ('Marston Moor Brewery Limited', 3.5),
#  ('Ambacht Brewing', 3.974),
#  ('Peak Brewing Company', 2.5),
#  ('Maui Brewing Co. (Brewpub)', 3.999),
#  ('Ezo Beer KK', 3.804),
#  ('Central City Brewing', 4.177),
#  ('Brauerei Vasold & Schmitt', 3.25),
#  ("Lily's Seafood & B.C.", 3.923),
#  ('Surly Brewing Company', 4.259),
#  ('Grebbestad Bryggeri', 3.559),
#  ('Old Hat Brewery & Grill', 3.55),
#  ('Pivovary Staropramen', 3.586),
#  ('John Boston Premium Beverages', 2.929),
#  ('Bayhawk Ales', 2.99),
#  ('Alltech’s Lexington Brewing and Distilling Co.', 3.621),
#  ('Great Dane Pub & Brewing Company (Downtown)', 3.917),
#  ("Amber's Brewing Co.", 3.479),
#  ('Blue House Mediterranean Cafe', 4.0),
#  ('Anchorage Brewing Company', 4.192),
#  ('Blacksmith Brewing', 4.143),
#  ('Fish Brewing Company / Fishbowl Brewpub', 3.789),
#  ('Freedom Brewery Ltd.', 3.5),
#  ('Coach House Brewing Company Ltd.', 3.417),
#  ('Old European Brewing Company', 2.0),
#  ('West End Brewery', 1.8),
#  ("De La Vega's Pecan Grill & Brewery", 3.5),
#  ('Cerveseria Birrart', 3.0),
#  ('Birreria Blues', 2.375),
#  ('Micro-brasserie Saint-Arnould', 3.218),
#  ('Michelsbräu GmbH', 3.5),
#  ('Payette Brewing', 3.5),
#  ('First In Last Out (FILO) Brewery', 3.0),
#  ('Burg Bier Brouwerij', 3.7),
#  ('Valkyrie Brewing', 3.77),
#  ('Durdin (Len)', 3.714),
#  ('Weisses Bräuhaus G. Schneider & Sohn GmbH', 4.104),
#  ('Church End Brewery Ltd', 3.611),
#  ('Battered Boar Brewing Company', 2.783),
#  ('Ale Industries', 3.585),
#  ("Liebhart's Privatbrauerei Detmold", 5.0),
#  ('Brouwerij Rodenburg', 3.5),
#  ('Brauerei Johannes Grasser', 4.143),
#  ('Brauerei Friedr. Jacob', 3.833),
#  ('Round Guys Brewing Company', 5.0),
#  ('Big Bear Mountain Brewery', 2.167),
#  ('Westerham Brewery Company Ltd', 3.896),
#  ("Uncle Buck's Brewery & Steakhouse", 3.182),
#  ('Microbrasserie Le Corsaire', 2.74),
#  ('Frampton Brasse', 3.667),
#  ('Brasserie Des Monts', 2.5),
#  ('Black Lotus Brewery', 3.862),
#  ('Bürgerbräu Bad Reichenhall', 3.5),
#  ('Hansa Borg Bryggerier ASA', 3.264),
#  ('Bethlehem Brew Works', 3.813),
#  ('Cervejaria Universitária', 3.778),
#  ('Les Bieres Des Hauts', 3.0),
#  ('Brouwerij Cnudde', 3.0),
#  ('Three Troupers Brewery', 3.15),
#  ('Cervejaria Bruge', 1.0),
#  ('Crailsheimer Engelbräu', 3.667),
#  ('Deschutes Brewery & Public House', 3.857),
#  ('Stone City Brewing', 4.1),
#  ('Amnesia Brewing', 3.906),
#  ('Brasserie du Chardon', 3.562),
#  ("Sacramento Brewing Company's Oasis", 3.333),
#  ('Yarra Flats Brewery', 2.957),
#  ('Brauerei Zwettl Karl Schwarz GmbH', 3.5),
#  ('Sebago Brewing Company', 3.785),
#  ('Morgan Street Brewery', 3.85),
#  ('Harriet Brewing', 4.148),
#  ('Sun King Brewing Company', 3.981),
#  ('Flying Goose Brew Pub & Grille', 3.095),
#  ('Thirsty Bear Brewing Company', 3.689),
#  ('Art Cervesers - Cervesa Artesanal', 4.25),
#  ('Grupo Modelo S.A. de C.V.', 2.95),
#  ('Spendrups Bryggeri AB', 2.763),
#  ('Silva Reghin S.A. (Brau-Union Romania)', 3.042),
#  ("O'Dempsey's", 3.676),
#  ('Harbor City Brewing Company', 3.25),
#  ("McGuire's Irish Pub of Destin", 3.692),
#  ('Lucky Bucket Brewing Co.', 3.538),
#  ('Birrificio Del Ducato', 3.843),
#  ('Fossil Fuels Brewing Company', 4.75),
#  ('Byron Bay Brewing', 3.1),
#  ('Squam Brewing', 3.826),
#  ('Purrumbete Brewing Company', 3.442),
#  ('Route 66 Brewery', 4.25),
#  ('Castel-Sakartvelo', 3.167),
#  ('Blind Lady Ale House & Automatic Brewing Co.', 4.273),
#  ('Limestone Brewing Company', 4.083),
#  ('Wessex Brewery', 3.0),
#  ('Ironbark Brewery', 3.056),
#  ('PT Bali Hai Brewery Indonesia', 2.81),
#  ('Hampshire Brewery Ltd', 3.794),
#  ('Macedonian Thrace Brewery', 3.13),
#  ('Buckeye Brewing Company', 3.758),
#  ('S´Kloane Brauhaus', 3.5),
#  ('Bent River Brewing Company', 3.769),
#  ('Moon Dog Craft Brewery', 3.595),
#  ('Zeos Brewing Company S.A.', 2.889),
#  ("Stewart's Brewing Co.", 3.994),
#  ('San Biagio', 3.5),
#  ('Bayou Teche Brewery', 3.133),
#  ('Pretty Things Beer & Ale Project', 3.988),
#  ('Brasserie Du Bocq', 3.755),
#  ('Hoeksche Waard Bierbrouwerij', 2.1),
#  ('Antigua Brewery Ltd.', 3.611),
#  ('Birrificio Freccia', 4.0),
#  ('Middle East International Investments Group/MEIIG', 2.0),
#  ('Brouwerij Bockor N.V.', 3.998),
#  ('Brownstone Restaurant & Brewhouse', 3.667),
#  ('Pivovar Ostravar (Staropramen Breweries / Inbev)', 3.375),
#  ('The Fox & Newt / Fox Beer Co.', 4.0),
#  ('Fusion Brewing', 3.25),
#  ('Pivovarský dv&#367;r Plze&#328; / Purkmistr Restaurant', 3.875),
#  ('Crouch Vale Brewery Limited', 3.98),
#  ("Govnor's Public House Restaurant And Brewery", 3.077),
#  ('HogsBack Brewing Company', 3.4),
#  ("Gritty McDuff's Brewing Company", 3.782),
#  ('J.J. Bitting Brewing Company', 3.978),
#  ('Dragonmead Microbrewery', 3.804),
#  ('Dachsbräu', 3.5),
#  ('Anadolu Efes Brewery', 3.143),
#  ("O'Brien Brewing", 2.7),
#  ('Sapporo Breweries Ltd.', 3.234),
#  ('Oceanside Ale Works', 3.595),
#  ("Trader Joe's Brewing Company", 3.673),
#  ('Iceni Brewery', 2.969),
#  ('Hansens Brauerei', 3.5),
#  ('Pivovariya Luzhniki OAO', 3.5),
#  ("Weston Brewing Company & O'Malley's Pub", 2.519),
#  ("JT Schmid's Restaurant & Brewery", 3.3),
#  ('Weissbierbrauerei Schwendl', 3.5),
#  ('Minhas Craft Brewery', 3.037),
#  ('Wharfedale Brewery', 4.0),
#  ('Obolon Brewery', 3.173),
#  ('Cervesera Tramuntana', 3.5),
#  ('Israel Beer Breweries Ltd.', 3.6),
#  ('Brasserie Seigneuriale (Sleeman Breweries Ltd.)', 4.167),
#  ('C.B. & Potts Restaurant & Brewery', 3.5),
#  ('Einstök Ölgerð', 3.5),
#  ('KleinBrouwerij De Glazen Toren', 4.12),
#  ('Liquid Hero Brewery', 3.0),
#  ('Fyne Ales Ltd', 3.904),
#  ('Rock Bottom Restaurant And Brewery', 3.312),
#  ('Pivovar Zlaty Bazant a.s.', 3.59),
#  ('Café - Brouwerij Nieuwhuys', 3.875),
#  ('Päffgen Obergärige Hausbrauerei', 4.067),
#  ('Elland Brewery', 3.943),
#  ('Fiddlehead Brewing Company', 4.25),
#  ('Red Lion Ales', 3.9),
#  ('Brasserie La Choulette', 3.891),
#  ('Viking Brewery - Vifilfell Ltd.', 2.744),
#  ('Barley and Hops Grill & Microbrewery', 3.442),
#  ('Abbey Beverage Company', 3.577),
#  ('Brasserie Artisanale Des Grands Cols', 3.6),
#  ('Long Brewing', 3.75),
#  ('Strange Brewing Company', 3.706),
#  ('Lodi Beer Company', 3.654),
#  ('Allentown Brew Works', 3.599),
#  ('Choperia & Distribuidora Opa Bier', 2.25),
#  ('Lang Creek Brewery', 3.359),
#  ('Brauerei Schäffler', 2.5),
#  ('Weissbierbrauerei Hopf', 3.864),
#  ('Oaken Barrel Brewing Company', 3.777),
#  ('AS L&#257;&#269;pl&#275;\x9aa Alus', 2.833),
#  ('Privatbrauerei Joh. Cramer', 3.0),
#  ('Demarche Brewery', 3.685),
#  ('Margaret River Ale Company', 3.0),
#  ('Brasserie Saint-Monon', 3.72),
#  ('Brasserie De La Pigeonnelle', 3.667),
#  ('Cervecería Bayernbräu de México', 3.667),
#  ('Brouwerij Bavik', 3.65),
#  ('Mendocino Brewing Company', 3.595),
#  ('Tui Brewery', 3.03),
#  ('Hofbräu Kaltenhausen (Brau Union)', 3.856),
#  ('Pratt Street Ale House', 3.929),
#  ("Monty's Brewery", 3.5),
#  ('Apatinska Pivara A.D.', 2.907),
#  ("Otter Creek Brewing / Wolaver's", 3.762),
#  ('Grassroots Brewing', 3.824),
#  ('Grauballe Bryghus - Gaardbryggeriet', 3.429),
#  ('Custom Beers Limited', 4.0),
#  ('Krash Brewery', 2.083),
#  ('Streek Bieren Iwamizawa Bakushukan', 3.0),
#  ('Trap Rock Restaurant & Brewery', 3.911),
#  ('Boscos Restaurant & Brewing Co. - Nashville', 3.737),
#  ('Brasserie Saint Antoine Abbé', 2.679),
#  ('Columbia Brewery', 3.216),
#  ('Cold Spring Brewing Co.', 3.111),
#  ('The Lab Brewing Co.', 3.5),
#  ('Ruby Mountain Brewing', 3.684),
#  ('Brasserie Haldemann', 4.0),
#  ('Sandbacka Bryggeri', 4.333),
#  ('Brouwerij De Graal', 3.833),
#  ('Peace Tree Brewing Co.', 3.767),
#  ('Bedondaine & Bedons Ronds', 3.79),
#  ('Occidental Brewing Co.', 4.0),
#  ('Ruckus Brewing', 3.697),
#  ('Lymestone Brewery', 4.0),
#  ('Utrechtse Stoombierbrouwerij B.V.', 3.75),
#  ('Throwback Brewery', 3.892),
#  ('Brauerei Eugen Häberlen', 3.0),
#  ('Brauerei Erharting', 3.5),
#  ('Ringwood Brewery', 3.727),
#  ('Smuttynose Brewing Company', 3.884),
#  ('Barley Island Brewing Company', 3.712),
#  ('Brauerei Mittenwald', 3.667),
#  ('Griesbräu Zu Murnau', 3.95),
#  ('Picaroons Brewing Co.', 3.518),
#  ('Pen-lon Cottage Brewery', 3.875),
#  ('Lake Bluff Brewing Company', 3.679),
#  ('Heater Allen Brewing', 4.129),
#  ('De Leyerth Brouwerijen (Urthel)', 3.948),
#  ('Greenbush Brewing Company', 4.0),
#  ('Qvänum Mat & Malt', 3.333),
#  ('La Brasserie Artisanale Touken', 2.875),
#  ('Cerveza Artesanal Araucana', 3.8),
#  ('Toscana Tipica  Birra  Del Linchetto', 4.333),
#  ('The Commons Brewery', 3.833),
#  ('Privatbrauerei Bischoff', 3.406),
#  ('The Walkerville Brewing Company', 3.564),
#  ('Les Brasseurs Du Sornin', 3.8),
#  ('Sebastopol Brewing Company', 2.75),
#  ('Brew Wharf', 3.625),
#  ('Eldos Grill And Brewery', 3.333),
#  ('Laverstoke Park Farm', 3.4),
#  ('Bass Brewers Limited', 3.687),
#  ('Brok Brewery', 3.15),
#  ("Martha's Exchange", 3.935),
#  ('Nashoba Valley Winery', 3.456),
#  ('Redondo Beach Brewing', 3.196),
#  ('Zagorka Brewery / Pivovaren Zavod Zagorka', 3.017),
#  ('Dogfish Head Brewery', 3.836),
#  ('Skytop Steakhouse', 4.062),
#  ('Main Street Beer Company / Williamsville Brewery', 3.091),
#  ('Brauerei Haag', 4.0),
#  ('Storchenbräu', 4.0),
#  ('Manhattan Beach Brewing Co.', 4.0),
#  ('Silver Gulch Brewing and Bottling Co.', 3.906),
#  ('Birrificio Hibu', 2.5),
#  ('Stadsbrouwerij Wittenburg', 3.5),
#  ('Greenshields Brewing Co.', 3.065),
#  ('Privatbrauerei Friedrich Düll', 2.0),
#  ('Brouwerij De Block bvba', 3.573),
#  ('Wiibroes Bryggeri', 2.594),
#  ('Unertl Weissbier GmbH', 3.842),
#  ('Square One Brewery', 3.859),
#  ('Straub Brewery', 3.519),
#  ('Socorro Springs Brewing Company', 3.333),
#  ('Allagash Brewing Company', 4.059),
#  ('New Zealand Breweries Limited', 3.071),
#  ('Cervecería Polar Los Cortijos', 3.0),
#  ('Twisted Pine Brewing Company', 3.404),
#  ('Electric Brewing Company', 3.0),
#  ('Northwoods Brewpub and Grill', 2.683),
#  ('LoverBeer', 3.875),
#  ('Blue Frog Grog & Grill', 3.148),
#  ('Pepperwood Bistro', 3.611),
#  ('Il Forteto', 1.5),
#  ('Browar Jab&#322;onowo S.C.', 3.0),
#  ('ShawneeCraft Brewing Company', 4.096),
#  ('Pasadena Brewing Company', 4.0),
#  ('Queens Wharf Brewery', 3.0),
#  ('Birra Tenute Collesi SRL', 3.828),
#  ('Titletown Brewing Company', 4.042),
#  ('Pivovar Litovel', 3.654),
#  ('Shikoku Kakou K.K.', 2.833),
#  ('Brauerei Gebrüder Röhrl', 3.8),
#  ('Angel City Brewing', 3.007),
#  ('Vat Pivobyezalkogolniy Kombinat Krim', 3.0),
#  ('Storm Brewing', 3.855),
#  ('Red Dot Brewhouse', 1.0),
#  ('Birrificio Ticinese', 3.5),
#  ('Onidensetsu Ji-Beer', 4.0),
#  ('North Coast Brewing Co.', 3.98),
#  ('Tempo Beer Industries LTD', 3.149),
#  ('Bräu im Moos', 3.5),
#  ('Greene King / Morland Brewery', 3.634),
#  ('Brouwerij Fisser NV', 3.917),
#  ('Commonwealth Brewery Ltd.', 3.129),
#  ('Musikbryggeriet DaCapo', 3.5),
#  ('Nantahala Brewing Company', 4.243),
#  ('Ma&#322;opolski Browar Strzelec', 3.308),
#  ('Great Baraboo Brewing Company', 3.8),
#  ('Flying Monkey Brewing Company', 3.44),
#  ('Grolsch Bierbrouwerij N.V.', 3.266),
#  ('Cold Storage Craft Brewery', 3.409),
#  ('Old Chimneys Brewery', 4.227),
#  ('Borsodi Brewery', 3.021),
#  ('Beachwood BBQ & Brewing', 4.129),
#  ('Huttenkloas', 4.0),
#  ('Northern Rivers Brewing Co.', 3.357),
#  ('Furthermore Beer', 3.654),
#  ('Lagerheads Smokehouse & Brewing Co.', 3.455),
#  ('Brewboys', 3.7),
#  ('Creekside Pub & Brewery', 2.25),
#  ("Mac's Brewery", 3.528),
#  ('The Gahan House', 3.296),
#  ('C.K. Browar', 3.667),
#  ('Brouwerij Het Sas', 3.057),
#  ("Mick Duff's Brewing Company", 3.917),
#  ('Mountain Ridge Brewery', 3.5),
#  ('Tullycross Tavern & Microbrewery', 3.833),
#  ('961 Beer', 3.222),
#  ('Harvest Moon Brewery', 3.75),
#  ('Cervezas Anaga', 3.0),
#  ('Beaver Street Brewery & Whistle Stop Cafe', 3.632),
#  ('Vanberg & DeWulf', 3.908),
#  ('Ascot Ales', 3.438),
#  ('Pivovar Steiger', 4.0),
#  ('Oasis Brewery', 3.786),
#  ("Callahan's Pub & Brewery", 4.0),
#  ('Whitewater Brewing Co', 4.065),
#  ('Red Rose Brewery', 2.5),
#  ('Brasserie de Skida', 1.25),
#  ('Licher Privatbrauerei', 3.879),
#  ('Potosi Brewing Company', 3.711),
#  ('Brasserie Piedboeuf', 2.906),
#  ('Bison Brewing', 3.551),
#  ('Tin Mill Brewing', 3.682),
#  ('Brouwerij De Dolle Brouwers', 3.981),
#  ('Hawkshead Brewery / Staveley Brewery & Beer Hall', 3.81),
#  ('Chateau Kamiya Hachinohe', 3.75),
#  ('Kraft Bräu - Blesius Garten', 3.5),
#  ('Rahr & Sons Brewing Company', 3.677),
#  ('Wuppertaler Brauhaus GmbH', 4.25),
#  ('SanTan Brewing Co.', 3.805),
#  ('Laughing Dog Brewing', 3.655),
#  ('Old Schoolhouse Brewery', 3.772),
#  ('Nynäshamns Angbryggeri', 3.832),
#  ('Brasserie Val De Sambre', 3.629),
#  ('Hue Brewery LTD', 2.558),
#  ('Flat 12 Bierwerks', 3.944),
#  ('Multi-Brasses', 2.883),
#  ('Bowman Ales Ltd.', 4.0),
#  ('Tundra Brewery', 2.8),
#  ('Italian Oasis Restaurant And Brewery', 3.375),
#  ('Kloster Kreuzberg', 4.5),
#  ('Brauerei Alsfeld AG', 3.5),
#  ("Johansson's Dining House", 4.065),
#  ('Bierbrouwerij De Drie Ringen', 3.2),
#  ('Empresa De Cervejas Da Madeira', 2.75),
#  ('Black Country Ales', 3.25),
#  ('Andwell Brewing Company', 4.5),
#  ('Wolf Brewery Ltd.', 3.738),
#  ('Bonnema Brewing Company', 4.167),
#  ('New Orleans Lager & Ale Brewing Company (NOLA)', 4.123),
#  ('Kingdom Brewers', 4.0),
#  ('Phantom Canyon Brewing Company', 3.642),
#  ('Brasserie Zannekin', 3.0),
#  ('Highlander Brew Co.', 3.636),
#  ('Lucky Labrador Brewing Company', 4.0),
#  ("Eske's Brew Pub & Eatery", 3.556),
#  ('Landmark Brewing Company', 4.045),
#  ('Indslev Bryggeri', 3.417),
#  ('Åsundens Bryggeri', 4.0),
#  ('Craft Brewing Company', 4.0),
#  ('Barossa Brewing Company', 4.0),
#  ('Beauce Broue', 3.5),
#  ("Brasserie Kerav'ale", 4.0),
#  ('Nihonkai Yuhi Brewery', 2.625),
#  ('Rivertowne Pourhouse', 4.046),
#  ('Shipyard Brewing Co.', 3.478),
#  ('Stone Coast Brewing Co.', 3.757),
#  ('Stieglbrauerei zu Salzburg GmbH', 3.713),
#  ('Brouwerij De Koninck NV', 3.683),
#  ('Rother Valley Brewing Co.', 3.833),
#  ("Pinglehead Brewing Co. / Brewer's Pizza", 4.364),
#  ('Old North State Winery And Brewery', 4.0),
#  ('Ahlafors Bryggerier AB', 4.0),
#  ('Nikko Brewing', 3.0),
#  ("BJ's Chicago Pizza & Brewery Inc.", 3.729),
#  ('Café-Brouwerij Loterbol', 3.858),
#  ('Hirschbrauerei GmbH & Co. KG', 3.389),
#  ('Tuscan Brewing', 3.389),
#  ("Ham's Restaurant & Brewhouse", 4.171),
#  ('Kikazakura K.K.', 2.0),
#  ('Lautertaler Hausbrauerei', 4.0),
#  ('Charlis Brygghus', 3.75),
#  ('Bierbrouwerij De Boei', 2.125),
#  ('Serengeti Breweries Ltd', 3.5),
#  ('Brasserie Augrenoise', 3.5),
#  ('Oskar Blues Grill & Brew', 4.006),
#  ('Roy Pitz Brewing Company', 3.748),
#  ('Shoes Brewery', 3.0),
#  ('Black Forest Brew Haus', 3.937),
#  ('Otter Brewery Ltd', 3.83),
#  ('La Grihète', 3.857),
#  ('Ursus S.A. (SAB) / Compania de Bere Romania', 2.933),
#  ('Microbrasserie Archibald', 3.455),
#  ('Yakima Craft Brewing Co.', 3.451),
#  ('Jack Black Beer', 3.75),
#  ('Augusta Brewing Company', 3.618),
#  ('Wibblers', 4.0),
#  ('Finlandia Sahti Ky', 3.667),
#  ('Bellarine Brewing Co.', 3.062),
#  ('Brasserie Basabürüa', 2.5),
#  ('Athenian Brewery', 2.993),
#  ('Maltovivo', 3.6),
#  ('Dugges Ale- & Porterbryggeri AB', 3.619),
#  ('Clanconnel Brewing Company', 3.786),
#  ('Brouwerij De Ryck', 3.365),
#  ('Seabright Brewery', 3.613),
#  ('Paulaner Bräuhaus', 4.0),
#  ('La Micro de Bromont', 3.074),
#  ('Luckie Ales', 4.125),
#  ('Spitalbrauerei Regensburg', 3.875),
#  ('Adirondack Pub & Brewery', 3.763),
#  ('Black Rock Brewing Co.', 4.0),
#  ('San Luis Valley Brewing Company', 3.6),
#  ('Boundary Bay Brewery & Bistro', 3.948),
#  ('Mauldons', 3.833),
#  ('Logsdon Farmhouse Ales', 4.194),
#  ("BJ's Restaurant", 3.433),
#  ('Central Waters Brewing Company', 3.974),
#  ('Alandale Brewing Company', 4.0),
#  ('Hinterland Brewery Restaurant', 3.865),
#  ('Hausbrauerei Zum Schlüssel', 4.263),
#  ("Cally's Restaurant and Brewing Co.", 4.028),
#  ('Last Drop Brewery', 3.583),
#  ('De Hoevebrouwers', 3.812),
#  ('El Toro Brewing Co.', 3.821),
#  ('Linden Brauerei GmbH', 2.929),
#  ('Beer House', 2.833),
#  ('Birrificio Spluga', 1.5),
#  ('St. George Brewery', 3.25),
#  ('Mistura Clássica', 3.6),
#  ('Old Yale Brewing Co.', 4.008),
#  ('Maple Valley Brewing Company', 4.5),
#  ('Brouwerij Het Anker', 4.024),
#  ('Barley Creek Brewing Company', 3.243),
#  ('Steam Exchange Brewery', 3.6),
#  ('Hardknott Brewery', 3.5),
#  ('Brouwerij Van den Bossche', 3.681),
#  ('Atlantic Brewery', 4.0),
#  ('Inuyama Loreley Beer', 4.0),
#  ('Grimm Brothers Brewhouse', 4.111),
#  ('Big Rock Brewery', 3.244),
#  ('Alaskan Brewing Co.', 3.912),
#  ('OPZ Saransk', 2.75),
#  ('Riverport Brewing Company', 3.409),
#  ("Bill's Tavern & Brewhouse", 3.833),
#  ('Browary Bydgoskie Sp. Z O.o. (Brau Union Polska)', 3.286),
#  ('Meantime Brewing Company Limited', 3.878),
#  ('Brauerei Göss (Brau Union)', 3.511),
#  ('Mythos Breweries S.A.', 2.908),
#  ('Birdsview Brewing Company', 3.864),
#  ('Wild Wolf Brewing Company', 4.0),
#  ('Hill Farmstead Brewery', 4.299),
#  ('Bruggsmiðjan', 3.375),
#  ('2 Brothers Brewery', 3.686),
#  ('Brauhaus Simon Strasser', 3.5),
#  ('Ilkley Brewery Co.', 4.125),
#  ("Brasserie D'Annoeulin", 3.667),
#  ('Bandersnatch Brewpub', 3.875),
#  ('Great White North Craft Brewery', 3.667),
#  ('Ørbæk Bryggeri', 3.583),
#  ('Privatbrauerei M.C. Wieninger', 3.583),
#  ('Sillamäe Õlletehas', 3.0),
#  ('Broken Drum Brewery And Wood Grill', 3.389),
#  ('Southern Star Brewing Company', 4.002),
#  ('Günther Bräu', 4.083),
#  ('Pardubický pivovar a.s.', 3.631),
#  ('Le Trou Du Diable', 3.822),
#  ('Wild River Brewery & Pizza Company', 3.729),
#  ('Bi-Du', 3.688),
#  ('The Defiant Brewing Company', 3.953),
#  ('Coldstream Brewery', 3.389),
#  ("Bierbrouwerij 't Vølendam", 3.167),
#  ('Caldera Brewing Company', 3.954),
#  ('7 Seas Brewery and Taproom', 3.56),
#  ('Calapooia Brewing Company', 3.982),
#  ('Hokusetsu Brewery', 3.0),
#  ('Isle Of Skye Brewery', 3.711),
#  ('Founders Brewing Company', 4.115),
#  ('Pivovarna Laško', 3.194),
#  ('Cambridge Brewing Company', 4.052),
#  ('Bath Ales Ltd', 4.0),
#  ('Great Basin Brewing Co.', 3.773),
#  ('Cooperstown Brewing Company', 3.623),
#  ('Big Hurt Brewing Company', 3.125),
#  ('McMenamins Queen Anne Hill', 3.682),
#  ('Brouwerij Ter Dolen N.V.', 3.833),
#  ('Colorado Mountain Brewery', 3.5),
#  ('Rinkuškiai Alaus Darykloje', 2.86),
#  ('Brauerei Heller-Trum / Schlenkerla', 3.899),
#  ('Brasserie Nationale (Bofferding)', 2.0),
#  ("O'so Brewing Company", 3.693),
#  ('Kolos OAO/ Ledyanoy Stakanchik', 2.4),
#  ('Brauerei Gilde', 3.891),
#  ('Cannon Brew Pub', 3.794),
#  ('Cheriton Brewery', 4.667),
#  ('Nail Creek Pub & Brewery', 4.0),
#  ('Summit Station Restaurant & Brewery', 3.447),
#  ('Scarampola', 2.75),
#  ('The Big Cheese Pizza Co.', 3.569),
#  ('Brouwerij Slaapmutske', 3.806),
#  ('Melchers Group', 3.25),
#  ('Hofbrauhaus Berchtesgaden', 3.6),
#  ('Les Brasseurs de Gayant', 3.481),
#  ('Robinsons Family Brewers', 3.615),
#  ('Guangzhou Zhujiang Brewery Co. Ltd.', 2.532),
#  ('Via Priula', 2.5),
#  ('C.B. & Potts', 3.812),
#  ('Zum Löwenbräu', 3.5),
#  ('Brasserie De Clerck', 4.0),
#  ('BFM Brasserie Des Franches-Montagnes', 3.858),
#  ('Brouwerij Roman N.V.', 3.732),
#  ("Hale's Ales Brewery & Pub", 3.716),
#  ('Four Peaks Brewing Company', 3.809),
#  ('Brouwerij Clarysse NV', 3.5),
#  ('Herslev Bryghus', 3.565),
#  ('Halifax Steam Brewing Company Ltd', 2.5),
#  ('Martini Brauerei GmbH', 3.583),
#  ('Sonoma Springs Brewing Co.', 3.75),
#  ('Schmohz Brewing Company', 3.135),
#  ('16 Mile Brewing Company', 3.571),
#  ('Keltic Brewing Company', 2.625),
#  ('Micro Cervejaria Bamberg', 3.842),
#  ('Keuka Brewing Company', 3.604),
#  ('McCall Brewing Company', 4.0),
#  ('Black Raven Brewing Co.', 3.975),
#  ('Engelbräu Rettenberg', 3.25),
#  ('Microbrasserie la Memphré', 3.0),
#  ('Galway Bay Brewery', 3.333),
#  ("Saint Katherine's Brewing Company", 3.375),
#  ('Buffalo Brewery (Aus.)', 2.214),
#  ('Genesee Brewing Co. / Dundee Brewing Co.', 3.384),
#  ('Rheingold Brewing Co.', 2.991),
#  ("Rogue's Roost Brew Pub & Eatery", 4.119),
#  ('Bristol Brewing Company', 3.736),
#  ('Original Gravity Brewing Company', 4.167),
#  ('To Øl', 4.0),
#  ('Brauerei Forst AG', 3.351),
#  ('High House Farm Brewery', 3.75),
#  ('Nelson Brewing Company', 3.694),
#  ("Scottish Chief's Tavern Brewery", 3.333),
#  ('Brauerei Hofstetten Krammer GmbH & Co. KG', 3.829),
#  ('Stallhagens Bryggeri Ab', 3.528),
#  ('Werner Bräu GmbH', 3.833),
#  ('Big City Brewing CO LTD', 3.375),
#  ('Aberdeen Brewing Company', 4.0),
#  ('Auerhahn Bräu Schlitz GmbH', 3.333),
#  ('Arbor Brewing Company', 3.544),
#  ('New Old Lompoc Brewery', 3.876),
#  ('Burleigh Brewing Co.', 3.391),
#  ('Ribe Bryghus', 3.75),
#  ('Brauerei Bischofshof', 3.759),
#  ('St. Sebastiaan Belgian Microbrewery', 3.607),
#  ('Hook Norton Brewery Co. Ltd.', 3.948),
#  ('Argus Brewery', 3.321),
#  ('OWA Beer', 3.5),
#  ('Howard Town Brewery', 3.75),
#  ('Cervejaria Petrópolis', 2.824),
#  ('Shinano Brewery Vanryu / Chestnut Pub', 4.333),
#  ('Brewbakers', 4.0),
#  ('River City Brewing Co.', 3.75),
#  ("Brasserie d'Oc", 3.2),
#  ('Halsnæs Bryghus', 4.0),
#  ('Roc Brewing Company', 3.0),
#  ('Mt. Emily Ale House', 3.611),
#  ('Brasserie Artisanale De Rullés SPRL', 4.042),
#  ('New Belgium Brewing', 3.854),
#  ('The Porterhouse Brewing Company', 3.729),
#  ('Cerveceria Costa Rica', 3.096),
#  ('Brauerei Schloss Starkenberg', 3.5),
#  ('Hopdaemon Brewery Company', 3.562),
#  ('Amherst Brewing Co.', 3.954),
#  ('Brouwerij De Vlier', 3.375),
#  ('Bowral Brewing Company', 3.167),
#  ('Lennet Brau- Und Vertriebsgesellschaft', 3.5),
#  ('Salopian Brewing Company Ltd', 3.95),
#  ('Odonata Beer Company', 4.235),
#  ('Huisbrouwerij Sint Canarus', 3.761),
#  ('Tun Tavern', 3.813),
#  ('Crazy Mountain Brewing Company', 3.717),
#  ('Brasserie Alauna', 4.0),
#  ('Brauerei Franz Xaver Glossner', 3.75),
#  ("Witch's Hat Brewing Co.", 4.333),
#  ('Erve Kots Brouwerij', 3.0),
#  ('Ben Middlemiss Brewing', 3.115),
#  ('BABB Srl', 2.875),
#  ("Maihama Beer Koubou Harvestmoon Brewery At Roti's House", 3.571),
#  ('Market Cross Pub & Brewery', 3.906),
#  ('Hangtown Brewery', 4.0),
#  ('Three Creeks Brewing Co.', 3.691),
#  ('Frosty Knuckle Brewing Company', 3.45),
#  ('McCallum Brewery', 3.188),
#  ('Baltimore Brewing Company', 3.805),
#  ('Brimstage Brewing Co Ltd', 4.75),
#  ("Brasserie D'Ecaussinnes", 3.565),
#  ('Brasserie Artisanale La Frasnoise', 3.75),
#  ('Brouwerij Mort Subite', 3.628),
#  ('Telegraph Brewing Company', 3.7),
#  ('Southampton Publick House', 4.004),
#  ("BJ's Restaurant & Brewhouse", 3.549),
#  ('Dead Frog Brewing', 3.519),
#  ('Brewsters Brewing Company & Restaurant - Eleventh Avenue', 3.647),
#  ('Market Garden Brewery', 3.455),
#  ('Mystic Brewery', 3.87),
#  ('High Point Brewing Company', 4.101),
#  ("Twain's Billiards and Tap", 3.801),
#  ('Dama Bier', 2.875),
#  ('Etna Brewery', 4.25),
#  ('Biha&#263;ka Pivovara', 2.714),
#  ("Stockholm's", 3.167),
#  ('Stoney Creek Brewing Company', 3.64),
#  ('Gamla Stans Bryggeri', 4.5),
#  ('Officina Della Birra', 2.5),
#  ('Boston Beer Company (Samuel Adams)', 3.692),
#  ('Nimbus Brewing Company', 3.659),
#  ('Princetown Breweries Limited', 2.5),
#  ('Ferme Brasserie Garland', 3.5),
#  ('Matten', 4.0),
#  ("Mary's Pizza Shack", 3.5),
#  ('North End Tavern & Brewery', 3.789),
#  ('Elevation 66 Brewing', 3.5),
#  ('Jailhouse Brewing Company', 3.89),
#  ('Hopworks Urban Brewery', 4.083),
#  ('Pabst Brewing Company', 3.281),
#  ('Metropolitan Brewing', 4.091),
#  ('Brasserie Du Canardou', 3.321),
#  ('Carlyle Brewing Company', 3.9),
#  ('Harts Pub / Rocks Brewing Co.', 3.694),
#  ('Mulholland Brewing Company', 3.6),
#  ('Bridestones Brewing Company Limited', 3.75),
#  ('Feldschloesschen AG', 4.1),
#  ('Triton Brewing Company', 3.917),
#  ('Tampa Bay Brewing Co.', 3.816),
#  ('Wentworth Brewery Limited', 3.659),
#  ('Slavutych Brewery', 2.938),
#  ('Hops Grillhouse & Brewery', 3.127),
#  ('Elk Head Brewing Company', 2.643),
#  ('North Star Craft Brewery', 4.0),
#  ('Cervecera Regional', 3.0),
#  ("Dempsey's Restaurant And Brewery", 3.361),
#  ('WinterCoat', 3.573),
#  ...]

# %%
# STEP 5
start_time5 = time.time()

processed_rdd = split_rdd.map(lambda x: (x[8], 1))
counts_rdd = processed_rdd.reduceByKey(lambda x,y: x+y)

end_time5 = time.time()
elapsed_time5 = end_time5 - start_time5
elapsed_times_list.append(elapsed_time5)
print(f"Elapsed time: {elapsed_time5} seconds")

counts_rdd.collect()
# Out:
# Elapsed time: 0.00940847396850586 seconds
# [('Rauchbier', 3758),
#  ('Belgian Strong Dark Ale', 36869),
#  ('American Strong Ale', 29570),
#  ('Märzen / Oktoberfest', 20951),
#  ('Altbier', 7207),
#  ('Scotch Ale / Wee Heavy', 16369),
#  ('English India Pale Ale (IPA)', 14722),
#  ('English Pale Mild Ale', 460),
#  ('Lambic - Fruit', 10178),
#  ('Eisbock', 2645),
#  ('Faro', 608),
#  ('Bière de Champagne / Bière Brut', 1041),
#  ('Russian Imperial Stout', 50997),
#  ('American Amber / Red Ale', 40292),
#  ('Euro Pale Lager', 16824),
#  ('English Bitter', 8082),
#  ('Euro Strong Lager', 2637),
#  ('Schwarzbier', 9343),
#  ('Munich Dunkel Lager', 7033),
#  ('Vienna Lager', 7570),
#  ('Witbier', 27479),
#  ('Kölsch', 7540),
#  ('Smoked Beer', 2804),
#  ('Dunkelweizen', 6700),
#  ('Winter Warmer', 19103),
#  ('American Double / Imperial Pilsner', 5356),
#  ('Quadrupel (Quad)', 17701),
#  ('Kvass', 229),
#  ('Roggenbier', 395),
#  ('Rye Beer', 9604),
#  ('English Barleywine', 13368),
#  ('Belgian Strong Pale Ale', 31289),
#  ('American Brown Ale', 24075),
#  ('English Stout', 2736),
#  ('Braggot', 979),
#  ('Japanese Rice Lager', 1349),
#  ('Happoshu', 120),
#  ('Sahti', 1004),
#  ('German Pilsener', 20333),
#  ('Herbed / Spiced Beer', 9823),
#  ('Oatmeal Stout', 16800),
#  ('American IPA', 107913),
#  ('English Brown Ale', 17103),
#  ('Belgian Pale Ale', 18565),
#  ('Irish Dry Stout', 11576),
#  ('American Double / Imperial Stout', 48299),
#  ('Dortmunder / Export Lager', 4195),
#  ('Low Alcohol Beer', 986),
#  ('Extra Special / Strong Bitter (ESB)', 14880),
#  ('Bock', 10676),
#  ('Milk / Sweet Stout', 12271),
#  ('Scottish Ale', 7758),
#  ('Saison / Farmhouse Ale', 30588),
#  ('California Common / Steam Beer', 3817),
#  ('Tripel', 29479),
#  ('Irish Red Ale', 7210),
#  ('Czech Pilsener', 10205),
#  ('English Dark Mild Ale', 2087),
#  ('Baltic Porter', 10986),
#  ('Flanders Red Ale', 6540),
#  ('Berliner Weissbier', 2717),
#  ('Gueuze', 5926),
#  ('Gose', 654),
#  ('English Strong Ale', 4287),
#  ('American Double / Imperial IPA', 81143),
#  ('American Pale Ale (APA)', 56871),
#  ('American Adjunct Lager', 25726),
#  ('American Stout', 18267),
#  ('Pumpkin Ale', 14815),
#  ('American Pale Wheat Ale', 20466),
#  ('American Black Ale', 11099),
#  ('Euro Dark Lager', 4207),
#  ('English Pale Ale', 22217),
#  ('Belgian Dark Ale', 6267),
#  ('Cream Ale', 4693),
#  ('Black & Tan', 2078),
#  ('Scottish Gruit / Ancient Herbed Ale', 2695),
#  ('Wheatwine', 3441),
#  ('American Dark Wheat Ale', 1035),
#  ('American Malt Liquor', 3705),
#  ('Kristalweizen', 2042),
#  ('Hefeweizen', 25713),
#  ('Foreign / Export Stout', 5802),
#  ('Light Lager', 13004),
#  ('American Pale Lager', 7330),
#  ('American Porter', 45566),
#  ('American Blonde Ale', 10291),
#  ('Fruit / Vegetable Beer', 30904),
#  ('English Porter', 9528),
#  ('American Barleywine', 24957),
#  ('Doppelbock', 20259),
#  ('Maibock / Helles Bock', 9698),
#  ('American Amber / Red Lager', 8228),
#  ('Flanders Oud Bruin', 4903),
#  ('Dubbel', 19394),
#  ('Keller Bier / Zwickel Bier', 2433),
#  ('Bière de Garde', 6400),
#  ('Chile Beer', 2087),
#  ('Belgian IPA', 12239),
#  ('American Wild Ale', 16760),
#  ('Weizenbock', 9234),
#  ('Munich Helles Lager', 7394),
#  ('Old Ale', 14440),
#  ('Lambic - Unblended', 1032)]

# %%
# STEP 6
start_time6 = time.time()

processed_rdd = split_rdd.map(lambda x: (x[8], (float(x[5]), 1)))

sum_per_style_rdd = processed_rdd.reduceByKey(lambda x, y: (x[0]+y[0], x[1]+y[1]))
# key(sum(review_aroma, count)
sum_per_style_rdd = sum_per_style_rdd.mapValues(lambda x: (x[0], x[1], (x[0]/x[1])))
# key(sum(aroma), count, mean)

squared_diffs = processed_rdd.join(sum_per_style_rdd).mapValues(lambda x: ((x[0][0] - x[1][2]) ** 2, 1))
sum_squared_diffs = squared_diffs.reduceByKey(lambda x,y: (x[0]+y[0], x[1]+y[1]))
variance_per_style = sum_squared_diffs.mapValues(lambda x: round(x[0]/x[1], 3))

end_time6 = time.time()
elapsed_time6 = end_time6 - start_time6
elapsed_times_list.append(elapsed_time6)
print(f"Elapsed time: {elapsed_time6} seconds")

variance_per_style.collect()
# Out:
# Elapsed time: 0.02527451515197754 seconds
# [('Rauchbier', 0.408),
#  ('American Strong Ale', 0.353),
#  ('Altbier', 0.337),
#  ('Scotch Ale / Wee Heavy', 0.304),
#  ('Eisbock', 0.28),
#  ('Faro', 0.381),
#  ('American Amber / Red Ale', 0.382),
#  ('Euro Pale Lager', 0.485),
#  ('English Bitter', 0.358),
#  ('Euro Strong Lager', 0.568),
#  ('Schwarzbier', 0.316),
#  ('Munich Dunkel Lager', 0.362),
#  ('Vienna Lager', 0.349),
#  ('Witbier', 0.38),
#  ('Smoked Beer', 0.334),
#  ('Dunkelweizen', 0.34),
#  ('Winter Warmer', 0.357),
#  ('Rye Beer', 0.316),
#  ('English Barleywine', 0.341),
#  ('Belgian Strong Pale Ale', 0.31),
#  ('English Stout', 0.318),
#  ('Sahti', 0.415),
#  ('German Pilsener', 0.473),
#  ('Herbed / Spiced Beer', 0.495),
#  ('Oatmeal Stout', 0.292),
#  ('American IPA', 0.343),
#  ('Belgian Pale Ale', 0.361),
#  ('Low Alcohol Beer', 0.71),
#  ('Extra Special / Strong Bitter (ESB)', 0.304),
#  ('Bock', 0.414),
#  ('Scottish Ale', 0.32),
#  ('California Common / Steam Beer', 0.3),
#  ('Czech Pilsener', 0.395),
#  ('English Dark Mild Ale', 0.339),
#  ('English Strong Ale', 0.314),
#  ('American Pale Ale (APA)', 0.365),
#  ('American Adjunct Lager', 0.516),
#  ('American Stout', 0.336),
#  ('American Pale Wheat Ale', 0.462),
#  ('American Black Ale', 0.275),
#  ('Cream Ale', 0.427),
#  ('Black & Tan', 0.401),
#  ('Wheatwine', 0.29),
#  ('American Dark Wheat Ale', 0.306),
#  ('Kristalweizen', 0.483),
#  ('American Porter', 0.336),
#  ('English Porter', 0.317),
#  ('American Barleywine', 0.274),
#  ('Doppelbock', 0.336),
#  ('Maibock / Helles Bock', 0.301),
#  ('Keller Bier / Zwickel Bier', 0.279),
#  ('Bière de Garde', 0.316),
#  ('American Wild Ale', 0.316),
#  ('Weizenbock', 0.266),
#  ('Munich Helles Lager', 0.37),
#  ('Belgian Strong Dark Ale', 0.294),
#  ('Märzen / Oktoberfest', 0.328),
#  ('English India Pale Ale (IPA)', 0.386),
#  ('English Pale Mild Ale', 0.36),
#  ('Lambic - Fruit', 0.411),
#  ('Bière de Champagne / Bière Brut', 0.495),
#  ('Russian Imperial Stout', 0.294),
#  ('Kölsch', 0.361),
#  ('American Double / Imperial Pilsner', 0.292),
#  ('Quadrupel (Quad)', 0.297),
#  ('Kvass', 0.58),
#  ('Roggenbier', 0.194),
#  ('American Brown Ale', 0.32),
#  ('Braggot', 0.323),
#  ('Japanese Rice Lager', 0.392),
#  ('Happoshu', 0.614),
#  ('English Brown Ale', 0.336),
#  ('Irish Dry Stout', 0.394),
#  ('American Double / Imperial Stout', 0.324),
#  ('Dortmunder / Export Lager', 0.425),
#  ('Milk / Sweet Stout', 0.324),
#  ('Saison / Farmhouse Ale', 0.292),
#  ('Tripel', 0.297),
#  ('Irish Red Ale', 0.354),
#  ('Baltic Porter', 0.286),
#  ('Flanders Red Ale', 0.326),
#  ('Berliner Weissbier', 0.367),
#  ('Gueuze', 0.314),
#  ('Gose', 0.262),
#  ('American Double / Imperial IPA', 0.32),
#  ('Pumpkin Ale', 0.49),
#  ('Euro Dark Lager', 0.454),
#  ('English Pale Ale', 0.377),
#  ('Belgian Dark Ale', 0.316),
#  ('Scottish Gruit / Ancient Herbed Ale', 0.318),
#  ('American Malt Liquor', 0.716),
#  ('Hefeweizen', 0.361),
#  ('Foreign / Export Stout', 0.31),
#  ('Light Lager', 0.609),
#  ('American Pale Lager', 0.48),
#  ('American Blonde Ale', 0.403),
#  ('Fruit / Vegetable Beer', 0.63),
#  ('American Amber / Red Lager', 0.421),
#  ('Flanders Oud Bruin', 0.361),
#  ('Dubbel', 0.329),
#  ('Chile Beer', 0.868),
#  ('Belgian IPA', 0.258),
#  ('Old Ale', 0.309),
#  ('Lambic - Unblended', 0.284)]

# %%
end_time_overall = time.time()
elapsed_time_visualisation = end_time_overall - start_time_overall
elapsed_time_no_visualisation = sum(elapsed_times_list)
print(f"Elapsed time: {elapsed_time_no_visualisation} seconds without visualising data")
print(f"Elapsed time: {elapsed_time_visualisation} seconds with visualising data")
# Out:
# Elapsed time: 0.6640036106109619 seconds without visualising data
# Elapsed time: 48.12921333312988 seconds with visualising data

# %%
sc.stop()
